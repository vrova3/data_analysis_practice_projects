# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Hello, Roman!👋 How are you today?</b>
#
# My name is Arina U. and I am glad to be your reviewer in this project! Nice to meet you!<br />
#
#
# You can find my comments in <font color='green'>green</font>, <font color='gold'>yellow</font> and <font color='red'>red</font> boxes. Examples you can see below:
#
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b> In case if task is completely correct and everything is alright!
# </div>
#
#
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>  In case when I can give some advice that can help you to improve your work or recommend you some useful links and resources that can help you widen your knowledge and help in future tasks.
# </div>
#
# <div class="alert alert-block alert-danger">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Needs fixing!🤔:</b> In case when step requires some extra work and some corrections. Project can't be accepted with comments in the red boxes
# </div>
#
# Please pay attention to not move or change my comments. It would be good to highlight your answers in some way.
#
# #### <font color='Purple'>Student's commentary:</font> for example like this <a class="tocSkip"> </div>
#
# OK, now let's go!😏
# </font>

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> Hello, Arina! It's nice to meet you too. Thank you so much for such detailed feedback and the super helpful tips! I really appreciate you taking the time to review my project (and now I don't feel so awful about it!). Sorry for not taking care to label my charts from the start, I must have gotten carried away plotting them! I've fixed that now. If it is not critical, I will come back to the sections where I could look more into correlation between data points for filling in missing values, as well as to the grouping methods that you suggested (and also check out that heatmap solution for the other part!) in a little bit as I am really pressed on time these few days (and stressed about the hard deadline!). But I read into it and I can see how these are important, so thank you again for pointing these out to me and for all the other amazing tips and links that you left for me, I will definitely apply them in my next project!
# <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review<a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Hi, again, Roman! Glad to hear from you so soon! Thank you so much for the feedbacl, I really appreciate it😉 Ok, got it, so let's look at what you managed to improve👀
# </div>

# %% [markdown]
# # Research on car sales ads
#
# For this task, I'm an analyst at Crankshaft List. Hundreds of free advertisements for vehicles are published on our site every day, and I need to study the data collected over the last year to determine which factors influence the price of a vehicle.
#
# **Description of the data**
#
# `price` - price of the advertised vehicle, presumably set by the seller
#
# `model_year` - year produced
#
# `model` -  name of the car brand + specific model
#
# `condition` - condition of the car
#
# `cylinders` - number of cylinders
#
# `fuel` - type of fuel (gas, diesel, etc.)
#
# `odometer` - the mileage of the car at the time of ad publication
#
# `transmission` - type of transmission (automatic, manual, etc.)
#
# `type` – type of vehicle (sedan, SUV, etc.)
#
# `paint_color` - color of the car
#
# `is_4wd` - whether the car has a four-wheel drive (Boolean – if not, presumably, two-wheel)
#
# `date_posted` - date of ad publication
#
# `days_listed` - for how many days the ad was available since published until it was removed
#
# How to go about it?
#
# First things first: we (first) need to have a good look at the data, see what's in store.
#
# For our second step, we'll preprocess the data – find and, if appropriate, fill in the missing values, deal with duplicate entries, rename some columns, change data types to more suitable  where appropriate. Brush up our dataset.
#
# Before proceeding on to the big task, it will be useful to enhance our data a little bit by adding some useful variables or categories, based on what we are provided with. For instance, we can produce addidional columns such as day of the week, month and year (this can be extracted from the date of ad publication), the age of the car at the time of publication, average mileage of the car per year. This will be step 3.
#
# Ultimately we want to carry out Exploratory Data Analysis (step 4) to answer the question, what contributes most to a vehicle's price? Does it depend on condition, age, transmission type, or even color? To do this, we will plot histograms and study such parameters as price, vehicle's age when the ad was placed, mileage, number of cylinders, and condition. We'll see if there are any outliers and plot the filtered data again to compare with the previous result. After that we'll look into the lifetime of ads (how many days they were on display). We'll find out the typical length and try to see when the ads were removed too quickly or listed for too long. We'll analyze the number of ads and the average price for each type of vehicle, and try to see if and how the number of ads depends on the type of the car. We'll then select the two most popular types (by number of ads), and study the correlation of factors mentioned above (condition, age, mileage, transmission type, color) with their price.

# %% [markdown]
# ## Open the data file and study the general information.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = pd.read_csv('/Users/rv/Desktop/practice_datasets/vehicles_us.csv')
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    47906 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   odometer      43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   paint_color   42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# I would like to recommend you to use `try-except` construction for importing of the data. More details see on the links below:
#
# https://www.w3schools.com/python/python_try_except.asp
#
# https://docs.python.org/3/tutorial/errors.html
#
# Some more interestiong materials about using od the construction:
#
# https://www.programiz.com/python-programming/exception-handling
#
# https://towardsdatascience.com/do-not-abuse-try-except-in-python-d9b8ee59e23b
#
# https://www.techbeamers.com/use-try-except-python/

# %% [markdown]
# OK, missing values for model_year, cylinders, odometer, paint_color, is_4wd.

# %% [markdown]
# If we display them as percentage of total data, we can see that the amount of missing values is quite significant:

# %%
data.isna().sum()/len(data)
# Out:
# price           0.000000
# model_year      0.070238
# model           0.000000
# condition       0.000000
# cylinders       0.102086
# fuel            0.000000
# odometer        0.153168
# transmission    0.000000
# type            0.000000
# paint_color     0.179854
# is_4wd          0.503697
# date_posted     0.000000
# days_listed     0.000000
# dtype: float64

# %% [markdown]
# 7% of values appear to be missing in model_year column, 10% in cylinders, 15% in odometer, nearly 18% in paint_color, and 50% in is_4wd. We'll need to deal with those in our next step.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# It is absolutely correct to check the percentage of missing values in your data.
#
# You can do it also using this code:
#
# `pd.DataFrame(round((data.isna().mean()*100),2)).style.background_gradient('coolwarm')`
#
# `data.isna().mean() * 100`
#
# Or like this:
#
# `report = data.isna().sum().to_frame()
# report = report.rename(columns = {0: 'missing_values'})
# report['% of total'] = (report['missing_values'] / data.shape[0]).round(2)
# report.sort_values(by = 'missing_values', ascending = False)`
# </div>

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# Also there is one rather useful library for working with the data - `sidetable`, it offers a great number of effective methods for working with the data, including missing values. More info here:
#
# https://pbpython.com/sidetable.html
#
# https://github.com/chris1610/sidetable
#
# Tip! If you decide to use sidetable library, don't forget to install it in the jupyter notebook, using `!pip install -U sidetable`

# %% [markdown]
# We could also see that some values could be more helpfully presented not as floats or strings, but as datetime values (such as model_year or date_posted, respectively), some not as floats but as integers (such as the number of cylinders): that we can do in our second step as well.
#
# First, let's see what the data itself looks like, and then look at the different categories.

# %%
data.head(20)
# Out:
#     price  model_year                     model  condition  cylinders fuel  \
# 0    9400      2011.0                    bmw x5       good        6.0  gas
# 1   25500         NaN                ford f-150       good        6.0  gas
# 2    5500      2013.0            hyundai sonata   like new        4.0  gas
# 3    1500      2003.0                ford f-150       fair        8.0  gas
# 4   14900      2017.0              chrysler 200  excellent        4.0  gas
# 5   14990      2014.0              chrysler 300  excellent        6.0  gas
# 6   12990      2015.0              toyota camry  excellent        4.0  gas
# 7   15990      2013.0               honda pilot  excellent        6.0  gas
# 8   11500      2012.0               kia sorento  excellent        4.0  gas
# 9    9200      2008.0               honda pilot  excellent        NaN  gas
# 10  19500      2011.0  chevrolet silverado 1500  excellent        8.0  gas
# ...

# %% [markdown]
# We can have a nice glance over all of our quantitative values at once to get a sense of what they are (kudos to my previous reviewer for this tip!):

# %%
data.describe().T
# Out:
#                count           mean           std     min      25%       50%  \
# price        51525.0   12132.464920  10040.803015     1.0   5000.0    9000.0
# model_year   47906.0    2009.750470      6.282065  1908.0   2006.0    2011.0
# cylinders    46265.0       6.125235      1.660360     3.0      4.0       6.0
# odometer     43633.0  115553.461738  65094.611341     0.0  70000.0  113000.0
# is_4wd       25572.0       1.000000      0.000000     1.0      1.0       1.0
# days_listed  51525.0      39.554760     28.204270     0.0     19.0      33.0
#
#                   75%       max
# price         16839.0  375000.0
# model_year     2014.0    2019.0
# cylinders         8.0      12.0
# odometer     155000.0  990000.0
# is_4wd            1.0       1.0
# days_listed      53.0     271.0

# %% [markdown]
# Wow, the oldest car on sale is more than a century old! I couldn't help but check Wikipedia for this..so technically the first automobile was first produced by Carl Benz twenty years prior, but still, 1908 is literally the year when Ford launched its famous mass market line production...could it be one of those?

# %%
data.query('model_year == 1908')
# Out:
#        price  model_year              model  condition  cylinders fuel  \
# 33906  12995      1908.0          gmc yukon       good        8.0  gas
# 33907  12995      1908.0  cadillac escalade  excellent        8.0  gas
#
#        odometer transmission type paint_color  is_4wd date_posted  days_listed
# 33906  169328.0    automatic  SUV       black     NaN  2018-07-06           34
# 33907       NaN    automatic  SUV       white     NaN  2018-06-24           25

# %% [markdown]
# Well this can't be right, that's a little early for Escalades. So this must an error of some kind, we can get back to it, and find others, in our next step.

# %% [markdown]
# Now, looking back at the description of our quants above, we can already flag a couple of things that we might want to keep in mind when we deal with the values in step 3:
#
# 1. Likely outliers in the price and mileage ('odometer') columns, judging by their max values, which are way up above the range for the majority of values in those columns. Also need to look into the min price of 1, or really any price below a certain threshold – likely outliers too.
#
# 2. A similar issue with 'days_listed' – abnormally long publication time at a max of 271 days. On the other side of the same coin – listings with the min amount of zero days.
#
# 3. A similar issue to the last one that we've already noted with the car model years (1908 for Escalade and GMC...).
#
# 4. Perhpas it will make sense to rename some of the columns for our convenience...why not change odometer to simply 'mileage': that's what we want to know and that's what it tells us. And change paint_color to just 'color' – it's enough to tell us it's about the color, right?

# %% [markdown]
# Now let's look at the cateforical values that we have (except for the is_4wd, which was in the quant description table because of its float values):

# %%
data.describe(include = 'object').T
# Out:
#               count unique         top   freq
# model         51525    100  ford f-150   2796
# condition     51525      6   excellent  24773
# fuel          51525      5         gas  47288
# transmission  51525      3   automatic  46902
# type          51525     13         SUV  12405
# paint_color   42258     12       white  10029
# date_posted   51525    354  2019-03-17    186

# %% [markdown]
# Alright, this gives us a sense of how many different types of charasteristics and colors there are. Gas is by far the predominant fuel option on sale. We can see that date_posted is a string and not a datetime...will need to fix that. But it's really more useful to look at each categorical value one by one with value_counts(). Let's go over them in order (from left to right, when reading the data):

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, it is correct to check the statistics for categorical values too.

# %%
data['model'].value_counts()
# Out:
# ford f-150                           2796
# chevrolet silverado 1500             2171
# ram 1500                             1750
# chevrolet silverado                  1271
# jeep wrangler                        1119
#                                      ...
# ford f-250 super duty                 241
# acura tl                              236
# kia sorento                           236
# nissan murano                         235
# mercedes-benz benze sprinter 2500      41
# Name: model, Length: 100, dtype: int64

# %% [markdown]
# There are so many different models that we can't see them in one place. Let's look at unique values:

# %%
data['model'].unique()
# Out:
# array(['bmw x5', 'ford f-150', 'hyundai sonata', 'chrysler 200',
#        'chrysler 300', 'toyota camry', 'honda pilot', 'kia sorento',
#        'chevrolet silverado 1500', 'honda accord', 'ram 1500',
#        'gmc yukon', 'jeep cherokee', 'chevrolet traverse',
#        'hyundai elantra', 'chevrolet tahoe', 'toyota rav4',
#        'chevrolet silverado', 'jeep wrangler', 'chevrolet malibu',
#        'ford fusion se', 'chevrolet impala', 'chevrolet corvette',
#        'jeep liberty', 'toyota camry le', 'nissan altima',
#        'subaru outback', 'toyota highlander', 'dodge charger',
#        'toyota tacoma', 'chevrolet equinox', 'nissan rogue',
#        'mercedes-benz benze sprinter 2500', 'honda cr-v',
#        'jeep grand cherokee', 'toyota 4runner', 'ford focus',
#        'honda civic', 'kia soul', 'chevrolet colorado',
#        'ford f150 supercrew cab xlt', 'chevrolet camaro lt coupe 2d',
#        'chevrolet cruze', 'ford mustang', 'chevrolet silverado 3500hd',
# ...

# %% [markdown]
# It's quite a mouthful, so hard to see straight away if there any hidden duplicates, but at least we can see that all values are lowercase, which helps some way.

# %%
data['condition'].value_counts()
# Out:
# excellent    24773
# good         20145
# like new      4742
# fair          1607
# new            143
# salvage        115
# Name: condition, dtype: int64

# %% [markdown]
# Alright, it would be interesting to get a description of what each of the categories means, but it seems clear that these condition options are provided by our website and picked by the sellers (otherwise there would be more custom entries – anything from 'godlike' to 'better-than-new'). It seems to me like the order of progression (from best to worst) would be:
#
# - `new`
# - `like new`
# - `excellent`
# - `good`
# - `fair`
# - `salvage`
#
# Could be a good idea to replace these with a scale from 5 – 0 down the line.

# %%
data['fuel'].value_counts()
# Out:
# gas         47288
# diesel       3714
# hybrid        409
# other         108
# electric        6
# Name: fuel, dtype: int64

# %% [markdown]
# I'm going to console myself by thinking that all these people are selling their gas powered cars to switch to electric... Seriously though, I see nothing suspect here, the data looks fine. It would be hard to check for any 'hidden' mistakes or miscategorizations of fuel type by, say, model, because (as far as I know) most autos come sold in two or more different modifications – powered by gas, diesel or a hybrid type of some sort.

# %%
data['transmission'].value_counts()
# Out:
# automatic    46902
# manual        2829
# other         1794
# Name: transmission, dtype: int64

# %% [markdown]
# This data looks fine to me too. Most cars nowadays come with automatic transmission type, it's even rare to see manual type in a driving school, so these numbers look reasonable.

# %%
data['type'].value_counts()
# Out:
# SUV            12405
# truck          12353
# sedan          12154
# pickup          6988
# coupe           2303
# wagon           1541
# mini-van        1161
# hatchback       1047
# van              633
# convertible      446
# other            256
# offroad          214
# bus               24
# Name: type, dtype: int64

# %% [markdown]
# I'm not that familiar with car types, so I had to check these out on Google, and the distinctions are legit, there seem to be no hidden dupes here or anything of the kind. Only thorny part is, if we look at, say ford f150 which is the most popular model on sale by our users, we will see this model listed both as a truck and a pickup.

# %%
data.query('model == "ford f-150"')
# Out:
#        price  model_year       model  condition  cylinders fuel  odometer  \
# 1      25500         NaN  ford f-150       good        6.0  gas   88705.0
# 3       1500      2003.0  ford f-150       fair        8.0  gas       NaN
# 39      8000      2009.0  ford f-150       good        8.0  gas  234000.0
# 50      6200      2006.0  ford f-150  excellent        6.0  gas   69698.0
# 65     12800         NaN  ford f-150  excellent        6.0  gas  108500.0
# ...      ...         ...         ...        ...        ...  ...       ...
# 51403  19350      2013.0  ford f-150  excellent        8.0  gas   76474.0
# 51419  19900      2013.0  ford f-150       good        6.0  gas   43855.0
# 51425   8495      2006.0  ford f-150       good        8.0  gas   96926.0
# 51434   3495      2007.0  ford f-150       good        8.0  gas  136782.0
# 51487   1495         NaN  ford f-150       fair        6.0  gas   15804.0
#
#       transmission    type paint_color  is_4wd date_posted  days_listed
# ...

# %% [markdown]
# The distinction here is a bit blurry, but from what I understood, these can be similar or even same-looking models, where one can be used for more work-like purposes, say, on a farm, or to carry a lot of weight, essentially for freighting but on a 'small business' scale, and thus its back part can be expanded (even more). Whereas the pickup doesn't get extra space on top of that original extra space at the back, but is enough to use for personal purposes, if those already involve driving a lot of stuff around, but not too much to be needing a truck. It's confusing, and even checking it on Google doesn't give a conclusive answer. On Ford's website f150 is called both a pickup, a truck, and a'pickup truck' on the same page. But the distinction still seems to be there, according to other websites.
#
# In order not to overthink this one any further, I propose we treat these categories as legitimate. After all, our own website gave the sellers the option to either call their salvage a truck or a pickup, so that must have been for a reason. Still, it's just good to give extra thought to this, because type is one of the most important categories for the final stages of this report. On the whole, this breakdown by types makes sense – less common and more exotic cars are in lower supply (like vans, buses or convertibles), while SUVs, sedans and pickups are more common, and are therefore more commonly sold.

# %%
data['paint_color'].value_counts()
# Out:
# white     10029
# black      7692
# silver     6244
# grey       5037
# blue       4475
# red        4421
# green      1396
# brown      1223
# custom     1153
# yellow      255
# orange      231
# purple      102
# Name: paint_color, dtype: int64

# %% [markdown]
# OK, everything seems fine here, but if one looks carefully, there's a massive error. There is simply no way that purple is the least popular color! On a more serious note, we must remember that there are quite a few missing values in this column:

# %%
data['paint_color'].isna().sum()
# Out:
# 9267

# %%
data['paint_color'].isna().sum() / len(data)
# Out:
# 0.17985443959243086

# %% [markdown]
# Which is nearly a fifth of all its values (could they all be purple? No, then they would still be only the second most popular color, which doesn't make sense). My guess is that these values could easily happen when the sellers just didn't indicate the color in their ads, and that's what we have in the dataset. It could be that color is not an absolute must to put on the ad, especially if the ad comes with a photo of the car for sale. In any case, we'll come back to these missing values in the preprocessing stage.

# %% [markdown]
# Another categorical value that was included in the quants table when we used describe() method earlier, is whether the vehicle is a four-wheel drive type or not ('is_4wd'). For this value, approximately half the values are shown as null, but this must obviously be a Boolean value, with 1.0 standing for yes, and missing value for no:

# %%
data['is_4wd'].unique()
# Out:
# array([ 1., nan])

# %%
data['is_4wd'].value_counts()
# Out:
# 1.0    25572
# Name: is_4wd, dtype: int64

# %%
len(data) - 25572
# Out:
# 25953

# %% [markdown]
# So almost exactly half the vehicles must be front- (or back?) wheel drive only. I guess this must be reasonable. I wonder if it depends on the type of car. It seems like the more powerful or massive cars like SUVs must more often be four-wheel drive, although not necessarily.

# %%
data.loc[data['is_4wd'].notna()]['type'].unique()
# Out:
# array(['SUV', 'pickup', 'sedan', 'truck', 'hatchback', 'wagon', 'other',
#        'offroad', 'convertible', 'mini-van', 'coupe', 'van'], dtype=object)

# %%
data.loc[data['is_4wd'].isna()]['type'].unique()
# Out:
# array(['sedan', 'pickup', 'SUV', 'coupe', 'van', 'truck', 'convertible',
#        'hatchback', 'wagon', 'mini-van', 'other', 'bus', 'offroad'],
#       dtype=object)

# %% [markdown]
# Yeah, OK...maybe not necessarily. Looks like all types of cars can be 4 wheel drive and not.

# %% [markdown]
# Let's move on to the last column in the table:

# %%
data['date_posted'].value_counts()
# Out:
# 2019-03-17    186
# 2019-01-05    184
# 2018-09-20    178
# 2019-03-11    176
# 2018-10-09    174
#              ...
# 2018-06-18    119
# 2018-07-04    118
# 2019-01-11    117
# 2018-06-08    117
# 2019-01-04    116
# Name: date_posted, Length: 354, dtype: int64

# %% [markdown]
# Before we deal with the format of values in date_posted by turning it into datetime format, we can't really learn that much from it by calling value_counts or describe methods on its column. We want to proceed with our tasks in order, so let's leave it here for now.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# When exploring the dataset, we've noted a few things to keep in mind for the next steps. We saw a lot of missing values in columns that are significant to our task, such as color and model_year, which should help us calculate age of the vehicles at the time of ad posting, as well as cylinders and mileage. The most probable cause of the missing values in this case is the seller forgetting or just omitting these details: after all, on a website like ours ticking all of the details is optional – you have to at least mention the model and type, otherwise it won't attract any attention, but the asker can always ask about the rest of the details in private. We will take a closer look at each of them in the next stage and decide whether and how they can be restored.
#
# For other values such as type and is_4wd the distribution of various categories and division into 4wd/non-4wd looks adequate. SUVs and pickups must be much more in use among common drivers than buses or convertibles, so the data makes sense.
#
# Same with the models, although the variety of models produced by the same car manufacturer makes it difficult to have a nice overview of them. Perhaps it would be a good idea to categorize them by manufacturer in the future stages. It's not actually needed for our task, but it'd be nice.
#
# There is also some faulty data. One example are the years of production (model_year) for some of the cars, such as 1908, which turned out to be plain faulty, not an antique Ford as I thought. I will look deeper into this in the following stage (perhaps we can look at unique values for production years by model or smth like that). There is also some tricky data in price, mileage and days_posted: 1, 0, and 0 for min, respectively, and possible outliers on the max side. More cause to investigate: some of those could be missing values, while others – just outliers. Indeed, 0 in mileage should make sense if the car's condition is 'new', but raise questions if it isn't.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, you investigated the data in detail, so, let's move on!🏃‍♂️🏃‍♀️

# %% [markdown]
# ## Data preprocessing

# %% [markdown]
# Let's get the easy stuff out of the way first and rename 'otometer' to 'mileage' and 'paint_color' to 'color'.

# %%
data = data.rename(columns = {'odometer': 'mileage', 'paint_color': 'color'})

# %%
data.head()
# Out:
#    price  model_year           model  condition  cylinders fuel   mileage  \
# 0   9400      2011.0          bmw x5       good        6.0  gas  145000.0
# 1  25500         NaN      ford f-150       good        6.0  gas   88705.0
# 2   5500      2013.0  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500      2003.0      ford f-150       fair        8.0  gas       NaN
# 4  14900      2017.0    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type  color  is_4wd date_posted  days_listed
# 0    automatic     SUV    NaN     1.0  2018-06-23           19
# 1    automatic  pickup  white     1.0  2018-10-19           50
# 2    automatic   sedan    red     NaN  2019-02-07           79
# 3    automatic  pickup    NaN     NaN  2019-03-22            9
# 4    automatic   sedan  black     NaN  2019-04-02           28

# %% [markdown]
# Excellent.

# %% [markdown]
# ### Missing values

# %% [markdown]
# #### Model_year

# %% [markdown]
# Let's move in order and deal with model_year first:

# %%
data['model_year'].isna().sum()
# Out:
# 3619

# %%
(data['model_year'].isna().sum() / len(data)) * 100
# Out:
# 7.023774866569626

# %% [markdown]
# To my mind, there are not many good options to fill in the missing data in model_year. One thing to try is to control for model itself – surely for some models it will be the case that they have a limited range of production years (perhaps because they were released near that year). Another helpful data point in this case would be mileage – how much a car has driven must correlate, although not perfectly, but still – with the car's age. That's assuming the seller is being truthful about it, of course.

# %% [markdown]
# Let's just make sure that the missing model_years are not specific to any one model:

# %%
data.loc[data['model_year'].isna()]['model'].unique()
# Out:
# array(['ford f-150', 'chevrolet tahoe', 'subaru impreza',
#        'hyundai elantra', 'chevrolet colorado',
#        'nissan frontier crew cab sv', 'chevrolet camaro lt coupe 2d',
#        'chevrolet silverado 1500', 'toyota camry', 'ford f350 super duty',
#        'honda cr-v', 'honda accord', 'nissan rogue', 'ford escape',
#        'toyota 4runner', 'ford fusion', 'kia soul', 'nissan maxima',
#        'chevrolet camaro', 'ram 2500', 'toyota corolla', 'ford focus se',
#        'chevrolet corvette', 'ford f-250 sd', 'toyota prius',
#        'gmc sierra', 'toyota rav4', 'chevrolet impala',
#        'volkswagen jetta', 'toyota highlander', 'ford f350',
#        'honda civic', 'dodge grand caravan', 'chevrolet silverado 2500hd',
#        'jeep cherokee', 'gmc sierra 1500', 'ford focus', 'toyota tundra',
#        'ford explorer', 'bmw x5', 'ford mustang', 'jeep wrangler',
#        'gmc sierra 2500hd', 'ford taurus', 'chevrolet equinox',
# ...

# %% [markdown]
# OK it's not. For what we know, all the models, or almost all of them, have missing values in model_years among them.

# %% [markdown]
# Let's see what the range of production years looks like for the most popular car model on sale:

# %%
data.loc[data['model'] == 'ford f-150']['model_year'].value_counts().sort_index(ascending = False)
# Out:
# 2019.0     10
# 2018.0    122
# 2017.0     82
# 2016.0    160
# 2015.0    150
# 2014.0    222
# 2013.0    252
# 2012.0    144
# 2011.0    222
# 2010.0    202
# 2009.0     73
# 2008.0    107
# 2007.0    116
# 2006.0    122
# 2005.0    117
# 2004.0     86
# 2003.0     70
# 2002.0     58
# 2001.0     44
# 2000.0     44
# 1999.0     36
# 1998.0     43
# 1997.0     29
# 1996.0     14
# 1995.0     18
# 1994.0     13
# 1993.0     11
# 1992.0      5
# 1991.0      4
# 1990.0      2
# 1989.0      5
# 1988.0      4
# 1987.0      4
# 1986.0      4
# 1979.0      5
# 1977.0      1
# 1975.0      1
# 1954.0      1
# 1936.0      1
# 1929.0      1
# Name: model_year, dtype: int64

# %% [markdown]
# OK, so that looks bad at first – the age span of just one specific model is, uhh, almost a century. But still, we can see that the majority of them were produced after 2000, so that's something at least.

# %%
data.loc[data['model'] == 'ford f-150']['model_year'].median()
# Out:
# 2011.0

# %% [markdown]
# But what's up with those ancient ones, again?

# %%
data.query('model == "ford f-150" and model_year < 1979')
# Out:
#        price  model_year       model  condition  cylinders fuel  mileage  \
# 1101    9200      1975.0  ford f-150  excellent        NaN  gas      NaN
# 8648   12000      1977.0  ford f-150       fair        8.0  gas      NaN
# 14752  15000      1954.0  ford f-150  excellent        NaN  gas   3565.0
# 34713   5000      1936.0  ford f-150  excellent        6.0  gas  30000.0
# 45694  18000      1929.0  ford f-150       good        8.0  gas      NaN
#
#       transmission    type   color  is_4wd date_posted  days_listed
# 1101     automatic   truck   green     NaN  2018-08-28           40
# 8648     automatic   truck   brown     NaN  2018-11-07           32
# 14752       manual  pickup   black     NaN  2019-02-16           13
# 34713       manual  pickup  purple     NaN  2018-11-22           10
# 45694       manual   other  silver     NaN  2018-11-18           59

# %% [markdown]
# OK so according to Wiki, Ford F-series appeared in 1948, so that 1954 specimen could actually be legit, even though its mileage record looks suspicious. But those 1936 and 1929 models are definitely off (although the color choices of that 1936 ford's owner are commendable).

# %% [markdown]
# Anyway, we need to fill in missing values for model_year, so let's forget about those artefacts for now. Based on the example of ford f-150, it seems like we should indeed check for model when filling them in.

# %% [markdown]
# Let's just double-check if mileage actually correlates with model_year:

# %%
data['mileage'].corr(data['model_year'])
# Out:
# -0.4739478581952939

# %% [markdown]
# Alright! There is a negative correlation, halfway towards -1, which, although not strong, is significant enough to take into account. It makes sense: as the model_year decreases, the mileage should increase, and the other way around: the less the mileage, the higher the model_year (the more recently the car has started hitting the road).

# %% [markdown]
# Before filling in the missing values, let us look at the distribution of model_year values in our data. We'll need to make another graph after we fill in the missing values and compare, to see how it affected the distribution.

# %%
data.hist('model_year', bins = 120, figsize = (12, 8))
plt.title("Distribution of model_year")
plt.xlabel('model_year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# To get more visual value out of it, let us just start at, say 1970

# %%
data.hist('model_year', bins = 50, range = (1970, 2020), figsize = (12, 8))
plt.title("Distribution of model_year")
plt.xlabel('model_year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Alright, this makes sense. We can see the largest number of vehicles (the peak) having been produced in 2013 or 2014. We can also see a fall in 2009...the big financial crisis is to blame? Could be. It also tells us smth about the average time owners will hold on to the car...although wait, it doesn't, since we don't have the data for when the car came into possession of the seller. But we can use the data to calculate the age of the car before it was put on sale. We'll do that later.

# %% [markdown]
# Let us create a new column with model_year missing values filled in. I will use the group and transform method to control for the model_year values depending on model and mileage, and I will use median values in both cases, to avoid any distortions.

# %%
data['full_model_year'] = data['model_year'].fillna(data.groupby(['model', 'mileage'])['model_year'].transform('median'))

# %%
data['full_model_year'].isna().sum()
# Out:
# 2080

# %% [markdown]
# Alright. Down by less than half. When controlling for several variables at once, it must have limited the range of options to base the median value on. After all, remember that we are missing somewhere between 15% and 20% of values in mileage, whereas we don't have any missing values in models. Not much choice, so let's just fill in the remaining missing values based on model alone.

# %%
data['full_model_year'] = data['full_model_year'].fillna(data.groupby('model')['model_year'].transform('median'))

# %%
data['full_model_year'].isna().sum()
# Out:
# 0

# %% [markdown]
# Now let's call up the histograms again to compare the results.

# %%
data['full_model_year'].hist(bins = 50, range = (1970, 2020), figsize = (12, 8), alpha = 0.5)
data['model_year'].hist(bins = 50, range = (1970, 2020), figsize = (12, 8), alpha = 1)
plt.title("Distribution of model_year")
plt.xlabel('model_year')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Alright, so we see that it pulled up the amount of cars produced mostly in the years 2008-2014 by a bit, however the overall distribution pattern remained similar to what it looked like without the missing values filled in (orange color). So seems safe to say, let's fill them in!

# %%
data['model_year'] = data['model_year'].fillna(data.groupby(['model', 'mileage'])['model_year'].transform('median'))

# %%
data['model_year'] = data['model_year'].fillna(data.groupby('model')['model_year'].transform('median'))

# %%
data['model_year'].isna().sum()
# Out:
# 0

# %% [markdown]
# Nice.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   price            51525 non-null  int64
#  1   model_year       51525 non-null  float64
#  2   model            51525 non-null  object
#  3   condition        51525 non-null  object
#  4   cylinders        46265 non-null  float64
#  5   fuel             51525 non-null  object
#  6   mileage          43633 non-null  float64
#  7   transmission     51525 non-null  object
#  8   type             51525 non-null  object
#  9   color            42258 non-null  object
#  10  is_4wd           25572 non-null  float64
#  11  date_posted      51525 non-null  object
#  12  days_listed      51525 non-null  int64
#  13  full_model_year  51525 non-null  float64
# dtypes: float64(5), int64(2), object(7)
# memory usage: 5.5+ MB

# %% [markdown]
# And we might as well get rid of that auxilliary full_model_year column now:

# %%
data.drop(columns = 'full_model_year', inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     46265 non-null  float64
#  5   fuel          51525 non-null  object
#  6   mileage       43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   color         42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# #### Cylinders

# %%
(data['cylinders'].isna().sum() / len(data)) * 100
# Out:
# 10.208636584182436

# %% [markdown]
# 10% is even higher than 7 as in the case with model_year, and even though model_year is more important for our report (because it will help us calculate ages in the next stage), I bet the amount of cylinders is quite an important factor for price.

# %%
data['cylinders'].corr(data['price'])
# Out:
# 0.2966269270037435

# %% [markdown]
# Well, it's not zero, anyway. Engine is what makes the car run, and cylinders are basically what makes the engine run. And it stands to reason that more powerful engine, being the key part of the car, will pull the price up.

# %% [markdown]
# Let's see how many different numbers of cylinders there are:

# %%
data['cylinders'].value_counts()
# Out:
# 8.0     15844
# 6.0     15700
# 4.0     13864
# 10.0      549
# 5.0       272
# 3.0        34
# 12.0        2
# Name: cylinders, dtype: int64

# %% [markdown]
# I wonder what those 12-cylinder bad boys are:

# %%
data.loc[data['cylinders'] == 12]
# Out:
#        price  model_year                 model  condition  cylinders    fuel  \
# 12615  18000      2001.0              ram 2500  excellent       12.0  diesel
# 44117  20000      2004.0  ford f350 super duty  excellent       12.0  diesel
#
#         mileage transmission   type   color  is_4wd date_posted  days_listed
# 12615  167500.0       manual  truck  silver     1.0  2018-08-05           22
# 44117       NaN    automatic  truck    grey     1.0  2019-03-29           24

# %% [markdown]
# Surprising to see 12 cylinders and diesel for fuel type, but then I really have little idea of how cars work.

# %% [markdown]
# We do see that those 12 cylinders came for powerful trucks, and if you google ram2500 or ford f350 super duty, they look exactly how you'd imagine.

# %% [markdown]
# Commons sense tells us that type, or better still, model, would probably predict the number of cylinders better than any other data. So let's make a histogram of our column of cylinders as it stands now to have it in front of us, then fill in the values based on model, and then compare.

# %%
data.hist('cylinders', bins = 9, range = (3, 12), figsize = (10, 6))
plt.title("Distribution of cylinders")
plt.xlabel('Number of cylinders')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# So I encountered a new problem with this one. The thing is, median, when stuck between two values in an even-numbered array, will resort to mean of the two central values. And that may give us a bunch of 'median' values in place of the missing ones, which normally couldn't occur by design of that column's values. In this case, we would get values like 4.5 or 7 or 9 cylinders, which weren't in the column before (probably because engines with 4.5/7/9 cylinders do not exist!).
#
# I decided to combine the median and mode functions to get the values that we need. Going through the rows with a loop and checking if the resulting median value strays from the list of unique values in the column will allow us to rely on mode() in that case, which will simply select the most popular value in the group (our next best option where median doesn't work).
#
# I'm filling in the values in a new column based on 'cylinders', just so we can compare them on a single histogram against each other after we have the results.

# %%
models = data['model'].unique()
cylinders = data['cylinders'].unique()
data['newC'] = data['cylinders']

for model in models:
    median_c = data.loc[data['model'] == model]['cylinders'].median()
    if median_c in cylinders:
        data.loc[data['model'] == model, 'newC'] = data['newC'].fillna(median_c)
    else:
        mode_c = data.loc[data['model'] == model]['cylinders'].mode()
        data.loc[data['model'] == model, 'newC'] = data['newC'].fillna(mode_c)

# %%
data['newC'].value_counts()
# Out:
# 8.0     17712
# 6.0     17435
# 4.0     15499
# 10.0      549
# 5.0       294
# 3.0        34
# 12.0        2
# Name: newC, dtype: int64

# %%
data['newC'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Now let's plot 'em

# %%
data['newC'].hist(bins = 9, range = (3, 12), figsize = (10, 6), alpha = 0.5)
data['cylinders'].hist(bins = 9, range = (3, 12), figsize = (10, 6), alpha = 1)

plt.title('Distribution of cylinders (overlay)')
plt.xlabel('Number of cylinders')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Looks good. The resulting distribution is line with the original data, so it seems like it worked well, and we don't have any outlandish values like 4.5 cylinders. We can now fill in the original column using the same method and get rid of the extra column.

# %%
models = data['model'].unique()
cylinders = data['cylinders'].unique()

for model in models:
    median_c = data.loc[data['model'] == model]['cylinders'].median()
    if median_c in cylinders:
        data.loc[data['model'] == model, 'cylinders'] = data['cylinders'].fillna(median_c)
    else:
        mode_c = data.loc[data['model'] == model]['cylinders'].mode()
        data.loc[data['model'] == model, 'cylinders'] = data['cylinders'].fillna(mode_c)

# %%
data['cylinders'].value_counts()
# Out:
# 8.0     17712
# 6.0     17435
# 4.0     15499
# 10.0      549
# 5.0       294
# 3.0        34
# 12.0        2
# Name: cylinders, dtype: int64

# %% [markdown]
# All good!

# %%
data.drop(columns = 'newC', inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  float64
#  5   fuel          51525 non-null  object
#  6   mileage       43633 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   color         42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# Lost...like tears in rain... Next up is mileage

# %% [markdown]
# #### Mileage

# %% [markdown]
# My guess is that it is best to fill missing values in mileage, when grouped by model_year and price. Let's see if there is any kind of correlation betweeen them.

# %%
data['price'].corr(data['mileage'])
# Out:
# -0.4202989623372094

# %%
data['model_year'].corr(data['mileage'])
# Out:
# -0.46830256532313586

# %% [markdown]
# Alright, let's do it using a new column so we can check our results against the original data. Let us take a look at the current stats of mileage to see if we should use median or mean:

# %%
data['mileage'].describe()
# Out:
# count     43633.000000
# mean     115553.461738
# std       65094.611341
# min           0.000000
# 25%       70000.000000
# 50%      113000.000000
# 75%      155000.000000
# max      990000.000000
# Name: mileage, dtype: float64

# %% [markdown]
# They're pretty close, but let's go with median to be sure.

# %%
data['new_mileage'] = data['mileage'].fillna(data.groupby(['model_year', 'price'])['mileage'].transform('median'))

# %%
data['new_mileage'].isnull().sum()
# Out:
# 1051

# %% [markdown]
# This is good! Down from 7 thousand or so missing values. It's the same problem we had when filling in model_years - too little data. So to finish it we need to loosen up our filters, say, by losing price.

# %%
data['new_mileage'] = data['new_mileage'].fillna(data.groupby('model_year')['mileage'].transform('median'))

# %%
data['new_mileage'].isnull().sum()
# Out:
# 1

# %% [markdown]
# Seriously?

# %%
data.loc[data['new_mileage'].isnull()]
# Out:
#        price  model_year       model condition  cylinders fuel  mileage  \
# 45694  18000      1929.0  ford f-150      good        8.0  gas      NaN
#
#       transmission   type   color  is_4wd date_posted  days_listed  \
# 45694       manual  other  silver     NaN  2018-11-18           59
#
#        new_mileage
# 45694          NaN

# %% [markdown]
# Fair enough, I can see why it's hard to gauge mileage for that one.

# %% [markdown]
# We know from previous explorations that ford f-150 launched in 1948, so the only way these wacky model_year values could creep in is probably by mistake of the seller mistyping the third digit. We could treat them as outliers, but it seems fair to just treat them as missing values (even though it would be hard to scale this approach if we had such values for a lot of different models, because we'd have to do similar research on each of them). So let's do it for this model for practice' sake, and replace its model_year with a median value for the model. Then we can repeat our last code to fill in the missing mileage.

# %%
data.loc[(data['model'] == 'ford f-150') & (data['model_year'] < 1948), 'model_year'] = data.loc[(data['model'] == 'ford f-150') & (data['model_year'] < 2000)]['model_year'].median()

# %%
data.loc[data['new_mileage'].isnull()]
# Out:
#        price  model_year       model condition  cylinders fuel  mileage  \
# 45694  18000      1997.0  ford f-150      good        8.0  gas      NaN
#
#       transmission   type   color  is_4wd date_posted  days_listed  \
# 45694       manual  other  silver     NaN  2018-11-18           59
#
#        new_mileage
# 45694          NaN

# %% [markdown]
# That should do!

# %%
data['new_mileage'] = data['new_mileage'].fillna(data.groupby('model_year')['mileage'].transform('median'))

# %%
data['new_mileage'].isnull().sum()
# Out:
# 0

# %% [markdown]
# Phew. On to the plots so we can check the distribution.

# %%
data['new_mileage'].hist(bins = 100, figsize = (12, 8), alpha = 0.5)
data['mileage'].hist(bins = 100, figsize = (12, 8), alpha = 1)

plt.title('Distribution of mileage values')
plt.xlabel('Mileage')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# It seems to have worked well: mileage with restored values repeats the original pattern of distribution. We can also check the main stats:

# %%
data['new_mileage'].describe()
# Out:
# count     51525.000000
# mean     115486.831887
# std       62992.962176
# min           0.000000
# 25%       72000.000000
# 50%      113893.000000
# 75%      154000.000000
# max      990000.000000
# Name: new_mileage, dtype: float64

# %%
data['mileage'].describe()
# Out:
# count     43633.000000
# mean     115553.461738
# std       65094.611341
# min           0.000000
# 25%       70000.000000
# 50%      113000.000000
# 75%      155000.000000
# max      990000.000000
# Name: mileage, dtype: float64

# %% [markdown]
# I guess it's OK, considering we restored over 15% of missing values!

# %% [markdown]
# That peak near 0 on the graph looks confusing though. Let's enlarge that.

# %%
x = 1000000
for i in range(5):
    data.hist('new_mileage', bins = 100, range = (0, x), figsize = (12, 8), alpha = 0.5)
    plt.title('Distribution of miles')
    plt.xlabel('Miles')
    plt.ylabel('Count')
    plt.show()
    x /= 10

# %% [markdown]
# OK so we see at least that it's not over a thousand of 0 values (which could potentially be 'hidden' missing values), but just under 200. Could they all be brand new cars?

# %%
data.loc[data['mileage'] == 0]['condition'].value_counts()
# Out:
# good         104
# excellent     69
# fair           6
# like new       4
# salvage        2
# Name: condition, dtype: int64

# %% [markdown]
# Hmm, nope. And we can see that mileage as a rule follows condition:

# %%
mil_pivot = data.pivot_table(index = 'condition', values = 'new_mileage', aggfunc = 'median')

# %%
mil_pivot
# Out:
#            new_mileage
# condition
# excellent     105251.0
# fair          177000.0
# good          129026.0
# like new       74500.0
# new            10500.0
# salvage       148000.0

# %% [markdown]
# Still, since these weren't marked as nan with the rest of the missing values, I think it's reasonable not to treat them as such, but rather as artefacts. Sure enough, it's a bit weird that even some 'salvage'-ranked cars would have 0 mileage, but then, for a small subset of under 200 cars, it could well happen for some strange reason – say, they were parked the entire time and used for storage. Or they were just readings from the odometer (what the column was originally called), which could have been reset at some point for whatever reason. In any case, we can always, and will probably have to, treat them as outliers when it comes to mileage.

# %% [markdown]
# Now let's just repeat the same for the original column and delete the auxilliary one.

# %%
data['mileage'] = data['mileage'].fillna(data.groupby(['model_year', 'price'])['mileage'].transform('median'))

# %%
data['mileage'].isnull().sum()
# Out:
# 1050

# %%
# same as before
data['mileage'] = data['mileage'].fillna(data.groupby('model_year')['mileage'].transform('median'))

# %%
data['mileage'].isnull().sum()
# Out:
# 0

# %% [markdown]
# All good!

# %%
data.drop(columns = 'new_mileage', inplace = True)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 13 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   price         51525 non-null  int64
#  1   model_year    51525 non-null  float64
#  2   model         51525 non-null  object
#  3   condition     51525 non-null  object
#  4   cylinders     51525 non-null  float64
#  5   fuel          51525 non-null  object
#  6   mileage       51525 non-null  float64
#  7   transmission  51525 non-null  object
#  8   type          51525 non-null  object
#  9   color         42258 non-null  object
#  10  is_4wd        25572 non-null  float64
#  11  date_posted   51525 non-null  object
#  12  days_listed   51525 non-null  int64
# dtypes: float64(4), int64(2), object(7)
# memory usage: 5.1+ MB

# %% [markdown]
# Done!

# %% [markdown]
# Actually, almost done! There is still a gaping 17% chunk of all values missing in the color column:

# %%
data['color'].isna().sum() / len(data)
# Out:
# 0.17985443959243086

# %% [markdown]
# Thinking about it, it seems to me like in this case the most reasonable option would be to just leave them missing – in a way, by changing the technical missing values ('nan'-s) to 'undefined' or 'unknown'. There are two reasons, why filling them in wouldn't make sense:
#
# 1. Color is likely the most random value in the dataset, so that filling it based on the most frequent color choices for similar models or types or year of production would be even more of a liberty / more guesswork, than usual.
# 2. Even if it were a case that certain colors are more frequent for a certain year of production and model, for instance, we have way too many missing values in the first place, and would probably end up filling in remaining missing values by most frequent value per one column such as type, which – again – probably would fail to follow the exisitng distribution.
#
# Either way, the result of trying to fill them in would skew the exisitng distribution too much, and we better keep it as it is. Well, let's just change it to 'unknown'.

# %%
data['color'] = data['color'].fillna('unknown')

# %%
data['color'].value_counts()
# Out:
# white      10029
# unknown     9267
# black       7692
# silver      6244
# grey        5037
# blue        4475
# red         4421
# green       1396
# brown       1223
# custom      1153
# yellow       255
# orange       231
# purple       102
# Name: color, dtype: int64

# %% [markdown]
# #### Days listed

# %% [markdown]
# Recall from the initital look at the data that we also had some zeros in 'days_listed', a column that will be crucial at the EDA stage.

# %%
data['days_listed'].describe()
# Out:
# count    51525.00000
# mean        39.55476
# std         28.20427
# min          0.00000
# 25%         19.00000
# 50%         33.00000
# 75%         53.00000
# max        271.00000
# Name: days_listed, dtype: float64

# %%
len(data.query('days_listed == 0'))
# Out:
# 54

# %%
data.query('days_listed == 0')
# Out:
#        price  model_year                          model  condition  cylinders  \
# 1247   14995      2008.0       chevrolet silverado 1500  excellent        8.0
# 1711   59589      2019.0     chevrolet silverado 2500hd  excellent        8.0
# 1983   14000      1999.0                      ford f250  excellent        8.0
# 2883    4000      2004.0                       ram 1500  excellent        8.0
# 3965   16750      1985.0             chevrolet corvette   like new        8.0
# 4567    5000      2007.0                 toyota corolla       good        4.0
# 4901   12500      2001.0                       ram 1500       good        8.0
# 6114     500      2003.0                   dodge dakota       fair        6.0
# 6548    4800      2007.0                  honda odyssey       good        6.0
# 7036    5900      2007.0     jeep grand cherokee laredo  excellent        6.0
# 9607    4999      2012.0                  nissan sentra  excellent        4.0
# ...

# %% [markdown]
# Judging by the very small number of zero days_listed values, and seeing nothing suspicious in these rows themselves (spread across different models/age/type and other values), I am inclined to not treat them as missing values. It's a very tiny subset to our dataset, and there would be no problem in dropping them, but then it could be possible that these 54 just happened to be the luckiest deals that found a buyer in less than 24 hours, thus clocking under 1 day listed as per our data recording system. In any case, it won't hurt to just keep these values as they are – for now.

# %% [markdown]
# Looks like we're done will all the missing values and can move on to changing the data types.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, Roman, you preprocessed the missing values in your data,  as a whole, I can agree with your startegy of dealing with missing values. a big plus for using `groupby()` approach ans as a whole so comprehensive and detailed view.
#
# I also have some thoughts about missing values preprocessing in case of columns odometer, cylinders, model_year, and price columns.
#
#
# Columns you have tried to preprocess have numeric data, so we can study their correlation with the categorical variables from the dataset.
#
# It would be reasonable to assume that the mileage and price correlate with the condition of the vehicle, and the number of cylinders and year with its model. And we can replace missing values with the medians, grouping the data by these parameters.
#
# As I can see, you tried to apply the grouping method here, ok, it works, but I have some doubts about categorization of the `model_year` because any categorization can lead to simplification of the data. As a whole, here you can use the initial `model_year` column and there is no need to categorize it additionally.
#
# See the examples:
#
# `grouped_by_condition = data.groupby('condition').agg({'odometer': 'median', 'price': 'median'})`
#
# `grouped_by_model = data.groupby('model').agg({'model_year': 'median', 'cylinders': 'median'})`
#
# And then you can use values in these resulted dfs to fill in missing values (using for loop + loc. method for example, you tried to do smth like this - it's ok!)
#
# Also you can use the combination of `groupby` + transform to fill in missing values by grouping (also you tried to use this appoach)
#
# One more way is to build the correlation matrix, check what factors are correlated and fill in the missing values based on correlation and grouping methods.
#
# Filling in missing values with simply a median or mean by a column is a rather risky strategy and is only acceptable for cases where no more than 10% of the data is missing in our dataframe. The risk is that such an approach can lead to distortion of the initial data and, as a result, we will get a biased estimate based on the analysis results.
#
# Remember, that it is important not only to fill in the missing values using some method, but also to give arguments why this particular method in this particular case is adequate and correct. And it is better to connect the strategy you choose for filling in missing values with the hypotheses about why there are missing values in the data, why they occur.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review<a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# The example of how to implement this logic:
#
# `grouped_by_condition = data.groupby('condition').agg({'odometer': 'median', 'price': 'median'})
# for cond in data['condition'].unique():
#     data.loc[(data['condition'] == cond) & (data['odometer'].isna()), 'odometer'] = \
#         grouped_by_condition.loc[grouped_by_condition.index == cond, 'odometer'][0]
#     data.loc[(data['condition'] == cond) & (data['price'].isna()), 'price'] = \
#         grouped_by_condition.loc[grouped_by_condition.index == cond, 'price'][0]`
#
# The same is true for grouped_by_model

# %% [markdown]
# ### Changing data types

# %% [markdown]
# We need to change data types in the following columns:
#
# - `model_year`: there is arguably no sense in having years as floats in the first place, but we should convert them to datetime values, and extract years from them, so that later on we can calculate vehicles' age at the time of ad placement but subtracting these years from values in date_posted
#
# - `condition`: as per our task description, it'll make our analysis down the road easier if we change the string description to a numerical (but categorical in the sense that it's a value to choose from) scale of 5 to 0, respectively with 'new' to 'salvage'
#
# - `cylinders`: it doesn't really make any sense to have these values as floats, since we only have whole numbers for the amount of cylinders – so we can convert them to integers
#
# - `mileage`: here we too don't really need that precision to meters or just extra zero digits after the dot for whole numbers, so we can convert these to integers
#
# - `is_4wd`: this column evidently must contain the boolean values for whether the car is a 4wd or not, so the half of it that's denoted as missing values (nan) is probably an accidental by-product opposed to the other half of values noted as 1 for 'True'. We can change all values to bools and present them as ints so that they will be 1's and 0's
#
# - `date_posted`: this, as with model_year, needs to be changed into datetime so we can make calculations off of it
#
# - that's it! Let's move in that order.

# %% [markdown]
# Let's have a look at date_posted again to make sure we impute the same format to the model_year when converting it to date_time:

# %%
data['date_posted'].describe()
# Out:
# count          51525
# unique           354
# top       2019-03-17
# freq             186
# Name: date_posted, dtype: object

# %% [markdown]
# OK, so we see that it's %Y-%m-%d

# %%
data['model_year'] = pd.to_datetime(data['model_year'], format = '%Y')

# %%
data['model_year'] = pd.to_datetime(data['model_year'], format = '%Y-%m-%d')

# %%
data.head()
# Out:
#    price model_year           model  condition  cylinders fuel   mileage  \
# 0   9400 2011-01-01          bmw x5       good        6.0  gas  145000.0
# 1  25500 2014-01-01      ford f-150       good        6.0  gas   88705.0
# 2   5500 2013-01-01  hyundai sonata   like new        4.0  gas  110000.0
# 3   1500 2003-01-01      ford f-150       fair        8.0  gas  160000.0
# 4  14900 2017-01-01    chrysler 200  excellent        4.0  gas   80903.0
#
#   transmission    type    color  is_4wd date_posted  days_listed
# 0    automatic     SUV  unknown     1.0  2018-06-23           19
# 1    automatic  pickup    white     1.0  2018-10-19           50
# 2    automatic   sedan      red     NaN  2019-02-07           79
# 3    automatic  pickup  unknown     NaN  2019-03-22            9
# 4    automatic   sedan    black     NaN  2019-04-02           28

# %% [markdown]
# Nice! On to turning the condition column into a numbered scale. We can just categorize it really, and keep the old column for reference.

# %%
def make_condition_scale(condition):
    if condition == 'new':
        return 5
    elif condition == 'like new':
        return 4
    elif condition == 'excellent':
        return 3
    elif condition == 'good':
        return 2
    elif condition == 'fair':
        return 1
    elif condition == 'salvage':
        return 0
    
data['condition_scale'] = data['condition'].apply(make_condition_scale)

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary: second iteration of the review<a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# Ok, the function looks great,  you can also use `replace()` method to categorize the data:
#
# `df['condition'] = df['condition'].replace(['salvage', 'fair', 'good', 'excellent', 'like new', 'new'], [0, 1, 2, 3, 4, 5])`

# %%
data.head(20)
# Out:
#     price model_year                     model  condition  cylinders fuel  \
# 0    9400 2011-01-01                    bmw x5       good        6.0  gas
# 1   25500 2014-01-01                ford f-150       good        6.0  gas
# 2    5500 2013-01-01            hyundai sonata   like new        4.0  gas
# 3    1500 2003-01-01                ford f-150       fair        8.0  gas
# 4   14900 2017-01-01              chrysler 200  excellent        4.0  gas
# 5   14990 2014-01-01              chrysler 300  excellent        6.0  gas
# 6   12990 2015-01-01              toyota camry  excellent        4.0  gas
# 7   15990 2013-01-01               honda pilot  excellent        6.0  gas
# 8   11500 2012-01-01               kia sorento  excellent        4.0  gas
# 9    9200 2008-01-01               honda pilot  excellent        6.0  gas
# 10  19500 2011-01-01  chevrolet silverado 1500  excellent        8.0  gas
# 11   8990 2012-01-01              honda accord  excellent        4.0  gas
# ...

# %% [markdown]
# Alright! Let's check them out while we are here:

# %%
data['condition_scale'].value_counts().sort_values().plot(kind = 'barh')
plt.title('Amount of cars by condition (expressed in scale)')
plt.xlabel('Count')
plt.ylabel('Condition_scale')
plt.show()

# %% [markdown]
# Good to know most of the cars come in excellent and good condition. On to cylinders.

# %%
data['cylinders'] = data['cylinders'].astype(int)

# %%
data['cylinders'].value_counts()
# Out:
# 8     17712
# 6     17435
# 4     15499
# 10      549
# 5       294
# 3        34
# 12        2
# Name: cylinders, dtype: int64

# %% [markdown]
# It was just inting to be int (sorry). Now let's do the same for mileage

# %%
data['mileage'].describe()
# Out:
# count     51525.000000
# mean     115493.896866
# std       62991.430962
# min           0.000000
# 25%       72000.000000
# 50%      113893.000000
# 75%      154000.000000
# max      990000.000000
# Name: mileage, dtype: float64

# %%
data['mileage'] = data['mileage'].astype(int)

# %%
data['mileage'].describe()
# Out:
# count     51525.000000
# mean     115493.888307
# std       62991.432051
# min           0.000000
# 25%       72000.000000
# 50%      113893.000000
# 75%      154000.000000
# max      990000.000000
# Name: mileage, dtype: float64

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   price            51525 non-null  int64
#  1   model_year       51525 non-null  datetime64[ns]
#  2   model            51525 non-null  object
#  3   condition        51525 non-null  object
#  4   cylinders        51525 non-null  int64
#  5   fuel             51525 non-null  object
#  6   mileage          51525 non-null  int64
#  7   transmission     51525 non-null  object
#  8   type             51525 non-null  object
#  9   color            51525 non-null  object
#  10  is_4wd           25572 non-null  float64
#  11  date_posted      51525 non-null  object
#  12  days_listed      51525 non-null  int64
#  13  condition_scale  51525 non-null  int64
# dtypes: datetime64[ns](1), float64(1), int64(5), object(7)
# memory usage: 5.5+ MB

# %% [markdown]
# Sweet. Next up is is_4wd

# %%
data['is_4wd'].isna().sum()
# Out:
# 25953

# %% [markdown]
# Knowing the above, we can simply fill in those missing values with zeros. And then convert the column to ints.

# %%
data['is_4wd'] = data['is_4wd'].fillna(0)

# %%
data['is_4wd'].isna().sum()
# Out:
# 0

# %%
data['is_4wd'].value_counts()
# Out:
# 0.0    25953
# 1.0    25572
# Name: is_4wd, dtype: int64

# %%
data['is_4wd'] = data['is_4wd'].astype(int)

# %%
data['is_4wd'].value_counts()
# Out:
# 0    25953
# 1    25572
# Name: is_4wd, dtype: int64

# %% [markdown]
# Done! Moving on to date_posted, which needs to be converted to datetime values.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary: second iteration of the review <a class="tocSkip"></h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# It is better to convert the `is_4wd` to bool type, because there are only two values in this column: 1 (True) 0 (False)

# %%
data['date_posted'] = pd.to_datetime(data['date_posted'], format = '%Y-%m-%d')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 14 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   price            51525 non-null  int64
#  1   model_year       51525 non-null  datetime64[ns]
#  2   model            51525 non-null  object
#  3   condition        51525 non-null  object
#  4   cylinders        51525 non-null  int64
#  5   fuel             51525 non-null  object
#  6   mileage          51525 non-null  int64
#  7   transmission     51525 non-null  object
#  8   type             51525 non-null  object
#  9   color            51525 non-null  object
#  10  is_4wd           51525 non-null  int64
#  11  date_posted      51525 non-null  datetime64[ns]
#  12  days_listed      51525 non-null  int64
#  13  condition_scale  51525 non-null  int64
# dtypes: datetime64[ns](2), int64(6), object(6)
# memory usage: 5.5+ MB

# %%
data['date_posted'].describe()
# Out:
# /var/folders/1g/s3zdmnjx7gsfvmjbw229rc7w0000gn/T/ipykernel_22638/3298022752.py:1: FutureWarning: Treating datetime data as categorical rather than numeric in `.describe` is deprecated and will be removed in a future version of pandas. Specify `datetime_is_numeric=True` to silence this warning and adopt the future behavior now.
#   data['date_posted'].describe()
# count                   51525
# unique                    354
# top       2019-03-17 00:00:00
# freq                      186
# first     2018-05-01 00:00:00
# last      2019-04-19 00:00:00
# Name: date_posted, dtype: object

# %% [markdown]
# Now we can check out the distribution for these:

# %%
data['date_posted'].hist(bins = 25, figsize = (12, 8))
plt.title('Distribution by date_posted')
plt.xlabel('Date')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Interesting! This doesn't really tell us all that much. Well, possibly, with Christmas coming up, people get their mind on the decision to sell off a major item like a car, who knows. Other than that, the distribution looks pretty even throughout.

# %% [markdown]
# ### Conclusion

# %% [markdown]
# We started out with a dataset that had about 15% values missing in mileage and 7% in model_year, which are significant numbers, and important data points for later analysis. Besides that there were also missing values in cylinders and color. We managed to restore missing values for mileage and model_year in line with the median values for the respective models and prices, where appropriate. This will help make sure that we have enough data to go by when we get to analysing prices by types or some other categorical breakdown, so this is good – we want to be sure we're not missing out on important data.
#
# Using histograms to visualise data and compare the results of data manipulation at preprocessing stage proved to be useful: when restoring values in so many rows, just looking at the graphs helped ensure that the resulting distribution is in line with what was observed in the beginning. If our 'model' for restoring the values was off, this would have been spotted instantly on the graph.
#
# By performing more 'routine' operations like changing data types where appropriate we also make sure that the data is completely ready for further calculations, additions and analysis, that will follow in the next steps. It's useful not to have to think about it, and actually feels like a large part of the work is already complete. What helps even more is the deeper familiarity with the data that is acquired at this stage, even simply as observations: for example, it helps to keep in mind that in some rows the zeros I will encounter later are (likely) not missing values, but are just the lowest values. And I also got the feel for the possible errors and outliers in the data (like with model_year).
#
# It also doesn't hurt to adjust the data we're working with a bit to make it more comprehensible – like when we don't need to stumnle over 'odometer' and 'paint_color' every time, and instead use more straightforward names.
#
# Wrapping up, the work done at this stage sets me up nicely for making additional calculations based on model_year and mileage in the next stage.

# %% [markdown]
# ## Make calculations and add them to the table

# %% [markdown]
# In order to enable our exploratory analysis, we need to make additional calculations and add the following to our table:
#
# - `day`, `month`, and `year` for each date_posted, so we can use these values for calculations (say, which day of the week is the most popular for posting ads? And similar questions)
#
# - `age`, as in the age of the car at the moment the ad was posted (in years): how many years have passed from the day it was manufactured to when it was advertised for sale
#
# - `miles_per_year` for cars average mileage count per year (based on its total mileage divided by its age)

# %%
data.head()
# Out:
#    price model_year           model  condition  cylinders fuel  mileage  \
# 0   9400 2011-01-01          bmw x5       good          6  gas   145000
# 1  25500 2014-01-01      ford f-150       good          6  gas    88705
# 2   5500 2013-01-01  hyundai sonata   like new          4  gas   110000
# 3   1500 2003-01-01      ford f-150       fair          8  gas   160000
# 4  14900 2017-01-01    chrysler 200  excellent          4  gas    80903
#
#   transmission    type    color  is_4wd date_posted  days_listed  \
# 0    automatic     SUV  unknown       1  2018-06-23           19
# 1    automatic  pickup    white       1  2018-10-19           50
# 2    automatic   sedan      red       0  2019-02-07           79
# 3    automatic  pickup  unknown       0  2019-03-22            9
# 4    automatic   sedan    black       0  2019-04-02           28
#
#    condition_scale
# 0                2
# 1                2
# 2                4
# 3                1
# 4                3

# %% [markdown]
# That's just to remind myself what our datetime format looks like: it's year-month-day. We add columns for weekday, month and year by simply calling the respective attributes on the datetime objects in the date_posted column.

# %%
data['day'] = data['date_posted'].dt.weekday
data['month'] = data['date_posted'].dt.month
data['year'] = data['date_posted'].dt.year

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
#
# Pandas library allows to add the month, year and weekday using methods like  `day_name()` и `month_name()`.
#
# More information here:
#
# https://www.geeksforgeeks.org/python-pandas-series-dt-day_name/
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.day_name.html
#
# https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.Series.dt.month_name.html
#
# https://www.geeksforgeeks.org/python-pandas-series-dt-month_name/

# %%
data.head(20)
# Out:
#     price model_year                     model  condition  cylinders fuel  \
# 0    9400 2011-01-01                    bmw x5       good          6  gas
# 1   25500 2014-01-01                ford f-150       good          6  gas
# 2    5500 2013-01-01            hyundai sonata   like new          4  gas
# 3    1500 2003-01-01                ford f-150       fair          8  gas
# 4   14900 2017-01-01              chrysler 200  excellent          4  gas
# 5   14990 2014-01-01              chrysler 300  excellent          6  gas
# 6   12990 2015-01-01              toyota camry  excellent          4  gas
# 7   15990 2013-01-01               honda pilot  excellent          6  gas
# 8   11500 2012-01-01               kia sorento  excellent          4  gas
# 9    9200 2008-01-01               honda pilot  excellent          6  gas
# 10  19500 2011-01-01  chevrolet silverado 1500  excellent          8  gas
# 11   8990 2012-01-01              honda accord  excellent          4  gas
# ...

# %% [markdown]
# Beautiful! Just out of curiosity, we can take a peek at how this data (days, month and year of the post) is distributed:

# %%
for i in ['day', 'month', 'year']:
    data[i].value_counts().sort_values(ascending = True).plot(kind = 'barh')
    plt.title(f'Distribution by {i}')
    plt.ylabel(f'{i}')
    plt.xlabel('Count')
    plt.show()

# %% [markdown]
# Interesting! We see that the majority (roughly over two thirds) of our ads were posted in 2018. And also that significantly fewer ads were posted in the month of April: I suspect that's due to the time period over which our data was collected:

# %%
data['date_posted'].max()
# Out:
# Timestamp('2019-04-19 00:00:00')

# %%
data['date_posted'].min()
# Out:
# Timestamp('2018-05-01 00:00:00')

# %% [markdown]
# Indeed this makes sense: we have data starting from the first of May in 2018 but up until 2/3 into April in 2019 (so not a full year, strictly speaking). This also implies at least 7 months for 2018 compared to (incomplete) 4 months of 2019. But there are no major differences as to the day when people post their ads, even though I thought there might be a pattern (like people getting around to it more often over the weekend).

# %%
data['age'] = (data['year'].astype(int)) - (data['model_year'].dt.year.astype(int))

# %%
data.head()
# Out:
#    price model_year           model  condition  cylinders fuel  mileage  \
# 0   9400 2011-01-01          bmw x5       good          6  gas   145000
# 1  25500 2014-01-01      ford f-150       good          6  gas    88705
# 2   5500 2013-01-01  hyundai sonata   like new          4  gas   110000
# 3   1500 2003-01-01      ford f-150       fair          8  gas   160000
# 4  14900 2017-01-01    chrysler 200  excellent          4  gas    80903
#
#   transmission    type    color  is_4wd date_posted  days_listed  \
# 0    automatic     SUV  unknown       1  2018-06-23           19
# 1    automatic  pickup    white       1  2018-10-19           50
# 2    automatic   sedan      red       0  2019-02-07           79
# 3    automatic  pickup  unknown       0  2019-03-22            9
# 4    automatic   sedan    black       0  2019-04-02           28
#
#    condition_scale  day  month  year  age
# 0                2    5      6  2018    7
# 1                2    4     10  2018    4
# ...

# %% [markdown]
# Alrighty!

# %% [markdown]
# So we'll have some values for age that will be equal to zero, and I propose that the easiest way is to just treat those as 'less than a year old' – to me it makes sense. If a car hasn't reached a full year of age at the time it was posted, then it shouldn't fall into the category '1 year' (or older..). Let's just make sure that these values correspond. The number of zeros values should be roughly the same as what was posted for sale in 2018 or 2019. Some, that were produced in 2018 (remember that all cars are assumed to be produced on the 1st of January: any other date would be just as arbitrary), but were posted later than that in the early months of 2019, will have the value of 1 in age.

# %%
len(data.loc[data['age'] == 0])
# Out:
# 2191

# %%
len(data.loc[data['model_year'].dt.year == 2018])
# Out:
# 2280

# %%
len(data.loc[data['model_year'].dt.year == 2019])
# Out:
# 387

# %% [markdown]
# Everything seems to be in order! Now let's do miles_per_year. For this one we'll use the apply() function so as not to divide those cars who's age in years is zero by their mileage in one swoop with the older cars. This way we can filter out the 0-aged cars to simply assign whatever mileage they have in total to their miles_per_year. In this case, we must pass the entire rows to the function so that we use values from different columns.

# %%
def make_miles_per_year(row):
    age = row['age']
    total_miles = row['mileage']
    
    if age == 0:
        return total_miles
    else:
        return int(total_miles / age)
    
data['miles_per_year'] = data.apply(make_miles_per_year, axis = 1)

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
#
# Ok, correct strategy of working with the data: we wouldn't have 0 values for calculation of mileage per year. If we divide  by zero we can get inf;
#
# You can also deal with it problem implementing this approach:
#
#
# `data['age'] = data['year_posted'] - data['model_year'] + 1`

# %%
data.head(20)
# Out:
#     price model_year                     model  condition  cylinders fuel  \
# 0    9400 2011-01-01                    bmw x5       good          6  gas
# 1   25500 2014-01-01                ford f-150       good          6  gas
# 2    5500 2013-01-01            hyundai sonata   like new          4  gas
# 3    1500 2003-01-01                ford f-150       fair          8  gas
# 4   14900 2017-01-01              chrysler 200  excellent          4  gas
# 5   14990 2014-01-01              chrysler 300  excellent          6  gas
# 6   12990 2015-01-01              toyota camry  excellent          4  gas
# 7   15990 2013-01-01               honda pilot  excellent          6  gas
# 8   11500 2012-01-01               kia sorento  excellent          4  gas
# 9    9200 2008-01-01               honda pilot  excellent          6  gas
# 10  19500 2011-01-01  chevrolet silverado 1500  excellent          8  gas
# 11   8990 2012-01-01              honda accord  excellent          4  gas
# ...

# %% [markdown]
# Beautiful. We don't even need to do an extra check for zero-aged card: there is one at the end of the table, we can see that its miles_per_year is the same as its total mileage.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 51525 entries, 0 to 51524
# Data columns (total 19 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   price            51525 non-null  int64
#  1   model_year       51525 non-null  datetime64[ns]
#  2   model            51525 non-null  object
#  3   condition        51525 non-null  object
#  4   cylinders        51525 non-null  int64
#  5   fuel             51525 non-null  object
#  6   mileage          51525 non-null  int64
#  7   transmission     51525 non-null  object
#  8   type             51525 non-null  object
#  9   color            51525 non-null  object
#  10  is_4wd           51525 non-null  int64
#  11  date_posted      51525 non-null  datetime64[ns]
#  12  days_listed      51525 non-null  int64
#  13  condition_scale  51525 non-null  int64
#  14  day              51525 non-null  int64
#  15  month            51525 non-null  int64
# ...

# %% [markdown]
# ### Conclusion

# %% [markdown]
# Adding necessary categories such age and miles_per_year, as well as day/week/year of publication was relatively straightforward, but different kinds of data require different approaches, and it was useful to keep in mind the particular features of different values – for instance, to return total_miles in case the age of the car was less than one full year (so as not to accidentally divide by zero). So I used an apply function approach there, whereas for making the age column it was enough to simply create a new column based on values in the other ones. A similar approach for extracting day/wee/year – but with the added convenience of being able to extract them as attributes of datetime values.
#
# When proceeding with steps in preprocessing or 'enhancing' data, it's useful to keep in mind what different values might mean – for instance, getting 0 for age might appear confusing at first glance, but with a simple check it was possible to ensure that they are just a result of cars being produced in recent years, not clocking in 1 full year of age. At least, it's a valid enough distinction to make in the absence of 'month of production'.

# %% [markdown]
# ## Carry out exploratory data analysis

# %% [markdown]
# ### Overview of basic parameters

# %% [markdown]
# For the first step of EDA, let us study the distribution of basic descriptive values for our cars, limiting ourselves to the following columns:
#
# - `price`
# - `age`
# - `mileage`
# - `cylinders`
# - `condition`

# %% [markdown]
# #### Price

# %% [markdown]
# For starters, let's just have the stats description in front of our eyes:

# %%
data['price'].describe()
# Out:
# count     51525.000000
# mean      12132.464920
# std       10040.803015
# min           1.000000
# 25%        5000.000000
# 50%        9000.000000
# 75%       16839.000000
# max      375000.000000
# Name: price, dtype: float64

# %%
data['price'].hist()
plt.title('Distribution of prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# So we can zoom in closer to the range of 0 to 100000. First let's take a quick look at those max values

# %%
higher_than_high = data.query('price > 100000')
higher_than_high
# Out:
#         price model_year                     model  condition  cylinders  \
# 1309   189000 2014-01-01                ford f-150       good          6
# 1668   189000 2014-01-01                ford f-150       good          6
# 11359  300000 2015-01-01                  ram 2500  excellent          6
# 12504  375000 1999-01-01           nissan frontier       good          6
# 20700  109999 2000-01-01        chevrolet corvette        new          8
# 22833  115000 2012-01-01     ford f-250 super duty       good          8
# 24999  140000 2004-01-01                  ram 2500       good          6
# 27375  189000 2014-01-01                ford f-150       good          6
# 29810  123456 2000-01-01        chevrolet suburban       good          8
# 30634  189000 2014-01-01                ford f-150       good          6
# 33434  189000 2014-01-01                ford f-150       good          6
# 34206  175000 2004-01-01         gmc sierra 2500hd       good          8
# ...

# %% [markdown]
# At first I thought: arghh, how did we miss those clearly duplicated rows? Why weren't they picked up earlier? But then I remembered that we have entries for ads, not individual cars. So yeah, we can see some very suspicious ones like that chevrolet suburban whose owner's theory of price formation is 'a dollar for every mile that I rode'. Or maybe he just typed '123456' on a whim. Either way, we see no Lamborghinis in this data slice, and we can definitely treat these as outliers.

# %%
data['price'].hist(bins = 20, range = (0, 100000), figsize = (12, 8))
plt.title('Distribution of prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Still a bit hard to see whether there is something happening from 70000 up to 100000 price range, so let's zoom in:

# %%
data['price'].hist(bins = 20, range = (70000, 100000), figsize = (12, 8))
plt.title('Distribution of prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %%
len(data.loc[data['price'] > 70000])
# Out:
# 28

# %%
data.loc[data['price'] > 70000]
# Out:
#         price model_year                       model  condition  cylinders  \
# 1309   189000 2014-01-01                  ford f-150       good          6
# 1326    79900 2008-01-01                   ford f350   like new          8
# 1668   189000 2014-01-01                  ford f-150       good          6
# 2790    76000 2016-01-01          chevrolet corvette        new          8
# 3919    75000 2016-01-01                  ford f-150   like new          8
# 4113    90577 2018-01-01                  ford f-150  excellent          6
# 7113    84900 2019-01-01                   ford f350        new          8
# 11359  300000 2015-01-01                    ram 2500  excellent          6
# 12485   78000 2009-01-01               honda odyssey       good          6
# 12504  375000 1999-01-01             nissan frontier       good          6
# 20700  109999 2000-01-01          chevrolet corvette        new          8
# ...

# %% [markdown]
# More of the same, no Tesla or anything like that. These machines are outliers

# %%
data['price'].hist(bins = 100, range = (0, 70000), figsize = (12, 8))
plt.title('Distribution of prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %%
len(data.loc[data['price'] > 50000])
# Out:
# 227

# %%
#data.loc[data['price'] < 5]

# %% [markdown]
# Let's look at the boxplot, so we can see the outliers at once.

# %%
data['price'].plot(kind = 'box')
plt.title('Distribution of prices')
plt.show()

# %% [markdown]
# It looks like the outliers start even earlier (at lower values).

# %%
data['price'].plot(kind = 'box')
plt.ylim(-100, 50000)
plt.title('Distribution of prices')
plt.show()

# %% [markdown]
# Indeed, according to the whiskers' position, we can everything that goes above ~35000 a piece as outlier values.

# %%
data['price'].plot(kind = 'box')
plt.ylim(-10, 10)
plt.title('Distribution of prices')
plt.show()

# %% [markdown]
# As well as everything that's..a little over zero? We didn't have any zero values which could be treated as hidden missing values in the price column, so what's up with these?

# %%
len(data.loc[data['price'] < 1000])
# Out:
# 1404

# %%
data.loc[data['price'] < 1000].describe()
# Out:
#              price    cylinders        mileage       is_4wd  days_listed  \
# count  1404.000000  1404.000000    1404.000000  1404.000000  1404.000000
# mean    217.480057     6.639601   81435.750712     0.599715    38.900997
# std     313.475340     2.230105   74603.834826     0.490131    27.374404
# min       1.000000     3.000000       0.000000     0.000000     0.000000
# 25%       1.000000     4.000000   23897.750000     0.000000    19.000000
# 50%       1.000000     6.000000   53163.500000     1.000000    33.000000
# 75%     441.750000     8.000000  131795.000000     1.000000    52.000000
# max     999.000000    10.000000  358189.000000     1.000000   213.000000
#
#        condition_scale          day        month         year          age  \
# count      1404.000000  1404.000000  1404.000000  1404.000000  1404.000000
# mean          2.678775     3.066952     6.722222  2018.297009     6.333333
# std           0.875796     2.035625     3.472083     0.457103     7.383401
# ...

# %%
len(data.loc[data['price'] < 500])
# Out:
# 1069

# %%
len(data.loc[data['price'] < 200])
# Out:
# 911

# %%
data.loc[data['price'] < 200].describe()
# Out:
#             price   cylinders        mileage      is_4wd  days_listed  \
# count  911.000000  911.000000     911.000000  911.000000   911.000000
# mean    14.361142    7.363337   46904.973655    0.761800    39.097695
# std     43.165668    2.238704   39751.432915    0.426216    28.145819
# min      1.000000    3.000000       0.000000    0.000000     1.000000
# 25%      1.000000    6.000000   17572.000000    1.000000    19.000000
# 50%      1.000000    8.000000   38617.000000    1.000000    33.000000
# 75%      1.000000   10.000000   61823.000000    1.000000    52.000000
# max    199.000000   10.000000  300000.000000    1.000000   213.000000
#
#        condition_scale         day       month         year         age  \
# count       911.000000  911.000000  911.000000   911.000000  911.000000
# mean          2.983535    3.050494    6.683864  2018.310648    3.141603
# std           0.367278    2.048231    3.553817     0.463013    4.653574
# ...

# %%
len(data.loc[data['price'] < 5])
# Out:
# 799

# %%
len(data.loc[data['price'] < 2])
# Out:
# 798

# %% [markdown]
# So we've whittled it down to 2 (dollars?) a piece. This explains the slight spike at the beginning of the graph when we look at a histogram of price (that looks like zero, but it's the 'ones').

# %%
((len(data.loc[data['price'] < 2]) + len(data.loc[data['price'] > 35000])) / len(data)) * 100
# Out:
# 4.293061620572538

# %% [markdown]
# So we have something like a total of 4% of outlier values for price (from both sides)

# %% [markdown]
# Let's look at price distribution excluding the outlier values:

# %%
data['price'].hist(bins = 100, range = (2, 35000), figsize = (12, 8))
plt.title('Distribution of prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# The data is till 'skewed' to the left, but slightly more readable. We can see a 'chainsaw' pattern with these spikes that go up near round values. I think that one possible explanation is psychological in the sense that when putting a numerical estimate on something, people tend to opt for round values, like "I want to sell this item for 20 or 25 dollars, not 22 or 23". This could also happen in this case, with sellers going for values divisible by 1000, 500, 250 or 100.

# %% [markdown]
# However, while that number of bins is good for precision and allows us to see where the spikes occur most often, the chainsaw pattern makes it somewhat hard to read the distribution, and to see which range of prices is the most prevalent in our dataset (one might be fooled especially to look intuitively at the area where the highest spikes occur). Let's do another one with fewer bins.

# %%
data['price'].hist(bins = 20, range = (2, 35000), figsize = (12, 8))
plt.title('Distribution of prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %%
data['price'].hist(bins = 10, range = (2, 35000), figsize = (12, 8))
plt.title('Distribution of prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# OK, maybe I was a bit prejudgemental about that graph with 100 bins, the largest number of prices does actually coincide near the highest spike – precisely because that's what the Y axis does in a histogram! The joke is on me. Still, nice to have this distribution more densely packed.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, as a whole the logic of the deciison at this step is correct, all the plots are in place, good job!

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# Some recommendations for formatting of the plot: it is better to add custom title and x and y axis labels to your plot and the common title too.
#
# Some useful links:
#
# https://www.python-graph-gallery.com/4-add-title-and-axis-label
#
# https://www.kite.com/python/answers/how-to-add-axis-labels-to-a-plot-in-matplotlib-in-python
#
# Also, it is better to delete technical strings like `<matplotlib.axes._subplots.AxesSubplot at 0x7f529e0802d0>` from your graphs: use `plt.show()` or `;`.
#
# So, please, try to improve all the plots in your project. Because it is the EDA project, here it is really important to make your plots informative.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review<a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, this time the plots are formatted much more correctly, good job!

# %% [markdown]
# To get an even clearer idea of the distribution of values without going back to boxplot, we can put the quantiles in front of us:

# %%
data['price'].hist(bins = 10, range = (2, 35000), figsize = (12, 8))
q1 = data['price'].quantile(0.25)
q2 = data['price'].quantile(0.5)
q3 = data['price'].quantile(0.75)

plt.vlines(x = [q1, q2, q3], ymin = 0.5, ymax = 13000, color = 'red')
plt.title('Distribution of prices')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %%
data.head(50)
# Out:
#     price model_year                              model  condition  cylinders  \
# 0    9400 2011-01-01                             bmw x5       good          6
# 1   25500 2014-01-01                         ford f-150       good          6
# 2    5500 2013-01-01                     hyundai sonata   like new          4
# 3    1500 2003-01-01                         ford f-150       fair          8
# 4   14900 2017-01-01                       chrysler 200  excellent          4
# 5   14990 2014-01-01                       chrysler 300  excellent          6
# 6   12990 2015-01-01                       toyota camry  excellent          4
# 7   15990 2013-01-01                        honda pilot  excellent          6
# 8   11500 2012-01-01                        kia sorento  excellent          4
# 9    9200 2008-01-01                        honda pilot  excellent          6
# 10  19500 2011-01-01           chevrolet silverado 1500  excellent          8
# ...

# %% [markdown]
# Indeed we can see the confirmation of our hypothesis about the reasons for that price distribution (and spikes) in the data in price column. Additionally, we can see the kind of classic 100, 10 and even 1 dollar discount from next largest round number like hey it's only 5990, not a whopping 6000! Makes for a more appealing offer.

# %% [markdown]
# #### Age

# %%
data['age'].describe()
# Out:
# count    51525.000000
# mean         8.528928
# std          6.152725
# min         -1.000000
# 25%          4.000000
# 50%          7.000000
# 75%         12.000000
# max        110.000000
# Name: age, dtype: float64

# %% [markdown]
# What's up with these negatively aged cars? Are they the flying cars from the future? Or did I mess up when calculating the age column?

# %%
data.loc[data['age'] == -1]
# Out:
#        price model_year                         model condition  cylinders  \
# 2976     287 2019-01-01              chevrolet impala  like new          6
# 8632   21900 2019-01-01   nissan frontier crew cab sv      good          6
# 24238  21900 2019-01-01   nissan frontier crew cab sv      good          6
# 45626  22900 2019-01-01   nissan frontier crew cab sv      good          6
# 46182  24100 2019-01-01  chevrolet camaro lt coupe 2d      good          6
# 48503  21800 2019-01-01   nissan frontier crew cab sv      good          6
#
#       fuel  mileage transmission    type    color  is_4wd date_posted  \
# 2976   gas    36147    automatic   sedan  unknown       0  2018-08-09
# 8632   gas    27576        other  pickup    white       1  2018-10-29
# 24238  gas    27576        other  pickup    white       1  2018-11-26
# 45626  gas    24402        other  pickup     blue       1  2018-07-10
# 46182  gas    18755        other   coupe  unknown       0  2018-08-06
# ...

# %% [markdown]
# Hmm. Doesn't look like a mistake in anything we've done in our calculations and changes to the table. The model year came with the data, as was the date when the ad was posted. Yet those cars have some mileage behind them somehow. So it could either be a technical error in the data exporting process or a typo by the seller. They all have 2019 as model_year and yet they posted their ads in the year before that. I think a reasonable option is drop these 6 rows, since we can't really fix the dates, and these are clearly erroneous values.

# %%
len(data)
# Out:
# 51525

# %%
data = data.drop(data.loc[data['age'] < 0].index)

# %%
len(data)
# Out:
# 51519

# %%
data['age'].describe()
# Out:
# count    51519.000000
# mean         8.530037
# std          6.152224
# min          0.000000
# 25%          4.000000
# 50%          7.000000
# 75%         12.000000
# max        110.000000
# Name: age, dtype: float64

# %% [markdown]
# OK so I would argue that a difference like that between mean and median is actually quite significant in this case (we're talking about age, which must not have as wide a range as some of our other quantitative values). We can clearly see the outliers there in the max section that must be pulling the mean age up. Let's look at the boxplot first so we can see the outliers more clearly and then make a histogram.

# %%
data['age'].plot(kind = 'box')
plt.title('Distribution of ages')
plt.show()

# %% [markdown]
# Let's zoom in to find where the outliers begin

# %%
data['age'].plot(kind = 'box')
plt.ylim(-5, 25)
plt.title('Distribution of ages')
plt.show()

# %% [markdown]
# I'm wondering how many entries we'll miss if the outliers really start at..24?

# %%
len(data.query('age > 24'))
# Out:
# 753

# %% [markdown]
# Fair enough..that's a really small slice of our dataset

# %%
(len(data.query('age > 24')) / len(data)) * 100
# Out:
# 1.4615966924823853

# %%
data['age'].hist(bins = 24, range = (0, 24))
q1 = data['age'].quantile(0.25)
q2 = data['age'].quantile(0.5)
q3 = data['age'].quantile(0.75)

plt.vlines(x = [q1, q2, q3], ymin = 0, ymax = 4000, color = 'red')
plt.title('Distribution of ages w/o outliers')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Crisp and clear! Compare this to how it would look like with all the outliers in place:

# %%
data['age'].hist(bins = 24)
plt.title('Distribution of ages with outliers')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# #### Mileage

# %%
data['mileage'].describe()
# Out:
# count     51519.000000
# mean     115504.501136
# std       62987.368479
# min           0.000000
# 25%       72000.000000
# 50%      113893.000000
# 75%      154000.000000
# max      990000.000000
# Name: mileage, dtype: float64

# %%
data['mileage'].plot(kind = 'box')
plt.title('Distribution of miles')
plt.ylabel('Miles')
plt.show()

# %%
data['mileage'].plot(kind = 'box')
plt.ylim(-10000, 300000)
plt.title('Distribution of miles')
plt.ylabel('Miles')
plt.show()

# %%
data['mileage'].plot(kind = 'box')
plt.ylim(200000, 300000)
plt.title('Distribution of miles')
plt.ylabel('Miles')
plt.show()

# %%
len(data.query('mileage > 280000'))
# Out:
# 523

# %% [markdown]
# Again we see that the number of outliers that go way above the upper whisker is reasonable. Let's look at a histogram

# %%
data['mileage'].hist(bins = 50)
plt.title('Distribution of miles')
plt.xlabel('Miles')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# Not terribly helpful.

# %%
data['mileage'].hist(bins = 50, range = (0, 300000), figsize = (10, 6))
plt.title('Distribution of miles')
plt.xlabel('Miles')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# This is much better. I wonder what is that spike near zero.

# %%
data['mileage'].hist(bins = 50, range = (0, 50000), figsize = (10, 6))
plt.title('Distribution of miles')
plt.xlabel('Miles')
plt.ylabel('Count')
plt.show()

# %%
data['mileage'].hist(bins = 50, range = (0, 1000), figsize = (10, 6))
plt.title('Distribution of miles')
plt.xlabel('Miles')
plt.ylabel('Count')
plt.show()

# %%
len(data.query('mileage < 1000'))
# Out:
# 870

# %% [markdown]
# We could consider them outliers, unless they all happen to be, say of new condition which would justify their mileage.

# %%
data.query('mileage < 1000')['condition_scale'].value_counts()
# Out:
# 3    357
# 2    319
# 4    113
# 5     48
# 1     29
# 0      4
# Name: condition_scale, dtype: int64

# %% [markdown]
# We saw earlier, when we studied the missing values in mileage, that the zero-sized values in mileage didn't really make much sense:

# %%
data.query('mileage == 0')['condition_scale'].value_counts()
# Out:
# 2    112
# 3     73
# 1      6
# 4      6
# 0      2
# Name: condition_scale, dtype: int64

# %% [markdown]
# How can the cars marked as 'good' and 'fair' (in the majority) have 0 mileage? It could be a faulty odometer reading, or even a reset, but either way, this isn't very quality data for us, or potential buyers, for that matter! The same applies really to mileage under 1000 (or 400 hundred, depending on how precise we want to be, but probably no need nail it down to every single car in this case).

# %% [markdown]
# So I propose that we treat this group as outliers going forward. Just look at the histogram without them:

# %%
data['mileage'].hist(bins = 50, range = (1000, 300000), figsize = (10, 6))
plt.title('Distribution of miles w/o outliers')
plt.xlabel('Miles')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# It's beautiful!

# %% [markdown]
# #### Cylinders

# %%
data['cylinders'].value_counts()
# Out:
# 8     17712
# 6     17429
# 4     15499
# 10      549
# 5       294
# 3        34
# 12        2
# Name: cylinders, dtype: int64

# %%
data['cylinders'].plot(kind = 'box')
plt.title('Distribution of cylinders')
plt.show()

# %% [markdown]
# Plotting a histogram for number cylinders doesn't seem to make sense, since these are categorical values. We can get a good enough sense of the distribution with a bar plot.

# %%
data['cylinders'].value_counts().plot(kind = 'bar', rot = 1)
plt.title('Distribution of cylinders')
plt.xlabel('Number of cylinders')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# I think this is clearer than this:

# %%
data['cylinders'].hist(bins = 7, range = (3, 12))
q1 = data['cylinders'].quantile(0.25)
q2 = data['cylinders'].quantile(0.5)
q3 = data['cylinders'].quantile(0.75)

plt.vlines(x = [q1, q2, q3], ymin = 0, ymax = 18000, color = 'red')
plt.title('Distribution of cylinders')
plt.xlabel('Number of cylinders')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# In any case, we have three dominant categories which are 4, 6, and 8 cylinders, and the others. Even though the total amount of other numbers of cylinders combined is very small, it seems to me unreasonable to exclude them from the analysis as outliers, after all these are categorical values which are rare, not numerical values that stray from the rest for a weird reason (like a ridiculously high price or a hundred years in service). Either way due to their relatively small weight they shouldn't distort our analysis.

# %% [markdown]
# #### Condition

# %%
data['condition_scale'].value_counts()
# Out:
# 3    24773
# 2    20140
# 4     4741
# 1     1607
# 5      143
# 0      115
# Name: condition_scale, dtype: int64

# %% [markdown]
# Same logic as with cylinders applies to condition, in terms of it being a categorical value.

# %%
data['condition_scale'].value_counts().plot(kind = 'bar', rot = 1)
plt.xlabel('Condition on a scale 0-5')
plt.ylabel('Count')
plt.title('Distribution of condition')
plt.show()

# %% [markdown]
# We can see that most cars come advertised as being in 'excellent' condition, followed by good, followed by 'like new', then by 'fair', 'new', and finally, 'salvage'. This should tell us, presumably, that at least the majority of sellers saying the car is new might actually be telling the truth and not exagerrating, since it's a very small number, second only to those who honestly mark their cars as 'salvage' (very poor condition).

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Again, a  big plus for so detailed and well-elaborated approach to the data exploration at this step of the analysis.

# %% [markdown]
# ### Filtering data

# %% [markdown]
# Based on our findings, let's filter the data, to get red of the outlier values identified so far in the `price`, `age`, and `mileage` columns. We can do achieve this by creating a good_data table, using data to query for rows excluding those containing outliers.

# %% [markdown]
# Let's take a moment to see how this will change our stats in the case of each column, as well as how many rows we'll have to say goodbye to (to think whether we can afford that).

# %%
len(data)
# Out:
# 51519

# %% [markdown]
# For price, if we abide by the guidance of BoxPlot the Wise, our outliers will start at ~35000. Our previous explorations also led us to conclude that we should get rid of the fishy 800 or so rows where the cars are priced at less than 2 dollars.

# %%
len(data.query('price < 2')) + len(data.query('price > 35000'))
# Out:
# 2212

# %%
((len(data.query('price < 2')) + len(data.query('price > 35000'))) / len(data))
# Out:
# 0.04293561598633514

# %% [markdown]
# That means saying goodbye to over 2000 rows. That sounds a bit much to me. Sure the 2 dollar cars must go. But I suppose we don't really have to be that strict to all cars priced above 35000.

# %%
((len(data.query('price < 2')) + len(data.query('price > 35000'))) / len(data))
# Out:
# 0.04293561598633514

# %% [markdown]
# That would be 4 percent of our data. Remember that we must also filter out outliers in mileage and age.

# %%
len(data.query('price < 2')) + len(data.query('price > 35000'))
# Out:
# 2212

# %%
len(data.query('price < 100')) + len(data.query('price > 35000'))
# Out:
# 2277

# %% [markdown]
# Perhaps we should consider all prices under 100 suspicious, really. I mean, I can imagine 'salvage' starting at 100, even though that would still be a car. Otherwise we'll still have some stray values at 3 or 5 dollars in our dataset.

# %%
data['price'].describe()
# Out:
# count     51519.000000
# mean      12131.686718
# std       10040.726778
# min           1.000000
# 25%        5000.000000
# 50%        9000.000000
# 75%       16801.500000
# max      375000.000000
# Name: price, dtype: float64

# %%
data.query('100 < price < 35000')['price'].describe()
# Out:
# count    49201.000000
# mean     11381.651186
# std       7856.882256
# min        105.000000
# 25%       5000.000000
# 50%       8995.000000
# 75%      15995.000000
# max      34999.000000
# Name: price, dtype: float64

# %% [markdown]
# We can see that this will actually pull up our median price by a bit and push down the mean.

# %% [markdown]
# Now let's look at age again.

# %%
data['age'].hist(bins = 24, range = (0, 50))
plt.title('Distribution of ages')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# So the boxplot again would tell us to consider everything above 24 an outlier. Let's see ho many rows that would mean.

# %%
len(data.query('age > 24'))
# Out:
# 753

# %% [markdown]
# It seems to me like we could go with 30 as a reasonable border: values only begin to flatten out on the histogram after that.

# %%
len(data.query('age > 30'))
# Out:
# 352

# %% [markdown]
# And we won't lose as many rows.

# %%
data['age'].describe()
# Out:
# count    51519.000000
# mean         8.530037
# std          6.152224
# min          0.000000
# 25%          4.000000
# 50%          7.000000
# 75%         12.000000
# max        110.000000
# Name: age, dtype: float64

# %%
data.query('age < 30')['age'].describe()
# Out:
# count    51115.000000
# mean         8.280113
# std          5.419441
# min          0.000000
# 25%          4.000000
# 50%          7.000000
# 75%         12.000000
# max         29.000000
# Name: age, dtype: float64

# %% [markdown]
# This won't even affect our values that much. We should just keep in mind, that when we do the slicing after we first slice based on prices, it might already be slightly different.

# %% [markdown]
# And finally, mileage.

# %%
len(data.query('mileage > 300000')) + len(data.query('mileage <= 1000'))
# Out:
# 1170

# %% [markdown]
# Looks like we could get rid of those. The only nuance to consider is maybe not filter out the cars with less than 1000 miles that are marked as new or like new? It seems entirely reasonable that such cars could have very low mileage, so let's try and keep them.

# %%
data.query('mileage <= 1000')['condition'].value_counts()
# Out:
# excellent    358
# good         319
# like new     115
# new           49
# fair          29
# salvage        4
# Name: condition, dtype: int64

# %% [markdown]
# We should try and salvage those 164 new and like new cars. Pun intended!

# %%
len(data.query('1000 < mileage < 280000')) + len(data.query('mileage <= 1000 and condition in(["new", "like new"])'))
# Out:
# 50269

# %%
N_D = data.query('mileage < 280000')

# %% [markdown]
# N_D for New Data. This is me just testing that it works. Will then start over filtering the data from price through age and then mileage.

# %%
len(N_D)
# Out:
# 50979

# %%
# after this, the length of N_D should be the same as three cells above – 50269 – this way we know we saved those rows
N_D = N_D.drop(N_D.loc[(N_D['mileage'] <= 1000) & ~(N_D['condition'].isin(['new', 'like new']))].index)

# %%
len(N_D)
# Out:
# 50269

# %%
N_D.query('mileage <= 1000')['condition'].value_counts()
# Out:
# like new    115
# new          49
# Name: condition, dtype: int64

# %% [markdown]
# Alright perfect! Had to sweat a little to make that query work. Now let me start clean with a variable good_data for filtered data, first filtering price, then age and finally mileage. We will have the original data variable for comparison.
#
# We can also see the confirmation of our previous assumption that based on the very small number of sellers claiming their cars are 'new', at least some of them must be telling the truth. Indeed we can glimpse here that at least a third of those cars have under 1000 mileage.

# %%
data.query('condition == "new"')['mileage'].describe()
# Out:
# count       143.000000
# mean      45897.559441
# std       66599.701586
# min           5.000000
# 25%          26.500000
# 50%       10500.000000
# 75%       72500.000000
# max      315000.000000
# Name: mileage, dtype: float64

# %%
data['mileage'].describe()
# Out:
# count     51519.000000
# mean     115504.501136
# std       62987.368479
# min           0.000000
# 25%       72000.000000
# 50%      113893.000000
# 75%      154000.000000
# max      990000.000000
# Name: mileage, dtype: float64

# %% [markdown]
# OK, so maybe there are some outliers (and straight out liers) in that 'new' group, but still, comparing the stats, we can see that it kind of checks out.

# %% [markdown]
# #### (Actually filtering the data)

# %%
good_data = data.query('100 < price < 35000')

# %%
good_data = good_data.query('age < 30')

# %%
len(good_data)
# Out:
# 48831

# %%
good_data = good_data.query('mileage < 280000')

# %%
len(good_data)
# Out:
# 48298

# %%
good_data = good_data.drop(good_data.loc[(good_data['mileage'] <= 1000) & ~(good_data['condition'].isin(['new', 'like new']))].index)

# %%
len(good_data)
# Out:
# 47631

# %%
good_data.query('mileage <= 1000')['condition'].value_counts()
# Out:
# like new    85
# new         19
# Name: condition, dtype: int64

# %% [markdown]
# Wait a second, that's less than what we had before. I bet some of those got lost with the outliers in price, most likely.

# %%
len(data.query('price >= 35000 and condition in (["new", "like new"]) and mileage <= 1000'))
# Out:
# 40

# %%
len(data.query('price <= 100 and condition in (["new", "like new"]) and mileage <= 1000'))
# Out:
# 19

# %% [markdown]
# Yeah that's gotta be it. Let's just see how much data we let go.

# %%
len(data) - len(good_data)
# Out:
# 3888

# %%
((len(data) - len(good_data)) / len(data)) * 100
# Out:
# 7.54673033249869

# %% [markdown]
# Over 7.5 percent of our original data.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, Roman, it is correct to use the IQR method for deleting the outliers, it is rather effective one for this task! More details about working with the outliers you can find by links:
#
# https://towardsdatascience.com/ways-to-detect-and-remove-the-outliers-404d16608dba
#
# http://colingorrie.github.io/outlier-detection.html#iqr-method
#
# https://statisticsbyjim.com/basics/outliers/

# %% [markdown]
# #### With and without the outliers

# %% [markdown]
# Now let's compare the histograms with and w/o outliers. We did look at each of the same values in depth before so we can do a quick overview this time.

# %%
for i in ['price', 'age', 'mileage']:
    data[i].hist()
    plt.title(f'Distribution of {i} including outliers')
    plt.xlabel(f'{i}')
    plt.ylabel('Count')
    plt.show()
    good_data[i].hist()
    plt.title(f'Distribution of {i} w/o outliers')
    plt.xlabel(f'{i}')
    plt.ylabel('Count')
    plt.show()

# %% [markdown]
# No surprises here! All seems to be in order, and the data is certainly more readable without the outliers. We can also see how data gets more and more skewed to the right on the histograms as we move through price, age and mileage (although it's mainly skewed to the left of course).

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# It is absolutely correct to compare the data with and without outliers, but it is still important to format the plots in a more correct and informative way👀

# %% [markdown]
# ### Studying ads (days_listed)

# %%
good_data['days_listed'].describe()
# Out:
# count    47631.000000
# mean        39.546388
# std         28.216564
# min          0.000000
# 25%         19.000000
# 50%         33.000000
# 75%         53.000000
# max        271.000000
# Name: days_listed, dtype: float64

# %%
len(good_data.query('days_listed == 0'))
# Out:
# 49

# %% [markdown]
# Recall that we decided not to treat these as outliers.

# %%
good_data['days_listed'].hist(bins = 40)
q1 = good_data['days_listed'].quantile(0.25)
q2 = good_data['days_listed'].quantile(0.50)
q3 = good_data['days_listed'].quantile(0.75)
plt.vlines(x = [q1, q2, q3], ymin = 0, ymax = 6000, color = 'red')
plt.title('Distribution of days_listed')
plt.xlabel('days_listed')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# We can see from the histogram how the values in days_listed are quite skewed to the left, with three quarters of listings staying up up to 53 days, and a median listing being up for just over a month. If we try to see within what range of time up 95% of our data falls, we'll get something close to 90 days, or three months:

# %%
good_data['days_listed'].hist(bins = 40, figsize = (12, 8))
q95 = good_data['days_listed'].quantile(0.95)
plt.vlines(x = q95, ymin = 0, ymax = 6000, color = 'red')
plt.title('Distribution of days_listed')
plt.xlabel('days_listed')
plt.ylabel('Count')
plt.show()

# %%
good_data['days_listed'].plot(kind = 'box')
plt.title('Distribution of days_listed')
plt.show()

# %% [markdown]
# Three months is indeed a long time for an ad to be up – at least it is per the distribution in our dataset, – even though the boxplot puts the outlier threshold at over 100.

# %%
len(good_data.query('7 < days_listed < 90')) / len(good_data)
# Out:
# 0.8794692532174424

# %% [markdown]
# We can see that the majority of our ads have been up between 1 week and 3 months (approximately). So for the purposes of classification, I propose that we use this scale for reference and create two columns so we have the opportunity to group data by how many too-quickly-gone and how many long-hanging ads there are per type/age/other category, if we ever want to look deeper into that.
#
# I imagine that the lifecycle of an ad for a car would be such that even if you manage to find your buyer more or less right away, 7 days would typically likely be the fastest time for you two to message each other, ascertain all the details, maybe bargain a little for a discount, make arrangements for transportation, payments and so on. In other words, it probably takes some time before the deal is complete and the ad can be removed. Of course it could also be that the seller finds their buyer from a different source (word of mouth / different website) on the same day or a couple days after they post the ad, and so they remove it very quickly. But then again, that also makes it less relevant for us.
#
# A lot of things can happen in between, and you might prefer one buyer over another one, or in case you're the buyer, you may find a better deal elsewhere, so an ad can hang there for a while. If it's longer than 3 months, however, it's likely either due to an error, or the car is just not a seller, or it's not an urgent sale for the owner.

# %%
good_data['too_short'] = good_data['days_listed'] <= 7
good_data['too_long'] = good_data['days_listed'] >= 90

# %% [markdown]
# Let's see if the amount of too_short or long hanging ads differs by type.

# %%
short_stat = good_data.pivot_table(index = 'type', values = 'too_short')

# %%
short_stat.sort_values(by = 'too_short', ascending = False)
# Out:
#              too_short
# type
# van           0.074380
# mini-van      0.069481
# offroad       0.066327
# wagon         0.064189
# hatchback     0.063444
# other         0.062762
# SUV           0.060713
# sedan         0.060388
# convertible   0.059783
# truck         0.059152
# coupe         0.059003
# pickup        0.058134
# bus           0.041667

# %%
long_stat = good_data.pivot_table(index = 'type', values = 'too_long')

# %%
long_stat.sort_values(by = 'too_long', ascending = False)
# Out:
#              too_long
# type
# offroad      0.076531
# wagon        0.069595
# van          0.069421
# mini-van     0.066843
# hatchback    0.066465
# convertible  0.065217
# SUV          0.062263
# coupe        0.060529
# sedan        0.060132
# pickup       0.056884
# truck        0.056314
# other        0.050209
# bus          0.041667

# %% [markdown]
# It is easy to see that there is no significant difference in the amount of too_short or too_long hanging ads when it comes to type, as an example (a range of roughly 6 to 7%). Let's see what it does to mean and median values, otherwise I don't see a reason to modify our data further in respect to days_listed.

# %%
good_data.query('7 < days_listed < 90')['days_listed'].describe()
# Out:
# count    41890.000000
# mean        36.913010
# std         20.126124
# min          8.000000
# 25%         20.000000
# 50%         33.000000
# 75%         50.000000
# max         89.000000
# Name: days_listed, dtype: float64

# %% [markdown]
# Seems like not such a bad call after all, chopping it down at 7 and 90 days! Our median values managed to stay the same, and the mean value got trimmed to 36.9 down from 39.5 in the original range.

# %% [markdown]
# Let's have a closer look at the distribution, to see how long a typical ad would be up.

# %%
q1 = good_data['days_listed'].quantile(0.25)
q2 = good_data['days_listed'].quantile(0.50)
q3 = good_data['days_listed'].quantile(0.75)
good_data['days_listed'].hist(bins = 42, range = (7, 90))
plt.vlines(x = q2, ymin = 0, ymax = 2000, color = 'red')
plt.title('Distribution of days_listed')
plt.xlabel('days_listed')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# So we know that the median value is 33 days, just over a month. But the graph peaks at just before 20 days, which means that's the most frequent amount of time an ad stays up – roughly 2 to 2.5 weeks.

# %% [markdown]
# Should maybe do a slice of good_data trimmed by days_listed? 🤔 – LEFT THIS BY ACCIDENT AS A REMINDER TO MYSELF 😅

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# As for days_listed column, it is better not to delete the outliers from this column because it contains rather sensetive information, Also, according to the instruction, you simply need to explore the data in this column:
#
# ![image.png](attachment:image.png)
#
# And now it is better to concentrate on the answering these questions👀

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> Ooops, sorry, I actually left this ponderous comment on whether I should slice out outliers in days_listed by accident! Still, thank you, I wasn't really sure about it 100%, but after trying it out I decided not to do it anyway, and obviously, forgot to wipe the comment 😅
# <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review<a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, thank you for explanation!

# %% [markdown]
# ### Types of car: popularity and price

# %% [markdown]
# Let's proceed and see which types of car are the most popular, as in, most often on sale. That should be as simple as looking at value_counts of types. First, let's check out how the price differs depending on type. The most comfortable way to do that would be to look at a combined boxplot graph:

# %%
good_data[['price', 'type']].boxplot(by = 'type', figsize = (14, 10))
plt.title('Price distribution by type')
plt.xlabel('Type of car')
plt.ylabel('Price')
plt.show()

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> If I may ask you, do you know, by chance, how to fix that red deprecation warning coming out below the code? I can see it's not critical to the code, but I've tried inserting dtype=object as it seems to suggest (I listed it as an argument to the boxplot), but that didn't work. <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review<a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, you have two options:
#
# 1) ignore warnings at all, using smth like this:
#
# `import warnings
# warnings.filterwarnings("ignore")`
#
# about warnings control:
#
# https://docs.python.org/3/library/warnings.html
#
# 2) try to implement other decision, because still the warnings are important, materail about this warning:
#
# https://stackoverflow.com/questions/63097829/debugging-numpy-visibledeprecationwarning-ndarray-from-ragged-nested-sequences

# %% [markdown]
# Interesting! We can see that pickups and trucks seem to be, on average, the most expensive. Cars like sedan, which imply a simpler complexion and less power than most other categories like SUVs, mini-vans, pickups and others, are cheaper too, so that makes sense. We can also see that there does seem to be a distinction between trucks and pickups after all: if our earlier assumption about trucks being slightly more powerful is right, then that should justify a higher median price for them. We should be wary about some of the values plotted above, however: remember that despite buses' impressive price range, they are a vanishingly small sample – only 24 or so. That's likely the reason why boxplotting their prices doesn't really give us meaningful graphical representation in terms of evaluating where a whisker should be, so it just lands on the highest value, leaving no outliers.

# %% [markdown]
# We can also make bar charts sorted by the median and mean values.

# %%
good_data.pivot_table(index = 'type', values = 'price', aggfunc = 'median').sort_values(by = 'price', ascending = True).plot(kind = 'barh')
plt.title('Types sorted by median prices')
plt.xlabel('Price (median)')
plt.ylabel('Type')
plt.show()

# %%
good_data.pivot_table(index = 'type', values = 'price', aggfunc = 'mean').sort_values(by = 'price', ascending = True).plot(kind = 'barh')
plt.title('Types sorted by mean prices')
plt.xlabel('Price (mean)')
plt.ylabel('Type')
plt.show()

# %%
len(good_data.query('type == "bus"'))
# Out:
# 24

# %% [markdown]
# If we look at the bar chart for mean values, this reminder about the number of buses in our dataset will tell us that it's best we use median values for reference!

# %% [markdown]
# OK. Finally, let's see which ones are actually the most on sale!

# %%
good_data['type'].value_counts().sort_values(ascending = True).plot(kind = 'barh')
plt.title('Types of cars by count')
plt.xlabel('Amount of cars')
plt.ylabel('Type')
plt.show()

# %% [markdown]
# Sedans and SUVs, roughly under 12000 ads per each. Let's just compare their price distribution side by side with a boxplot:

# %%
good_data.query('type in (["SUV", "sedan"])')[['price', 'type']].boxplot(by = 'type')
plt.title('Price distribution for SUVs and sedans')
plt.xlabel('Type')
plt.ylabel('Price')
plt.show()

# %%
good_data.query('type == "SUV"')['price'].describe()
# Out:
# count    11612.000000
# mean     10747.756889
# std       7105.043473
# min        179.000000
# 25%       5316.500000
# 50%       8980.000000
# 75%      14900.000000
# max      34999.000000
# Name: price, dtype: float64

# %%
good_data.query('type == "sedan"')['price'].describe()
# Out:
# count    11691.000000
# mean      7064.823882
# std       4203.946806
# min        105.000000
# 25%       3995.000000
# 50%       5999.000000
# 75%       9295.000000
# max      33390.000000
# Name: price, dtype: float64

# %% [markdown]
# We can see that these types are quite different: the median price for a sedan is 6000, and a median SUV is roughly 3000 more expensive at 8980.

# %%
good_data.query('type == "SUV"')['price'].hist(alpha = 0.5, color = 'orange')
good_data.query('type == "sedan"')['price'].hist(alpha = 0.5, color = 'blue')

plt.title('Distribution of prices for SUVs and sedans')
plt.xlabel('Price')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# We can also see that SUVs have a wider price range, and the pricings are more spread out, too, and so their prices are not as concentrated at the peak as they are for sedans. For both this range (it looks like) is around 5 to 8 thousand.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, the two most advertised types of vehicles are identified correctly, good job!

# %% [markdown]
# ### Price formation

# %% [markdown]
# The two most popular types of car in our dataset happen to be SUV and sedan. Let's find out if and how the other factors like `age`, `mileage`, `condition`, `transmission` type and `color` affect the price of these types of cars. Let's start by slicing out the data we need:

# %%
suvs = good_data.query('type == "SUV"')
sedans = good_data.query('type == "sedan"')

# %% [markdown]
# #### Age

# %% [markdown]
# Let's start by looking at scatterplots

# %%
suvs.plot(kind = 'scatter', x = 'price', y = 'age', alpha = 0.1, figsize = (10, 6))
plt.title('SUV prices by age')
plt.show()
sedans.plot(kind = 'scatter', x = 'price', y = 'age', alpha = 0.1, figsize = (10, 6))
plt.title('Sedan prices by age')
plt.show()

# %% [markdown]
# Alright, so there does seem to be a correlation there: we can see how data spreads to the right as the age decreases (the newer the car), and vice versa, so that makes sense, even though it's a bit cloudy with the scatterplots. We can also look at the outline of this pattern if we just plot a line graph with the respective median values:

# %%
suvspt = suvs.pivot_table(index = 'age', values = 'price', aggfunc = 'median')
suvspt['age'] = suvspt.index
suvspt.plot(x = 'age', y = 'price')
plt.xlim(0, 30)
plt.ylim(0, 30000)
plt.title('SUV median price by age')
plt.ylabel('price')
plt.show()

# %%
sedpt = sedans.pivot_table(index = 'age', values = 'price', aggfunc = 'median')
sedpt['age'] = sedpt.index
sedpt.plot(x = 'age', y = 'price')
plt.xlim(0, 30)
plt.ylim(0, 30000)
plt.title('Sedan median price by age')
plt.ylabel('price')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# In case of these plots it seems to me that it ue better to fix the price on the y-axis and age on thex-axis.

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> Got it 👌 <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary: second iteration of the review<a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍</b>

# %% [markdown]
# Yup, it's a pattern! When plotting the medians though, we'd do well to keep in mind that for some ages the sample is much smaller, as can be guessed from looking at the scatterplot. Therefore we don't have to wreck our brains as to why the median line seems to tail in on itself up above 25 years, because those are very few observations and their pricing is more random:

# %%
suvs['age'].hist(bins = 30, alpha = 0.5, color = 'orange')
sedans['age'].hist(bins = 29, alpha = 0.5) #turns out there is no 30-year aged sedan ¯\_(ツ)_/¯
plt.title('Age distribution for SUVs and sedans')
plt.xlabel('Age')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# So plotting a line graph using median values, if possible, is helpful for seeing the pattern, but scatterplot is clerly better for seeing the dispersion and density. So maybe it's a good idea to have both.

# %% [markdown]
# We can also avail ourselves of the beautiful hexogram graphs, just for the visuals that they provide: let's see if they can reflect both the pattern and density of data that we need, but more concentratedly than scatterplots.

# %%
suvs.plot(x='price', y='age', kind='hexbin', gridsize=12, sharex=False, grid=True)
plt.title('SUVs')
plt.show()
sedans.plot(x='price', y='age', kind='hexbin', gridsize=12, sharex=False, grid=True) 
plt.title('Sedans')
plt.show()

# %% [markdown]
# Stunning. Although I must admit it takes some time to calibrate them with the right number of bins (I mean gridsize in their case), but we can still see how they reflect the same pattern for both SUVs and sedans. As a last step in exploring age's correlation with price, let's see look at the corr() measure:

# %%
suvs['age'].corr(suvs['price'])
# Out:
# -0.6430080613083778

# %%
sedans['age'].corr(sedans['price'])
# Out:
# -0.6677156243740162

# %% [markdown]
# So that shows quite a strong correlation actually, over halfway from 0 to -1 because in this case the relationship is inverted: the less the age (meaning the newer a car), the higher the price, and vice versa. And it's a bit stronger for sedans than for SUVs, which might be surprising at first if one looks at the curved line for median values.
#
# One explanation why the correlation is actually stronger for sedans is in the density of data on the scatterplot: it appears to be less dispersed than for SUVs, therefore, even though the price doesn't increase or fall as steeply depending on the age value, I guess it must nevertheless do so more often than for SUVs (that's why we see less points splattered outside of the dense cloudy line on the plot, as opposed to SUVs).

# %% [markdown]
# #### Mileage

# %%
suvs.plot(kind = 'scatter', x = 'price', y = 'mileage', alpha = 0.1, figsize = (10, 6))
plt.title('SUV prices by miles')
plt.show()
sedans.plot(kind = 'scatter', x = 'price', y = 'mileage', alpha = 0.1, figsize = (10, 6))
plt.title('Sedan prices by miles')
plt.show()

# %%
suvs.plot(x='price', y='mileage', kind='hexbin', gridsize=12, sharex=False, grid=True)
plt.title('SUVs')
plt.show()
sedans.plot(x='price', y='mileage', kind='hexbin', gridsize=12, sharex=False, grid=True)
plt.title('Sedans')
plt.show()

# %%
suvs['mileage'].corr(suvs['price'])
# Out:
# -0.6461968895423096

# %%
sedans['mileage'].corr(sedans['price'])
# Out:
# -0.6475587488881566

# %% [markdown]
# We can see a similar pattern when we plot mileage. It makes sense: the newer the car or the less worn out it is by driving (which is mostly how cars get worn out I suppose), the better the condition –> the higher a price a seller can put on it. Again though we see that the data appears more spread out for SUVs. And, interestingly, we see that the peak area at intersection of price and mileage is very similar for both types: under 150000 miles and around 4000 to 7000 thousand seems to be the most frequent bunch on sale.
#
# If we measure the correlation, however, we can see that for both SUVs and sedans mileage seems to be correlated with price on the same level of strength, which is more or less the same as age.

# %% [markdown]
# #### Condition

# %% [markdown]
# The best way to look at the relationship between categorical values like condition, transmission type or color and price would be to plot a boxplot containing the different categorical values on the x-axis. So let's start by looking at condition:

# %%
suvs[['price', 'condition_scale']].boxplot(by = 'condition_scale', figsize = (8, 5), grid = True)
plt.title("Price by condition for SUVs")
plt.ylabel('price')
plt.show()
sedans[['price', 'condition_scale']].boxplot(by = 'condition_scale', figsize = (8, 5), grid = True)
plt.title("Price by condition for sedans")
plt.ylabel('price')
plt.show()

# %% [markdown]
# Remember that for some of our conditions like new (5) and salvage (0) the samples can be very tiny. So it's best to not draw any conclusion just yet:

# %%
suvs['condition'].value_counts()
# Out:
# excellent    6044
# good         4156
# like new     1079
# fair          298
# salvage        20
# new            15
# Name: condition, dtype: int64

# %%
sedans['condition'].value_counts()
# Out:
# excellent    5828
# good         4193
# like new     1307
# fair          278
# new            46
# salvage        39
# Name: condition, dtype: int64

# %% [markdown]
# For both SUVs and sedans the amount of new and salvage cars are below 50%. Maybe if we look at the data for all our cars, we can make some conclusions about the condition and its relationship to price, but it's best not to make one based on just SUVs and/or sedans. But let's get back to the graphs above.
#
# There's definitely a difference in the price range, and median prices based on condition – we can see this looking at how the boxes for conditions 2, 3, 4 are positioned. For both types, the price, on average (as well as its range) increases as the condition of the car improves. And even though we shouldn't rely on those tiny samples of new and salvage cars, we still see how 'fair' falls behind 'good', which also makes sense.
#
# But can we put a number on it?

# %%
suvs['condition_scale'].corr(suvs['price'])
# Out:
# 0.29143681926781156

# %%
sedans['condition_scale'].corr(sedans['price'])
# Out:
# 0.31281653806572685

# %% [markdown]
# It seems the correlation is not super strong, but it's there. If the car is in good condition, you can expect a higher price. Also, if it's an SUV, I guess it matters a little bit less? A wild guess: SUVs are much sturdier in general than sedans, and more often used for heavy car duties outside of waiting in city traffic jams, and therefore their owners are less concerned about their condition... Seriously though, it still matters, and the difference between corr() measures is pretty small, so I wouldnt' be quick to draw conclusions from that.

# %% [markdown]
# #### Transmission type

# %% [markdown]
# We can use the same approach to look at transmission:

# %%
suvs[['price', 'transmission']].boxplot(by = 'transmission', grid = True)
plt.title("Price by transmission for SUVs")
plt.ylabel('price')
plt.show()
sedans[['price', 'transmission']].boxplot(by = 'transmission', grid = True)
plt.title("Price by transmission for sedans")
plt.ylabel('price')
plt.show()

# %%
suvs['transmission'].value_counts()
# Out:
# automatic    11044
# manual         477
# other           91
# Name: transmission, dtype: int64

# %%
sedans['transmission'].value_counts()
# Out:
# automatic    11051
# manual         570
# other           70
# Name: transmission, dtype: int64

# %% [markdown]
# That's interesting! So there is a difference between SUVs and sedans. From my limited experience, cars with manual transmission should either be cheaper because they tend to be older models (like, really old models), or it may be the opposite, because manual transmission may be preferred for 'sport' or 'offroad' mode, if the driver is inclined to race a little or be more nimble on the highway or something like that. So my explanation for the difference would be that the SUVs with manual transmission are likely that – more robust SUVs not just for driving around the city, but that you can actually challenge a little if you take it somewhere in the mountains or offroad.
#
# For good ol' sedans, it makes less sense to have manual transmission, unless it's like a sportscar. But in that case we'd have a separate type for that.
#
# For both types we have a very small 'other' transmission sample, and I struggle to think of it as anything other than a mixed transmission type where you can switch between automatic and manual transmission. And having that option would indeed warrant a higher price.

# %% [markdown]
# #### Color

# %% [markdown]
# Finally, let's look at how the price differs depending on the color:

# %%
suvs[['price', 'color']].boxplot(by = 'color', figsize = (12, 8), grid = False)
plt.ylim(0, 35000)
plt.title("Price by color for SUVs")
plt.ylabel('price')
plt.show()
sedans[['price', 'color']].boxplot(by = 'color', figsize = (12, 8), grid = False)
plt.ylim(0, 35000)
plt.title("Price by color for sedans")
plt.ylabel('price')
plt.show()

# %% [markdown]
# Interesting! The prices do seem to differ by color, more so for SUVs, in the range between 5 and 15 thousand if we look at median values, and 5 to 10 thousand for sedans. At first glance, more exotic colors like orange, green, purple and yellow tend to fall out of line – be either more expensive or cheap, on average. But let's check the amount of these cars:

# %%
suvs['color'].value_counts()
# Out:
# unknown    2083
# black      2019
# white      1837
# silver     1489
# grey       1130
# blue        991
# red         865
# green       411
# brown       353
# custom      271
# orange       80
# yellow       44
# purple       39
# Name: color, dtype: int64

# %%
sedans['color'].value_counts()
# Out:
# unknown    2106
# silver     2005
# black      1706
# grey       1579
# white      1440
# blue       1191
# red         892
# custom      265
# brown       254
# green       199
# purple       24
# yellow       21
# orange        9
# Name: color, dtype: int64

# %% [markdown]
# Hmm. So purple, yello and orange do seem to be 'outliers' in the sense that they are too small a sample to be considered in comparing prices in our case. Although orange does beat the mark for SUVs with 80 cars, and is priced at a premium to all other SUVs. But that's still a pretty small sample. A very popular color black seems to be associated with higher-priced SUVs compared to other popular colors like silver and white, compared to sedans, among which the median price for white cars is a bit higher.
#
# But the graph is a bit hard to read. Let's see if we can group SUVs and sedans by color and plot the median prices for them. For this one, we will only consider those colors of which there are more than 50:

# %%
new_suvs = suvs.pivot_table(index = 'color', values = 'price', aggfunc = ['median', 'count'])
new_suvs.columns = ['median', 'count']
plot_suvs = new_suvs.query('count > 50').sort_values(by = 'median', ascending = True).plot(kind = 'barh')
plt.title('SUVs sorted by median price for color')
plt.xlabel('price')
plt.show()

# %%
new_sedans = sedans.pivot_table(index = 'color', values = 'price', aggfunc = ['median', 'count'])
new_sedans.columns = ['median', 'count']
plot_sedans = new_sedans.query('count > 50').sort_values(by = 'median', ascending = True).plot(kind = 'barh')
plt.title('Sedans sorted by median price for color')
plt.xlabel('price')
plt.show()

# %% [markdown]
# Huh, so black is actually pricier, on average, for sedans too, not just for SUVs. I made a mistake in the previous markdown cell by looking at the boxplot. Should've used the gridlines...

# %% [markdown]
# But yes, looking at the median values is useful for overview. We should be wary of the scale on the x axis though, as the range is different for SUVs and sedans. But in relative values, it's almost the same order for both types (with some exception): the highest median price of the cars is associated with the color black, except for orange with SUVs...which still isn't very reliable because it's just 80 cars. White, grey, silver and red (but also custom) come in the middle, and brown, green in blue come cheaper.
#
# Although in the case of sedans, blue seems to be significantly more expensive on average than brown, which wins over for SUVs. But it helps that we have count plotted on the same graph: the ratio of blue to brown SUVs seems to be about 3:1, so I assume in the case of this two colors at least, it wouldn't be wise to make predictions.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Roman, you are doing great! Absolutely agree with the logic of your decision at this step of the analysis!

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# Some recommendations for this step of the analysis:
#
# * as for correlation (you need to conduct correclation analysis here) you can create one common correlation matrix for quantitative variables or visualize correlation analysis using heatmap plot. More information below:
#
# https://towardsdatascience.com/heatmap-basics-with-pythons-seaborn-fb92ea280a6c?gi=59629750b22d
#
# https://matplotlib.org/stable/gallery/images_contours_and_fields/image_annotated_heatmap.html
#
# https://blog.quantinsti.com/creating-heatmap-using-python-seaborn/
#
# https://datatofish.com/correlation-matrix-pandas/
#
# https://www.geeksforgeeks.org/create-a-correlation-matrix-using-python/
#
# * it is still important to fix the appearance of the plots, so please, remove technical strings, add the plots' title and x and y-axis labels where they are needed
#
# </div>

# %% [markdown]
# ### Conclusion

# %% [markdown]
# From what we have seen, age and mileage appear to be the factors most correlated with price of a car in our dataset. It's helpful to have all types of graphs that are appropriate for the types of data involved, as they can help us see the relationship in a more rounded way. For instance, we can definitely see the relationship by how curved the line is if we plot median values, as opposed to a proper scatterplot.
#
# The relationship between age and mileage and price is exactly what one would expect: the newer the car, the better its value on the market. And we could easily expect in 9 cases out of 10 for mileage to be closely correlated with age, for obvious reasons.
#
# It's a little more puzzling to see that the corr() coefficient for condition and price appears to be two times weaker than for mileage or age, even though we can see the relationship more or less clearly on the graph. Remember that our condition scale goes from 0 to 5 where 0 is salvage and 5 is (supposedly) new. For each of the 4 categories in between there appears to be a clear progression of these data points intersecting more often with higher values for price. I think there are two reasons for that (for the weaker correlation). Firstly, condition being a categorical value, we had to use boxplot, which is helpful, but a little deceiving in that it is easy to spot the progression, which is there, but harder to remind yourself that the boxes' ranges actually still overlap for (what looks like) the most part. After all, there are only so many conditions (6, or 4 with enough data to estimate correlation), and they inevitably capture a wider range of prices. The second reason for that is that condition, as it is originally collected and reflected in our dataset, is not as precise and reliable a value as mileage and age of the car, but is decided upon by the seller and is wildly subjective compared to the reading of the car's odometer. Perhaps if there was some kind of a precise condition index, computed based on age, mileage, number and severity of scratches, repairs, recorded accidents and so on, it would actually correlate with the price much more strongly.
#
#
# Transmission is a category for which we have disproportionate amount of data for the two types (automatic and manual), and too little data for mixed transmission, to see a difference in relationship. Based on the data we have, however, there is a difference for sedans and SUVs: it's quite self-explanatory for sedans that manual transmission cars are in most cases the more outdated models, and since they are not as well suited for the most drivers' purposes, they are less in demand. Therefore their median price is a couple thousand lower. With SUVs the opposite appears to be the case: they are at least two thousand or so more expensive, judging by the median value (however it is clear from the graph that most of their price values are, in fact, in the same range). If a corr() value could be computed for transmission and price, I wouldn't expect it to be very high, since the two values (if we don't count the mixed type), cover almost every other possible combination of factors. But I suppose it makes sense that manual transmission is more suited for some people's purposes and demands from a car. Since it implies more precise control over transmission, it may well be something that could be valuable to SUV owners more often, so for that type of car it's more a valuable feature, than a useless and cumbersome transmission mechanism, as it is likely perceived by unassuming sedan-owning city drivers.
#
# For colors it's bit more tricky, since we can definitely guess that color is a factor that likely doesn't determine a car's price directly, but can rather be associated with a set of other features that do that. For instance, red or yellow could in some cases be disproportionately more popular with some kind of expensive sportcar-like vehicles. Whilst black could more often be the color of choice for 'representative' class sedans and SUVs purchased by corporations or used by government officials, or something else like that. For our dataset, it is most likely the case that black (along with white and silver) are simply the most popular color in general and therefore capture a wider price range. My subjective guess for the rest of the colors would be that such colors as green or brown could be associated with older cars, and purple is...priceless. There is the weird case of orange color being wildly outside the range, both for SUVs and sedans. I really struggle to think of a reason for that. I even struggle to remember the last time I have seen an orange car. But I think it's safe to assume this is a case of some local outlier values, because there are still only 80 of those cars in the case of SUVs, and less than 50 among sedans. If one looks at the data for those sedans though, one will see some fancy and pretty expensive Dodge cars, that look like sportcars to me. Case in point: it's a small selection and wacky color for most people, but it looks well on a limited selection of cars that happen to be more expensive.

# %% [markdown]
# ## Overall conclusion

# %% [markdown]
# The data that we received for the listings on our website was quite broad. It doesn't appear to have any duplicated rows, which made the initital steps easier to an extent, but it would be a good idea to consider including some kind of a unique identifier per user in the future, which would enable the analyst to parse the listings better, because it is not certain that some cars wouldn't be listed twice or more times, but it would be difficult to spot them.
#
# Preprocessing the data made me discover the relationship between different parts of the dataset. For example, in order to restore a (substantial) number of missing values in model_year, I first remembered that age of the car is something that I'll need to explore deeper further on, and so I really did need to restore them, and secondly considered how that might depend on other data points such as model of the car and its mileage. This call seems to have been proven right in the end, judging by how similar the correlation coefficient is for age and mileage when measured against price. This time I could use the advantages of corr function and plots like histogram at preprocessing stage to see whether my assumptions check out. I also encountered new difficulties, for instance when trying to restore values for cylinders, which is really a categorical values, although expressed numerically – but I was able to come up with a relatively simple function that applied mode that doesn't return incorrect values (which the programme doesn't know are incorrect). Another one was color: a substantial number of values were missing, and I had to make a call not to restore them, because to the best of my judgement, I couldn't see a way how to restore them so that it made sense, and so I decided to pack them into 'unknown' category.
#
# When considering which data to use, I decided to trust the distribution as exhibited in a boxplot, in order to cut at the points where outliers begin. However, again, in most cases, it helps to study the data a bit deeper and see whether it will actually make sense to slice out large chunks of it, and to think of the implications – I will make sure to consider this in the future. One case in point is when measuring outliers in such numerical categories as mileage. Surely there is not much use in entries below a thousand miles if they do not add up to a substantial percentage of the dataset. But then we have cars that are listed as brand new or almost new, and slicing out that subset could mean distorting the distribution of conditions of cars in our data.
#
# We saw that most of our cars were advertised for about a month before being sold (presumably?). Of course we don't have enough data to think why exactly a listing could go down. Although it could be gathered in the future by asking users to fill out surveys perhaps. Otherwise we don't really have enough data to judge as to why an ad could be removed on the first day or during the first week. Personally, such sales appear to be too quick to me. But generally, the majority of our ads stayed up from a week to 3 months or so.
#
# The price of the cars, it appears, it mostly correlated with age and mileage (which in turn correlate with each other). It is pretty straightforward: newer, less 'worn out' cars are sold at a higher price. This is true across types (we studied it using the examples of SUVs and sedans). However, when it comes to other characteristics like transmission and color, and even condidion (to an extent), they have a different relationship with price depending on the type of vehicle. This could be explained by the purposes for which people own cars, as well as by somewhat idiosyncratic factors like certain models just being popular in signature colors (like orange). On a methodological note, it helps using a variety of plot types to study these relationships, but we should always keep in mind the size of our samples, like with wacky colors or curved lines when plotting median values.

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **The overall review conclusion**
#
#
# Roman, thank you for submitting your project! I can see that you've worked really hard on it! You did a great job to bring the project to completion, thanks for your patience and desire to complete the project! But there are several things in your project which I suppose it is important to fix in order to make your project really ideal! My comments will navigate you!
#
# **Good things and practices in your project I want to highlight🙂**:
# * You used different methods for working with your data. It is really great that you can apply these methods on practice, keep it up!
# * You used visualization a lot, good job!
# * You formulated deep and comprehensive conclusions after the each step of the analysis, good job, I can see your analytical approach.
#
# **What is worth working on👀**:
#
# * It is important to work on the plots' appearance.
# * You can find other recommendations in my comments, all of them are not critical at all!
#
#
# **Good luck! I will wait for your work for a second iteration of the review!😉**
#
# ![gif](https://media.giphy.com/media/l3UcjBJUov1gCRGbS/giphy.gif)

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **The overall review conclusion: second iteration of the review**
#
# Roman, thank you for submitting your project with corrections! And thank you for your feedback too, I really appreciate it😊
#
# You did a great job to improve the project, I can see your progress, so I hasten to say that your project has been accepted and you can proceed to the next sprint!
#
# **I wish you exciting and cool projects in the next sprints😉**
#
# ![gif](https://media.giphy.com/media/j1Xyt3DHfJcmk/giphy.gif)

# %% [markdown]
# # Project completion checklist
#
# Mark the completed tasks with 'x'. Then press Shift+Enter.

# %% [markdown]
# - [x]  file opened
# - [x]  files explored (first rows printed, info() method)
# - [x]  missing values determined
# - [x]  missing values filled in
# - [x]  clarification of the discovered missing values provided
# - [x]  data types converted
# - [x]  explanation of which columns had the data types changed and why
# - [x]  calculated and added to the table: day of the week, month, and year the ad was placed
# - [x]  calculated and added to the table: the vehicle's age (in years) when the ad was placed
# - [x]  calculated and added to the table: the vehicle's average mileage per year
# - [x]  the following parameters investigated: price, vehicle's age when the ad was placed, mileage, number of cylinders, and condition
# - [x]  histograms for each parameter created
# - [x]  task completed: "Determine the upper limits of outliers, remove the outliers and store them in a separate DataFrame, and continue your work with the filtered data."
# - [x]  task completed: "Use the filtered data to plot new histograms. Compare them with the earlier histograms (the ones that included outliers). Draw conclusions for each histogram."
# - [x]  task completed: "Study how many days advertisements were displayed (days_listed). Plot a histogram. Calculate the mean and median. Describe the typical lifetime of an ad. Determine when ads were removed quickly, and when they were listed for an abnormally long time.  "
# - [x]  task completed: "Analyze the number of ads and the average price for each type of vehicle. Plot a graph showing the dependence of the number of ads on the vehicle type. Select the two types with the greatest number of ads. "
# - [x]  task completed: "What factors impact the price most? Take each of the popular types you detected at the previous stage and study whether the price depends on age, mileage, condition, transmission type, and color. For categorical variables (transmission type and color), plot box-and-whisker charts, and create scatterplots for the rest. When analyzing categorical variables, note that the categories must have at least 50 ads; otherwise, their parameters won't be valid for analysis.  "
# - [x]  each stage has a conclusion
# - [x]  overall conclusion drawn
