# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# <b>Hello, Roman!👋 How are you today?</b>
#
# My name is Arina U. and I am glad to be your reviewer in this project!It seems to me that we've already met with you in one of the previous sprint, if so, nice to meet you again! <br />
#
#
# You can find my comments in <font color='green'>green</font>, <font color='gold'>yellow</font> and <font color='red'>red</font> boxes. Examples you can see below:
#
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b> In case if task is completely correct and everything is alright!
# </div>
#
#
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>  In case when I can give some advice that can help you to improve your work or recommend you some useful links and resources that can help you widen your knowledge and help in future tasks.
# </div>
#
# <div class="alert alert-block alert-danger">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Needs fixing!🤔:</b> In case when step requires some extra work and some corrections. Project can't be accepted with comments in the red boxes
# </div>
#
# Please pay attention to not move or change my comments. It would be good to highlight your answers in some way.
#
# #### <font color='Purple'>Student's commentary:</font> for example like this <a class="tocSkip"> </div>
#
# OK, now let's go!😏
# </font>

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> Hi Arina! I remember, and it's nice to see you again! Since my first project was accepted right away I couldn't resubmit so you probably didn't see my thanks ^^ So I'll say it again: thank you so much for taking the time to review my first project, and for reviewing this one too, of course! Your first review helped me immensely and all the tips are super appreciated! <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary:second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Hello, Roman! Glad to hear from you so soon! Thank you too for your feedback, I appreciate it too, it's nice to know that review and my comments were useful!
# </div>

# %% [markdown]
# # Integrated Project 1: Video game sales research

# %% [markdown]
# For this project, I'm an analyst with the video game online store called Ice. We've put together some data on sales, platforms, critic and user reviews, going back to 2016. It's the end of the year, in fact, and we are about to study this data in detail to see what the trends are going into 2017, so that we can allocate the right amount of resources for advertising and focus on the products and platforms that have the biggest potential in terms of bringing revenue.
#
# \
# ***Description of the data***
#
# \
# The data that I have my hands on for this project has the following entries:
#
# `Name` - name of the game\
# `Platform` - platform (PlayStation, Xbox, etc.)\
# `Year_of_Release` - the year the game was released\
# `Genre` - genre (sports, fantasy, etc.)\
# `NA_sales` - North American sales in USD million\
# `EU_sales` - sales in Europe in USD million\
# `JP_sales` - sales in Japan in USD million\
# `Other_sales` - sales in other countries in USD million\
# `Critic_Score` - on a scale up to 100\
# `User_Score` - on a scale up to 10\
# `Rating` - ESRB (Entertainment Software Rating Board - assigns age rating like Teen or Mature based on the game's contents)
#
# \
# ***Project outline***
#
# \
# I'm going to carry out the project by implementing the following steps:
#
# **Step 1: study the data in the files**
#
# I'm going to study the data in the file to see what we got
#
# **Step 2: prepare and preprocess the data**
#
# I'm going to deal with missing values if necessary, change datatypes where appropriate and decide if I need to add any additional categories or calculations based on the existing data to aid in further analysis
#
# **Step 3: analyse the data**
#
# In this section I will perform the following analytical taks to answer the respective questions about the data:
#
# - Look at how many games were released in different years. Is the data for every period significant?
# - Look at how sales varied from platform to platform. Choose the platforms with the greatest total sales and build a distribution based on data for each year. Find platforms that used to be popular but now have zero sales. How long does it generally take for new platforms to appear and old ones to fade?
# - Determine what period we should take data for. To do so, review answer to the previous questions. The data should allow Ice to build a prognosis for 2017. Continue working only with the data that we've picked as relevant and disregard the data for years up to that, in answering the following questions
# - Which platforms are leading in sales? Which ones are growing or shrinking? Select several potentially profitable platforms
# - Build a box plot for the global sales of all games, broken down by platform. Are the differences in sales significant? What about average sales on various platforms? Describe the findings
# - Look at how user and professional reviews affect sales for one popular platform of our choice (based on previous findings). Build a scatter plot and calculate the correlation between reviews and sales & draw conclusions
# - Keeping our conclusions in mind, compare the sales of the same games across platforms. Look at the general distribution of games by genre. What can we say about the most profitable genres? Can we generalize about genres with high and low sales?
#
# **Step 4: create user profile for each region**
#
# In this extension of our analysis, I'll do the following:
#
# For each of the regions (NA, EU and Japan) I'll determine the top 5 platforms and 5 genres (separately), and describe the variations in market share between them across regions. Additionally, I'll look at whether the ESRB rating has an effect on sales in any of the regions
#
# **Step 5: hypothesis testing**
#
# In this section I'll employ statistical methods to test the following hypotheses:
#
# - "Average user ratings of the Xbox One and PC platforms are the same"
# - "Average user ratings for the Action and Sports genres are different"
#
# **Step 6: overall conclusion**
#
# Finally, I'll write an overall conclusion to reflect back on our findings and to give some tentative recommendations for Ice going into 2017

# %% [markdown]
# ## Open the data files and study the general information

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy import stats as st

# %%
# !pip install -U seaborn=='0.11.0'
# Out:
# ...
#
# [notice] A new release of pip available: 22.2.1 -> 22.2.2
# [notice] To update, run: pip install --upgrade pip

# %%
import seaborn as sns

# %%
sns.__version__
# Out:
# '0.12.0'

# %%
pip install --upgrade pip
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
pip install sidetable
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sidetable

# %%
data = pd.read_csv('/Users/rv/Desktop/practice_datasets/games.csv')

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# I would like to recommend you to use `try-except` construction for importing of the data. More details see on the links below:
#
# https://www.w3schools.com/python/python_try_except.asp
#
# https://docs.python.org/3/tutorial/errors.html
#
# Some more interesting materials about using od the construction:
#
# https://www.programiz.com/python-programming/exception-handling
#
# https://towardsdatascience.com/do-not-abuse-try-except-in-python-d9b8ee59e23b
#
# https://www.techbeamers.com/use-try-except-python/
# </div>

# %% [markdown]
# Let's just see what it looks like:

# %%
data.head()
# Out:
#                        Name Platform  Year_of_Release         Genre  NA_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    EU_sales  JP_sales  Other_sales  Critic_Score User_Score Rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# And now to some basic info:

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16713 non-null  object
#  1   Platform         16715 non-null  object
#  2   Year_of_Release  16446 non-null  float64
#  3   Genre            16713 non-null  object
#  4   NA_sales         16715 non-null  float64
#  5   EU_sales         16715 non-null  float64
#  6   JP_sales         16715 non-null  float64
#  7   Other_sales      16715 non-null  float64
#  8   Critic_Score     8137 non-null   float64
#  9   User_Score       10014 non-null  object
#  10  Rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# So I'm just wondering, how many unique games we are dealing with..

# %%
data['Name'].nunique()
# Out:
# 11559

# %%
data.head(20)
# Out:
#                                             Name Platform  Year_of_Release  \
# 0                                     Wii Sports      Wii           2006.0
# 1                              Super Mario Bros.      NES           1985.0
# 2                                 Mario Kart Wii      Wii           2008.0
# 3                              Wii Sports Resort      Wii           2009.0
# 4                       Pokemon Red/Pokemon Blue       GB           1996.0
# 5                                         Tetris       GB           1989.0
# 6                          New Super Mario Bros.       DS           2006.0
# 7                                       Wii Play      Wii           2006.0
# 8                      New Super Mario Bros. Wii      Wii           2009.0
# 9                                      Duck Hunt      NES           1984.0
# 10                                    Nintendogs       DS           2005.0
# ...

# %%
data.query('Name == "Grand Theft Auto: San Andreas"')
# Out:
#                                 Name Platform  Year_of_Release   Genre  \
# 17     Grand Theft Auto: San Andreas      PS2           2004.0  Action
# 875    Grand Theft Auto: San Andreas       XB           2005.0  Action
# 2115   Grand Theft Auto: San Andreas       PC           2005.0  Action
# 10311  Grand Theft Auto: San Andreas     X360           2008.0  Action
#
#        NA_sales  EU_sales  JP_sales  Other_sales  Critic_Score User_Score  \
# 17         9.43      0.40      0.41        10.57          95.0          9
# 875        1.26      0.61      0.00         0.09          93.0        8.6
# 2115       0.00      0.93      0.00         0.04          93.0        8.9
# 10311      0.08      0.02      0.00         0.01           NaN        7.5
#
#       Rating
# 17         M
# 875       AO
# 2115       M
# 10311      M

# %% [markdown]
# OK, so it looks like some of the games (quite a few) are likely to be 'repeated', but that's because they are released for different platforms, which may also happen in different years. Otherwise this column is fine except for the two missing values. Let's see what they are:

# %%
data.loc[data['Name'].isnull()]
# Out:
#       Name Platform  Year_of_Release Genre  NA_sales  EU_sales  JP_sales  \
# 659    NaN      GEN           1993.0   NaN      1.78      0.53      0.00
# 14244  NaN      GEN           1993.0   NaN      0.00      0.00      0.03
#
#        Other_sales  Critic_Score User_Score Rating
# 659           0.08           NaN        NaN    NaN
# 14244         0.00           NaN        NaN    NaN

# %% [markdown]
# I was born around that time so I've never even heard of a platform called 'GEN'.

# %%
data.query('Platform == "GEN" and Year_of_Release == 1993')
# Out:
#                                                     Name Platform  \
# 659                                                  NaN      GEN
# 7885                                    Shining Force II      GEN
# 8893                             Super Street Fighter II      GEN
# 11986                            Ecco: The Tides of Time      GEN
# 12098  Street Fighter II': Special Champion Edition (...      GEN
# 12264                                  Streets of Rage 3      GEN
# 12984                                    Dynamite Headdy      GEN
# 13343                                       Beyond Oasis      GEN
# 14244                                                NaN      GEN
#
#        Year_of_Release         Genre  NA_sales  EU_sales  JP_sales  \
# 659             1993.0           NaN      1.78      0.53      0.00
# 7885            1993.0      Strategy      0.00      0.00      0.19
# 8893            1993.0      Fighting      0.00      0.00      0.15
# ...

# %% [markdown]
# Looks like not too many games were released on GEN that year. As for the two missing values, we are also missing their genre names and, for the most part sales, too (althought the latter are not really 'missing values', they might just be zero sales in that region). So we don't really have any info on them to go by, and they're just two relic games from 1993 for GEN, so we shouldn't worry over them too much. They are unlikely to impact our analysis, however they can mess with our data when we try to group and plot it in the future, so I suggest we get rid of them in Step 2.

# %% [markdown]
# Now let's look at the platforms:

# %%
data['Platform'].describe()
# Out:
# count     16715
# unique       31
# top         PS2
# freq       2161
# Name: Platform, dtype: object

# %% [markdown]
# So PS2 is the most popular one, it seems, as per our dataset, which in this case doesn't measure popularity among players or sales of platforms, but it does point at it indirectly: it means it's the platform for which the largest number of games were released throughout these years (just during the years when this platform was in use, mind you!), and that surely couldn't happen without a reason. Let's see what the others are:

# %%
data['Platform'].unique()
# Out:
# array(['Wii', 'NES', 'GB', 'DS', 'X360', 'PS3', 'PS2', 'SNES', 'GBA',
#        'PS4', '3DS', 'N64', 'PS', 'XB', 'PC', '2600', 'PSP', 'XOne',
#        'WiiU', 'GC', 'GEN', 'DC', 'PSV', 'SAT', 'SCD', 'WS', 'NG', 'TG16',
#        '3DO', 'GG', 'PCFX'], dtype=object)

# %% [markdown]
# I think I only understand PS and Xbox among these (apart from PC)...let's look at counts:

# %%
data['Platform'].value_counts()
# Out:
# PS2     2161
# DS      2151
# PS3     1331
# Wii     1320
# X360    1262
# PSP     1209
# PS      1197
# PC       974
# XB       824
# GBA      822
# GC       556
# 3DS      520
# PSV      430
# PS4      392
# N64      319
# XOne     247
# SNES     239
# SAT      173
# WiiU     147
# 2600     133
# NES       98
# GB        98
# DC        52
# GEN       29
# NG        12
# SCD        6
# WS         6
# 3DO        3
# TG16       2
# GG         1
# PCFX       1
# Name: Platform, dtype: int64

# %% [markdown]
# OK, I felt obliged to google to at least know that DS stands for Nintendo. We can see GEN down there with a paltry 29 entries (that's including two nameless genreless games). But seriously, these numbers are helpful for perspective: we have data up to 2016, and we can imagine how these statistics would be different by now, most likely, with new generation platforms (PS4, and whatever came after that...) and more and more games coming out.

# %% [markdown]
# Now let's look at the years of release:

# %%
data['Year_of_Release'].describe()
# Out:
# count    16446.000000
# mean      2006.484616
# std          5.877050
# min       1980.000000
# 25%       2003.000000
# 50%       2007.000000
# 75%       2010.000000
# max       2016.000000
# Name: Year_of_Release, dtype: float64

# %%
sns.histplot(data, x = 'Year_of_Release')
plt.title('Distribution of year_of_release')
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Needs fixing!🤔:</b>
#
# Code provide error here. As for seaborn it is important not simply upgrade it but upgrade to the concrete version, the same version that you use at your local machine.
#
# ![image.png](attachment:image.png)
# </div>

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font>  Absolutely! And thank you, I was wondering what the problem was, because it gave me errors from time to time with plots failing to execute. I made sur to restart the kernel and run all cells again so that everything was in place when submitting, but looks like that didn't cut it. I've fixed it now (at least I hope so!) by specifying the concrete version to install, and placed the import last in line because it requires other libraries to work smoothly (as per the documentation website). I hope it works on resubmission! <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary:second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# This time everything is alright, the code works correctly!

# %% [markdown]
# We'll make a prettier graph later to get a better look at it, this is just to get an idea of when we start seeing a lot of games being released. It looks like after 2000 thousand is a good threshold to mark the beginning of a kind of expansion age for the games industry.

# %% [markdown]
# We don't really know what happened around 2009. I don't know if the financial crisis had any major impact on the game industry, although I suppose it could very well have impact in terms of reduced purchases of games which could lead to fewer releases, but then one would have to explain why it would hold through until 2016. One could speculate that perhaps around the same time companies shifted business strategy toward producing less new games overall, narrowing it down to dependable franchises, or maybe around the same time some platforms just died off. Anyway we don't have enough data to look for and provide such a macro level explanation, it's just something to note.

# %% [markdown]
# We should also note that we have a few hundred missing values in this column:

# %%
data['Year_of_Release'].isnull().sum()
# Out:
# 269

# %% [markdown]
# Let's check how many games are missing year of release:

# %%
len(data.loc[data['Year_of_Release'].isnull()]['Name'].unique())
# Out:
# 232

# %%
data.loc[data['Year_of_Release'].isnull()]['Name'].unique()
# Out:
# array(['Madden NFL 2004', 'FIFA Soccer 2004',
#        'LEGO Batman: The Videogame', 'wwe Smackdown vs. Raw 2006',
#        'Space Invaders', 'Rock Band',
#        "Frogger's Adventures: Temple of the Frog",
#        'LEGO Indiana Jones: The Original Adventures', 'Call of Duty 3',
#        'Call of Duty: Black Ops', 'Triple Play 99', 'Adventure', 'Combat',
#        'LEGO Harry Potter: Years 5-7', 'NASCAR Thunder 2003',
#        'Hitman 2: Silent Assassin', 'Legacy of Kain: Soul Reaver',
#        'Donkey Kong Land III', 'Air-Sea Battle', 'Suikoden III',
#        'Wheel of Fortune', 'Yakuza 4', 'Namco Museum', 'Rhythm Heaven',
#        'The Lord of the Rings: War in the North', 'Madden NFL 07',
#        'MLB SlugFest 20-03', 'Shaun White Snowboarding',
#        'PES 2009: Pro Evolution Soccer', 'WarioWare: Twisted!',
#        'Madden NFL 11', 'Test Drive Unlimited 2',
#        'The Chronicles of Narnia: The Lion, The Witch and The Wardrobe',
# ...

# %%
data.loc[data['Year_of_Release'].isnull()]['Platform'].unique()
# Out:
# array(['PS2', 'Wii', '2600', 'X360', 'GBA', 'PC', 'PS3', 'PS', 'PSP',
#        'XB', 'GB', 'DS', 'GC', '3DS', 'N64', 'PSV'], dtype=object)

# %% [markdown]
# So we can see that the missing year of release has not impacted every platform. I suppose some of the games would have been released on more than one platform. In that case, we can fill in the missing value with the median value of year of release based on the game's name. But that's not always the case:

# %%
data.query('Name == "Advance Wars: Days of Ruin"')['Platform'].unique()
# Out:
# array(['DS'], dtype=object)

# %% [markdown]
# In a case like this, the second best option would be to fill the missing value with median value for year of release based on the platform, since platforms typically are more popular during a given time period. This way we'll restore missing values, and while we might get wrong years for some of the games for lack of a more precide reference, this shouldn't distort our year of release distribution too much since this will be only between a hundred to two hundred games (depending on how many of them have year_of_release present for a different platform). We can do this in Step 2.

# %% [markdown]
# Let's look at genres:

# %%
data['Genre'].value_counts()
# Out:
# Action          3369
# Sports          2348
# Misc            1750
# Role-Playing    1498
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       873
# Fighting         849
# Strategy         683
# Puzzle           580
# Name: Genre, dtype: int64

# %% [markdown]
# I assume Misc stands for miscellaneous? Otherwise this breakdown makes sense more or less. I would also assume that it could vary from platform to platform, say, with strategy or shooter being more popular on average on PCs, and sports being more frequently released for platforms like PS and Xbox... We can see from info that there are two rows with missing values in this column, but as we know this must be the same mysterious game from 1993 on GEN. That game is literally in oblivion (never played the game, but pun intended).

# %% [markdown]
# Now let's look at the sales figures. We can look at all four segments at once:

# %%
data[['NA_sales', 'EU_sales', 'JP_sales', 'Other_sales']].describe()
# Out:
#            NA_sales      EU_sales      JP_sales   Other_sales
# count  16715.000000  16715.000000  16715.000000  16715.000000
# mean       0.263377      0.145060      0.077617      0.047342
# std        0.813604      0.503339      0.308853      0.186731
# min        0.000000      0.000000      0.000000      0.000000
# 25%        0.000000      0.000000      0.000000      0.000000
# 50%        0.080000      0.020000      0.000000      0.010000
# 75%        0.240000      0.110000      0.040000      0.030000
# max       41.360000     28.960000     10.220000     10.570000

# %% [markdown]
# This gives us a sense of the markets: we can see that North America is the largest market with the other three segments following in the same order in which they are laid out from left to right. We can also see that there is a higher dispersion of values, in respective order, with NA region recording some fantastic sales figures that really pull the mean value up. And we see that a lot of games, perhaps, are simply not released to all regions, with Japan having a median sales value of 0, which is strange. It is strange, too, that the 25% quantile values is 0 for other regions too. But since these are zeros mixed in among numbers it is hard to say whether they should be treated as missing values.

# %%
len(data.query('NA_sales == 0 and EU_sales == 0 and JP_sales == 0 and Other_sales == 0'))
# Out:
# 2

# %% [markdown]
# Yeah – there are only two games with 0 sales across all regions, so the amount of zeros overall which is quite high is likely due to this segmentation by region for certain releases. Pretty common for entertainment industry I suppose, including music and films, to designate a release to a certain region. It's also possible that for some older or not even older, but not very popular games it was much harder to come by their sales figures (or maybe they weren't even published). It is possible, too, that recent sales figures could be unavailable for new releases of relatively niche games, unlike big franchises like FIFA sports or such that might monitor these numbers on a quarterly or even monthly basis. Let's move on to critic scores.

# %%
data['Critic_Score'].describe()
# Out:
# count    8137.000000
# mean       68.967679
# std        13.938165
# min        13.000000
# 25%        60.000000
# 50%        71.000000
# 75%        79.000000
# max        98.000000
# Name: Critic_Score, dtype: float64

# %% [markdown]
# So we see that just over a half of values in critics' scores are missing vlaues. It is on a scale of 0 to 100, it seems, and the most satisfied critic only ever gave a 98 grade review, with the worst review scoring a 13.

# %%
sns.histplot(data, x = 'Critic_Score')
plt.title("Distribution of scores")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Needs fixing!🤔:</b>
#
# Error again: I suppose all the cells with seaborn plots will provide errors due to the versions difference.
#
# ![image.png](attachment:image.png)
#
# Common recommendation: before submitting the project for review it is better to restarn kernel and run all cells to check if the code works correctly at the platform:
#
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> Again, sorry for this mess with seaborn plots. Hopefully it should be fixed now! <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary:second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Yes, it works correctly, good job!

# %%
data['User_Score'].isnull().sum()
# Out:
# 6701

# %% [markdown]
# We've almost just as many user scores missing. It's most likely that both critic and user reviews are just not available for every game that gets released. Games that were not very popular, or that were barely sold to anyone, naturally get less coverage from the critics, if any. Same works for the users, with the added factor that not everyone publicly reviews whatever products they purchase (I never leave reviews unless for detailed feedback), and when they do, it's likely to disproportionately be headed the most popular games' way since people will be more likely to complain about a bug or praise it, or leave a comment for the sake of participating in some kind of a promotional campaign or offer ("leave a comment / share with your friends to receive or unlock a bonus", etc.). And then again, some of it may be due to the time difference. It could be harder to find user feedback for some legacy games from the 1990s or even early 2000s, I imagine. Not as many people even had Internet back then. In fact, let's check this:

# %%
scores_count = data.pivot_table(index = 'Year_of_Release', values = 'Critic_Score', aggfunc = 'count')
scores_count['Year_of_Release'] = scores_count.index
scores_count.plot(x = 'Year_of_Release', y = 'Critic_Score')
plt.show()

# %% [markdown]
# Case in point! Critic reviews only really started coming in in 2000.

# %% [markdown]
# Let's just double-check what the values in user scores look like:

# %%
data['User_Score'].describe()
# Out:
# count     10014
# unique       96
# top         tbd
# freq       2424
# Name: User_Score, dtype: object

# %% [markdown]
# So we know that user scores are measured on a scale from 0 to 10, but here we have a 'to be determined' value, it seems. For our purposes, it's as good as a miising value. (In fact, it seems that if we add them together, we'll get a total number of missing values in user scores that's very close to that in critics' scores).

# %% [markdown]
# I think it makes most sense to simply exclude missing values (and tbds) from our analysis when it comes to measuring something against the critics or users scores. There are way too many of them to restore so it would obviously distort the data, and besides, this is such a subjective value it's hard to predict for most of the games, except for maybe the most popular (most sold) ones.
#
# Let's move on to rating:

# %%
data['Rating'].describe()
# Out:
# count     9949
# unique       8
# top          E
# freq      3990
# Name: Rating, dtype: object

# %% [markdown]
# Well, the biggest number of games is one that's rated for everyone! As to the large number of missing values in Rating, I think the logic is the same here as for critic and user score. It's probably not even necessary to rate a game unless it is officially distributed in some way, or if it is hardly sold at all. It could also be the case that regulations regarding game rating in this way probably evolved from a low base over this period of time, roughly from the nineties, gradually picking up pace, so that's something to keep in mind. I bet if we build a graph of rating counts it will look the same as for critic scores:

# %%
r_count = data.pivot_table(index = 'Year_of_Release', values = 'Rating', aggfunc = 'count')
r_count['Year_of_Release'] = r_count.index
r_count.plot(x = 'Year_of_Release', y = 'Rating')
plt.show()

# %% [markdown]
# In fact let's see what the counts compare like for all games, critic and user scores and rating:

# %%
counts = data.pivot_table(index = 'Year_of_Release', values = ['Name', 'Critic_Score', 'User_Score', 'Rating'], aggfunc = 'count')
counts['Year_of_Release'] = counts.index

for column in counts.drop('Year_of_Release', axis = 1):
    plt.plot(counts['Year_of_Release'], counts[column], marker='', linewidth=2, alpha=0.5, label=column)

plt.legend()
plt.show()

# %% [markdown]
# We can *roughly* estimate that even throughout 2000s, during peak years, something like a third to a half of games were not reviewed or rated. And we can indeed see how games started to roll out in the 1990s up until 2000 without any significant amount of user feedback, ratings or reviews.

# %% [markdown]
# Let's now fill the missing values where needed and change the datatypes!

# %% [markdown]
# ## Preprocess the data

# %% [markdown]
# It's annoying to type up capital letter every time so let's start by making our column names lowercase:

# %%
data.columns = data.columns.str.lower()

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16446 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Beautiful

# %%
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii           2006.0        Sports     41.36
# 1         Super Mario Bros.      NES           1985.0      Platform     29.08
# 2            Mario Kart Wii      Wii           2008.0        Racing     15.68
# 3         Wii Sports Resort      Wii           2009.0        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# There's also no sense in having years as floats. We can simply convert them to datetime and the year of datetime. This will also make it easier to fill in missing values with median values in years (we won't get any weird 2004.5 entries).

# %% [markdown]
# UPD. I was wrong, that didn't make it easier. Now I remember dt.year doesn't prevent that because it becomes int. So I patched the function to round the value down.

# %%
data['year_of_release'] = pd.to_datetime(data['year_of_release'], format = '%Y')
data['year_of_release'] = data['year_of_release'].dt.year

# %% [markdown]
# So these are the games with missing values in year:

# %%
games_wo_year = data.loc[data['year_of_release'].isnull()]['name'].unique()

# %% [markdown]
# We can write a function that looks up the game's median value for year if it appears on other platforms, or, in case it doesn't, fill it in with the median year for the platform:

# %%
for game in games_wo_year:
    game_year_median = data.loc[data['name'] == game]['year_of_release'].median()
    if not pd.isna(game_year_median): # this is to check in case there is just one release: in that case we'll fill in by platform
        data.loc[data['name'] == game, 'year_of_release'] = data['year_of_release'].fillna(round(game_year_median)) # rounding to the earliest year of release for that game in case it's not a round year
    else:
        data.loc[data['name'] == game, 'year_of_release'] = data['year_of_release'].fillna(data.groupby('platform')['year_of_release'].transform('median'))

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16715 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16715 non-null  object
#  2   year_of_release  16715 non-null  float64
#  3   genre            16713 non-null  object
#  4   na_sales         16715 non-null  float64
#  5   eu_sales         16715 non-null  float64
#  6   jp_sales         16715 non-null  float64
#  7   other_sales      16715 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       10014 non-null  object
#  10  rating           9949 non-null   object
# dtypes: float64(6), object(5)
# memory usage: 1.4+ MB

# %% [markdown]
# Looks like it worked! Let's double-check:

# %%
data.query('name == "Advance Wars: Days of Ruin"')
# Out:
#                             name platform  year_of_release     genre  \
# 3289  Advance Wars: Days of Ruin       DS           2008.0  Strategy
#
#       na_sales  eu_sales  jp_sales  other_sales  critic_score user_score  \
# 3289      0.43      0.12       0.0         0.05          86.0        8.7
#
#      rating
# 3289   E10+

# %%
data.query('platform == "DS"')['year_of_release'].median()
# Out:
# 2008.0

# %% [markdown]
# ☝️recall that this random game from this list of games that had missing values in year was only released on one platform. So it seems it worked correctly, as we got the median year of release for that platform

# %%
data.query('name == "Hitman 2: Silent Assassin"')
# Out:
#                            name platform  year_of_release   genre  na_sales  \
# 483   Hitman 2: Silent Assassin      PS2           2002.0  Action      1.36
# 1699  Hitman 2: Silent Assassin       XB           2002.0  Action      0.76
# 9493  Hitman 2: Silent Assassin       GC           2003.0  Action      0.10
#
#       eu_sales  jp_sales  other_sales  critic_score user_score rating
# 483       1.15      0.04         0.41          85.0        7.8      M
# 1699      0.38      0.00         0.05          84.0          8      M
# 9493      0.03      0.00         0.00          83.0        5.5      M

# %% [markdown]
# ☝️ and in this case it selected year based on median values for the same game released elsewhere, and likely rounded the value down from 2002.5 which is what we indended to do.

# %% [markdown]
# It seems like because of the calculations under the hood the values in the year column reverted to float again. Let's just turn them back into ints for clarity. I decided to leave this multistep process in the notebook as evidence to my folly:

# %%
data['year_of_release'] = data['year_of_release'].astype(int)

# %%
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score user_score rating
# 0     28.96      3.77         8.45          76.0          8      E
# 1      3.58      6.81         0.77           NaN        NaN    NaN
# 2     12.76      3.79         3.29          82.0        8.3      E
# 3     10.93      3.28         2.95          80.0          8      E
# 4      8.89     10.22         1.00           NaN        NaN    NaN

# %% [markdown]
# Alrighty

# %% [markdown]
# Let's see what missing values we've got left using sidetable:

# %%
data.stb.missing(style = True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_d1485">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_d1485_level0_col0" class="col_heading level0 col0" >missing</th>
#       <th id="T_d1485_level0_col1" class="col_heading level0 col1" >total</th>
#       <th id="T_d1485_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_d1485_level0_row0" class="row_heading level0 row0" >critic_score</th>
#       <td id="T_d1485_row0_col0" class="data row0 col0" >8,578</td>
#       <td id="T_d1485_row0_col1" class="data row0 col1" >16,715</td>
#       <td id="T_d1485_row0_col2" class="data row0 col2" >51.32%</td>
#     </tr>
#     <tr>
#       <th id="T_d1485_level0_row1" class="row_heading level0 row1" >rating</th>
#       <td id="T_d1485_row1_col0" class="data row1 col0" >6,766</td>
#       <td id="T_d1485_row1_col1" class="data row1 col1" >16,715</td>
# ...

# %% [markdown]
# Alright, we have those two games lacking all insignia, so we might as well drop them:

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# it is better to place all import of libraries at the beginning of the project.

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> Fixed that 👌 <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary:second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍</b>

# %%
data = data.dropna(subset = ['name', 'genre'])

# %%
data.stb.missing(style = True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_3417e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_3417e_level0_col0" class="col_heading level0 col0" >missing</th>
#       <th id="T_3417e_level0_col1" class="col_heading level0 col1" >total</th>
#       <th id="T_3417e_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_3417e_level0_row0" class="row_heading level0 row0" >critic_score</th>
#       <td id="T_3417e_row0_col0" class="data row0 col0" >8,576</td>
#       <td id="T_3417e_row0_col1" class="data row0 col1" >16,713</td>
#       <td id="T_3417e_row0_col2" class="data row0 col2" >51.31%</td>
#     </tr>
#     <tr>
#       <th id="T_3417e_level0_row1" class="row_heading level0 row1" >rating</th>
#       <td id="T_3417e_row1_col0" class="data row1 col0" >6,764</td>
#       <td id="T_3417e_row1_col1" class="data row1 col1" >16,713</td>
# ...

# %% [markdown]
# As for the rest of the missing values, namely the lot of them in rating and critics and users' scores, I think our previous conclusion stands: we can neither fill them nor drop them, so let's keep them and exclude from our analysis when and if needed.

# %% [markdown]
# UPD. On second thought, as per the review suggestion, it's easier and makes more sense to replace 'tbd' with NaN to reduce number of steps in the future:

# %%
data['user_score'].isna().sum()
# Out:
# 6699

# %%
len(data.query('user_score == "tbd"'))
# Out:
# 2424

# %%
data['user_score'] = data['user_score'].replace({'tbd': np.nan})
# Out:
# /var/folders/1g/s3zdmnjx7gsfvmjbw229rc7w0000gn/T/ipykernel_23395/3562022118.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['user_score'] = data['user_score'].replace({'tbd': np.nan})

# %%
data.stb.missing(style = True)
# Out:
# <style type="text/css">
# </style>
# <table id="T_abceb">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_abceb_level0_col0" class="col_heading level0 col0" >missing</th>
#       <th id="T_abceb_level0_col1" class="col_heading level0 col1" >total</th>
#       <th id="T_abceb_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_abceb_level0_row0" class="row_heading level0 row0" >user_score</th>
#       <td id="T_abceb_row0_col0" class="data row0 col0" >9,123</td>
#       <td id="T_abceb_row0_col1" class="data row0 col1" >16,713</td>
#       <td id="T_abceb_row0_col2" class="data row0 col2" >54.59%</td>
#     </tr>
#     <tr>
#       <th id="T_abceb_level0_row1" class="row_heading level0 row1" >critic_score</th>
#       <td id="T_abceb_row1_col0" class="data row1 col0" >8,576</td>
#       <td id="T_abceb_row1_col1" class="data row1 col1" >16,713</td>
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   object
#  10  rating           9949 non-null   object
# dtypes: float64(5), int64(1), object(5)
# memory usage: 1.5+ MB

# %% [markdown]
# Alright! Now we can just convert user_score to float

# %%
data['user_score'] = data['user_score'].astype(float)
# Out:
# /var/folders/1g/s3zdmnjx7gsfvmjbw229rc7w0000gn/T/ipykernel_23395/1942774938.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['user_score'] = data['user_score'].astype(float)

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           9949 non-null   object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %% [markdown]
# UPD. As my reviewer correctly pointed out, it's best to convert missing values in the rating column to 'unknown', since it's actually a useful category in analysis. I didn't think of it at first, and thought about it the same way as about critic and user scores, but rating, unlike, them, is categorical. I agree that it was a miss, so let's fix that:

# %%
data['rating'] = data['rating'].fillna('unknown')
# Out:
# /var/folders/1g/s3zdmnjx7gsfvmjbw229rc7w0000gn/T/ipykernel_23395/3376390366.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['rating'] = data['rating'].fillna('unknown')

# %%
data['rating'].value_counts()
# Out:
# unknown    6764
# E          3990
# T          2961
# M          1563
# E10+       1420
# EC            8
# K-A           3
# RP            3
# AO            1
# Name: rating, dtype: int64

# %% [markdown]
# Last thing to do before we proceed to EDA is to add a total_sales column, which will combine all the sales racked up in NA, Japan, Europe and other markets.

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 16713 entries, 0 to 16714
# Data columns (total 11 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             16713 non-null  object
#  1   platform         16713 non-null  object
#  2   year_of_release  16713 non-null  int64
#  3   genre            16713 non-null  object
#  4   na_sales         16713 non-null  float64
#  5   eu_sales         16713 non-null  float64
#  6   jp_sales         16713 non-null  float64
#  7   other_sales      16713 non-null  float64
#  8   critic_score     8137 non-null   float64
#  9   user_score       7590 non-null   float64
#  10  rating           16713 non-null  object
# dtypes: float64(6), int64(1), object(4)
# memory usage: 1.5+ MB

# %%
data['total_sales'] = data[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis = 1)
# Out:
# /var/folders/1g/s3zdmnjx7gsfvmjbw229rc7w0000gn/T/ipykernel_23395/3860550295.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   data['total_sales'] = data[['na_sales', 'eu_sales', 'jp_sales', 'other_sales']].sum(axis = 1)

# %%
data.head()
# Out:
#                        name platform  year_of_release         genre  na_sales  \
# 0                Wii Sports      Wii             2006        Sports     41.36
# 1         Super Mario Bros.      NES             1985      Platform     29.08
# 2            Mario Kart Wii      Wii             2008        Racing     15.68
# 3         Wii Sports Resort      Wii             2009        Sports     15.61
# 4  Pokemon Red/Pokemon Blue       GB             1996  Role-Playing     11.27
#
#    eu_sales  jp_sales  other_sales  critic_score  user_score   rating  \
# 0     28.96      3.77         8.45          76.0         8.0        E
# 1      3.58      6.81         0.77           NaN         NaN  unknown
# 2     12.76      3.79         3.29          82.0         8.3        E
# 3     10.93      3.28         2.95          80.0         8.0        E
# 4      8.89     10.22         1.00           NaN         NaN  unknown
#
#    total_sales
# 0        82.54
# 1        40.24
# 2        35.52
# ...

# %% [markdown]
# All good!

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# Ok, you offered and implemented the strategy that allows to fill in missing values using groupby and median and other techniques. But, to tell the truth, there are too many missing values in the columns critic_score and user_score, so it is rather risky to fill in missing values using this technique. In fact, we do not know why the data in these columns is missing (we can only hypothesize), and we do not have access to a source that would allow us to replenish the data, restore it, so it is better leave missing values in the data or you can simply replace them with indicators, which you can filter at the next steps of the analysis if it is necessary. Missing values are also some kind of signal worth paying attention to and analyzing, it is valuable in its own way! The analyst's goal when working with missing values is not about filling the 100% of missing values! When filling missing values, it is important to proceed from the specifics of the data, take into account the risks of data distortion and the introduction of artificial trends and characteristics.
#
# I would like to recommend you to leave the missing values in these columns as they are.
#
# As for rating column,  we again cannot restore the data in this column, because the percentage of missing values is really high, but we can replace missing values in this column with marker value `unknown` because later in this project it is important to take into account the games without rating.
#
# As for your approach  to preprocessing of tbd value: the adequate solution here is to replace tbd with NaN value (because 'to be determined' means that the game have not yet had the rating, so NaN is suitable equivalent as you also suggested) But there is no need to replace missing values in this column to int number and then convert the data type to float. You can directly convert the values in this column to float because the NaN value is special case of  float.
#
# One more way to avoid mistakes while data convertion (because of NaN values existence in the column), you can use alternative like this:
#
# `games['user_score'] = np.floor(pd.to_numeric(games['user_score'], errors='coerce')).astype('Int64')`
#
# And still you need to pay more attention to this tbd value according to the instruction.
#
#
# As for year of release - the same logic, we can distort the data by filling in missing values with zero values/ So my recommendation to leave the missing values as they are and at the next steps of the analysis pay more attention to the results considering the big amount of missing values.

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> Thank you Arina! You're absolutely right, thank you for pointing these out to me. I've changed my approach to tbd as you suggested, replacing them with nan, and changing user scores to float (and I will make the relevant changes to the code in later sections where they previously had to specify/cut off 'tbd' and so on. And I made changes to rating too, replacing missing values with 'unknown'. However, forgive me, but if I may - may I argue the case for replacing missing values in year of release in this once case? 😁 I completely agree with you in principle, and I try to be wary about replacing missing values en masse because there is a risk of distorting the data. But since in this case the number of rows with missing values in year of release is quite small, and we have really strong reference like the name of the game if it was released on more than one platform the risk of distortion or the resulting distortion would be really strong – would it not be right to try in this project?  <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary:second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# As a whole - agree with your new version of the decision at this step of the analysis, as for year_of_release - it's up to you, my aim is to provide the recommendation and alternative view:) I think that your approachworks good, especially when you support it with arguments👌

# %% [markdown]
# ## Analyse the data:

# %% [markdown]
# 📝 **Checklist:**

# %% [markdown]
# - [x] Look at how many games were released in different years. Is the data for every period significant?
# - [x] Look at how sales varied from platform to platform. Choose the platforms with the greatest total sales and build a distribution based on data for each year. Find platforms that used to be popular but now have zero sales. How long does it generally take for new platforms to appear and old ones to fade?
# - [x] Determine what period we should take data for. To do so, review answer to the previous questions. The data should allow Ice to build a prognosis for 2017. Continue working only with the data that we've picked as relevant and disregard the data for years up to that, in answering the following questions
# - [x] Which platforms are leading in sales? Which ones are growing or shrinking? Select several potentially profitable platforms
# - [x] Build a box plot for the global sales of all games, broken down by platform. Are the differences in sales significant? What about average sales on various platforms? Describe the findings
# - [x] Look at how user and professional reviews affect sales for one popular platform of our choice (based on previous findings). Build a scatter plot and calculate the correlation between reviews and sales & draw conclusions. Keeping our conclusions in mind, compare the sales of the same games across platforms.
# - [x] Look at the general distribution of games by genre. What can we say about the most profitable genres? Can we generalize about genres with high and low sales?

# %% [markdown]
# ### Game releases over the years

# %% [markdown]
# We are going to build a chart that should look similar in shape to the simple histogram that we made in Step 1, but more precise (and pretty). In order to look at the number of game releases over the years we need to group the data by year and look at counts of names of the games. In fact, since those are the only columns that we need, we might as well take the subset:

# %%
games_count = data[['year_of_release', 'name']].groupby('year_of_release').count().sort_values(by = 'year_of_release').reset_index()

# %%
games_count
# Out:
#     year_of_release  name
# 0              1980     9
# 1              1981    46
# 2              1982    52
# 3              1983    17
# 4              1984    14
# 5              1985    14
# 6              1986    21
# 7              1987    16
# 8              1988    15
# 9              1989    17
# 10             1990    16
# 11             1991    41
# 12             1992    43
# 13             1993    60
# 14             1994   121
# 15             1995   219
# 16             1996   263
# 17             1997   290
# 18             1998   386
# 19             1999   341
# 20             2000   351
# 21             2001   485
# 22             2002   845
# 23             2003   797
# 24             2004   772
# 25             2005   968
# 26             2006  1020
# 27             2007  1202
# 28             2008  1463
# 29             2009  1455
# 30             2010  1285
# 31             2011  1164
# 32             2012   662
# 33             2013   552
# ...

# %% [markdown]
# Now let's use the above dataframe to build a lollipop chart using matplotlib:

# %%
fig, ax = plt.subplots(figsize = (16, 10))
ax.vlines(x = games_count['year_of_release'], ymin = 0, ymax = games_count['name'], color = 'blue', alpha = 0.6, linewidth = 2)
ax.scatter(x = games_count['year_of_release'], y = games_count['name'], s = 75, color = 'black', alpha = 0.6)
ax.set_xticks(games_count['year_of_release'])
ax.set_xticklabels(games_count['year_of_release'], rotation = 40)
plt.title("Number of games rolled out over the years")

# this next trick is really all thanks to our dear instructor who showed it in a webinar. 
# this was hard to find elsewhere!

for row in games_count.itertuples():
    ax.text(row.year_of_release, row.name + 40, s = round(row.name, 2))

plt.show()

# %% [markdown]
# Look on my works, ye mighty...just kidding. Looks good! We see now that before the 2000s there was another slight spike in 1998 followed by the decline..must have been the dotcom bubble. And the market really starts growing after 2000, with the number of releases up by something like a third in 2001. Combine this wuth the more complete data we have in reviews during this period, and I say it makes sense to really look at the data starting from 2001.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, plot looks really great! Agree with your conclusions here!

# %% [markdown]
# ### Sales from platform to platform

# %% [markdown]
# Let's find out the top five platforms in terms of total sales. We can do this by grouping our data by platform and sum up the values for each in the total_sales column that we created for this purpose:

# %%
sales = data[['platform', 'total_sales']].groupby('platform').sum().sort_values(by = 'total_sales', ascending = False).reset_index()

# %%
sales
# Out:
#    platform  total_sales
# 0       PS2      1255.77
# 1      X360       971.42
# 2       PS3       939.65
# 3       Wii       907.51
# 4        DS       806.12
# 5        PS       730.86
# 6       GBA       317.85
# 7       PS4       314.14
# 8       PSP       294.05
# 9        PC       259.52
# 10      3DS       259.00
# 11       XB       257.74
# 12       GB       255.46
# 13      NES       251.05
# 14      N64       218.68
# 15     SNES       200.04
# 16       GC       198.93
# 17     XOne       159.32
# 18     2600        96.98
# 19     WiiU        82.19
# 20      PSV        54.07
# 21      SAT        33.59
# 22      GEN        28.35
# 23       DC        15.95
# 24      SCD         1.86
# 25       NG         1.44
# 26       WS         1.42
# 27     TG16         0.16
# 28      3DO         0.10
# 29       GG         0.04
# 30     PCFX         0.03

# %% [markdown]
# Alright! So it looks like the top five most sales-generating platforms over the years have been:
#
# - PS2
# - X360
# - PS3
# - Wii
# - DS (Nintendo)

# %% [markdown]
# But we want to see how the total_sales for each of them have varied over the years. We could do a lollipop chart for each in a similar way to what we did before, but that would be too cumbersome. We can instead creat one plot to plot them all. Let's first create a new table with the data from five top grossing platforms:

# %%
top_five = data.query('platform == ["PS2", "X360", "PS3", "Wii", "DS"] and year_of_release > 1985')

# %% [markdown]
# UPD. I've added the condition with year of release because when I grouped the data subsequently I saw that a relic version nintendo appears once in 1985, and then no sales for either of the five platforms until 2000. This would create a needless gap in our chart that would also make up about half the length of its x axis (which would be years). There's really no sense in that, so we might as well get rid of that bit.

# %%
top_five.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 8224 entries, 0 to 16711
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             8224 non-null   object
#  1   platform         8224 non-null   object
#  2   year_of_release  8224 non-null   int64
#  3   genre            8224 non-null   object
#  4   na_sales         8224 non-null   float64
#  5   eu_sales         8224 non-null   float64
#  6   jp_sales         8224 non-null   float64
#  7   other_sales      8224 non-null   float64
#  8   critic_score     4336 non-null   float64
#  9   user_score       4160 non-null   float64
#  10  rating           8224 non-null   object
#  11  total_sales      8224 non-null   float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 835.2+ KB

# %% [markdown]
# This just about cuts our dataset in half – just something to keep in mind. This means that the top five platforms' performance accounts for about half of all game releases in our dataset.

# %% [markdown]
# Now we can make a pivot table based on this data:

# %%
top_5 = pd.pivot_table(top_five, index = 'year_of_release', columns = 'platform', values = 'total_sales', aggfunc = 'sum', fill_value = 0)

# %%
top_5
# Out:
# platform             DS     PS2     PS3     Wii    X360
# year_of_release
# 2000               0.00   39.17    0.00    0.00    0.00
# 2001               0.00  166.43    0.00    0.00    0.00
# 2002               0.00  208.36    0.00    0.00    0.00
# 2003               0.00  193.05    0.00    0.00    0.00
# 2004              17.27  212.76    0.00    0.00    0.00
# 2005             130.14  169.27    0.19    0.00    9.22
# 2006             119.81  104.24   21.44  140.19   51.79
# 2007             147.23   76.10   73.19  153.41   95.41
# 2008             147.20   53.90  118.79  177.68  136.07
# 2009             119.56   26.40  130.93  211.17  120.82
# 2010              85.35    5.64  142.96  128.67  175.36
# 2011              26.33    0.45  162.44   59.79  145.23
# 2012              11.67    0.00  108.28   22.94  100.72
# 2013               1.54    0.00  113.25    8.59   88.58
# 2014               0.00    0.00   47.76    3.75   34.74
# ...

# %% [markdown]
# And we're good to pass this data to our line chart:

# %%
sns.lineplot(data = top_5)
sns.set(rc = {'figure.figsize':(12,6)})
plt.show()

# %% [markdown]
# Oh shucks, looks like all of the five most-grossing platforms' sales are shrinking. PS2 was in the limelight for about 4 years when its sales started going down. It's about the same time that its competitors started to appear and gradually pick up growth (2003 for Nintendo, 2004 for X360 and 2005 Wii). We can see how, because Sony was perhaps a bit complacent, it ended up playing some catch up with X360 with its own PS3 which started picking up the slack after PS2 a year later than X360 did, only catching up with it in terms of total sales after 2010, when both were on a downward trajectory.
#
# We saw on our lollypop chart that game releases decreased too over the last five years (as seem to have done total sales for top five platforms). We should take a look at the total total_sales figure for all platforms to see if sales are decreasing overall (or are they just spreading out among fewer games and niche platforms, while keeping up the growth?)

# %%
all_sales = pd.pivot_table(data, index = 'year_of_release', values = 'total_sales', aggfunc = 'sum', fill_value = 0)

# %%
sns.lineplot(data = all_sales)
sns.set(rc = {'figure.figsize':(12,6)})
plt.show()

# %% [markdown]
# Looks like bad news for everybody indeed... But we shoudn't despair. Since it is hard to look for and spot platforms with a good sales trajectory among an overall downward trend, we need to get a new perspective on the data. We can tweak our data so as too see year-to-year growth, and maybe we will be able to select some platforms with a promising dynamic.
#
# It's worth noting that against such a dismal backdrop for the entire market, it might even be worth to look at platforms that are on a downward trajectory, but are not anywhere near zero yet – they can still rack up some good sales. If we look at the multiline chart again, we will see that for most of the platforms on there it took roughly 5 to 6 years to descend from their peak sales to zero, during which they still amassed good revenues.
#
# That being said, I think it would be reasonable to just confine ourselves to the data for the last 5 years if we want to focus on the (near) future – to make sure we don't miss any uptrending platforms.

# %% [markdown]
# ### Select data and review platforms

# %% [markdown]
# Before we add year-to-year change in growth to get a better perspective on our data, let's just select the data anew, starting after 2011:

# %%
new_data = data.query('year_of_release > 2011')

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary<a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, Roman, agree with your logic of thoughts. The year that can be considered as boundary of the current period, can be determined by building histograms for each platform (you did it) The histograms (or barplots) will show that games lose relevance within 3-4, maximum 5 years, at the same time the lifespan of the platform is on average about 10 years. The final year of the dataset is 2016, so we subtract 3-4 years from 2017 (as the year for which we buid the prediction) and get a year, which can be considered the boundary of the current period.
#
# So, finally, 2012 can be correct lower border for the current.

# %%
new_data.describe(include = 'object')
# Out:
#                             name platform   genre   rating
# count                       2905     2905    2905     2905
# unique                      1677       11      12        5
# top     LEGO Marvel Super Heroes      PS3  Action  unknown
# freq                           9      494    1041     1277

# %%
len(new_data)
# Out:
# 2905

# %% [markdown]
# That's less than a fifth of our original data, something to keep in mind. We should also note how this narrows down the numer of platforms to 11 – but this is nothing to fear, since we want to look at data that's relevant for the current period.

# %%
new_data['year_of_release'].value_counts()
# Out:
# 2012    662
# 2015    606
# 2014    583
# 2013    552
# 2016    502
# Name: year_of_release, dtype: int64

# %% [markdown]
# Now, let's group this data by platforms and calculate their total sales per year.

# %%
df = pd.pivot_table(new_data, index = 'year_of_release', columns = 'platform', values = 'total_sales', aggfunc = 'sum', fill_value = 0)

# %%
df
# Out:
# platform           3DS     DS     PC     PS3     PS4   PSP    PSV    Wii  \
# year_of_release
# 2012             51.76  11.67  23.45  108.28    0.00  7.95  16.19  22.94
# 2013             57.04   1.54  12.66  113.25   25.99  3.38  10.59   8.59
# 2014             43.76   0.00  13.63   47.76  100.00  0.24  12.16   3.75
# 2015             27.78   0.00   8.52   16.82  118.90  0.12   6.25   1.14
# 2016             15.14   0.00   5.25    3.60   69.25  0.00   4.25   0.18
#
# platform          WiiU    X360   XOne
# year_of_release
# 2012             17.56  100.72   0.00
# 2013             21.65   88.58  18.96
# 2014             22.03   34.74  54.07
# 2015             16.35   11.96  60.14
# 2016              4.60    1.52  26.15

# %% [markdown]
# Now we can add the year-to-year change in growth to our data:

# %%
growth_dynamic = (df - df.shift(+1))

# %%
growth_dynamic
# Out:
# platform           3DS     DS     PC    PS3    PS4   PSP   PSV    Wii   WiiU  \
# year_of_release
# 2012               NaN    NaN    NaN    NaN    NaN   NaN   NaN    NaN    NaN
# 2013              5.28 -10.13 -10.79   4.97  25.99 -4.57 -5.60 -14.35   4.09
# 2014            -13.28  -1.54   0.97 -65.49  74.01 -3.14  1.57  -4.84   0.38
# 2015            -15.98   0.00  -5.11 -30.94  18.90 -0.12 -5.91  -2.61  -5.68
# 2016            -12.64   0.00  -3.27 -13.22 -49.65 -0.12 -2.00  -0.96 -11.75
#
# platform          X360   XOne
# year_of_release
# 2012               NaN    NaN
# 2013            -12.14  18.96
# 2014            -53.84  35.11
# 2015            -22.78   6.07
# 2016            -10.44 -33.99

# %% [markdown]
# And we can calculate the growth rate:

# %%
growth_rate = (growth_dynamic / df.shift(+1)) * 100

# %%
growth_rate
# Out:
# platform               3DS         DS         PC        PS3         PS4  \
# year_of_release
# 2012                   NaN        NaN        NaN        NaN         NaN
# 2013             10.200927  -86.80377 -46.012793   4.589952         inf
# 2014            -23.281907 -100.00000   7.661927 -57.827815  284.763371
# 2015            -36.517367        NaN -37.490829 -64.782245   18.900000
# 2016            -45.500360        NaN -38.380282 -78.596908  -41.757780
#
# platform                PSP        PSV        Wii       WiiU       X360  \
# year_of_release
# 2012                    NaN        NaN        NaN        NaN        NaN
# 2013             -57.484277 -34.589253 -62.554490  23.291572 -12.053217
# 2014             -92.899408  14.825307 -56.344587   1.755196 -60.781215
# 2015             -50.000000 -48.601974 -69.600000 -25.783023 -65.572827
# 2016            -100.000000 -32.000000 -84.210526 -71.865443 -87.290970
#
# platform               XOne
# year_of_release
# ...

# %% [markdown]
# So, based on this data, this is not the most fantastic outlook out there. We don't actually see any positive growth rate dynamic for any of these platforms. But we have to work with what we have, and judging by what we saw about the average lifespan of sales for a well-performing platform based on the 'top five' data before, I would say the best judgement is to:
#
#  - look at those platforms whose growth rate was still positive within the last three or four years. This means that while the sales won't be growing, they won't be zeroing out as fast as the other platforms too, and they will still bring in substantial revenue. In a better market, we would of course look at growing growth rates, but what can we do.

# %%
sns.lineplot(data = growth_rate)
sns.set(rc = {'figure.figsize':(12,6)})
plt.title("Sales growth rate by platforms from 2013 to 2016")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Needs fixing!🤔:</b>
#
# Please, check this error too (it still can be caused by version)
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> Done 👌 <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary:second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍</b>

# %% [markdown]
# Yeah, we can see how this graph is confusing...although it does help us spot us one platform with a positive dynamic in growth rate! It's the PSV. Indeed looking at the table, we see that its growth rate, as strange as it may sound, has increased from -48% to -32%, which is still a positive dynamic. And we can see that PC is also going more or less steady. But these are relatively small fish in ters of total_sales (although nothing to dismiss!). Let's look at the numbers for total sales themselves to see the trend a bit better in terms of the span of the growth period and how much of it could still lie ahead.

# %%
sns.lineplot(data = df)
sns.set(rc = {'figure.figsize':(12,6)})
plt.title("Total sales by platforms from 2012 to 2016")
plt.show()

# %% [markdown]
# While not discounting PC and PSV, with this graph we see how, considering we are looking at data from 2012, and if we assume that this generation's major platforms will not fade away any faster than did the top five that we analysied before, we might say that both PS4 and XOne will continue to show substantial sales, albeit on a downward trajectory, for the next couple of years: they only reached their peaks in 2015, and surely have a few more years to go. The PC, however, might be nearing its end in terms of the growth cycle. However it is at this point that our analysis likely hits the limits and we would have to think deeper about the peculiarities of the industry itself – like how to differentiate between specialised platforms like PS or Xbox, for which every iteration of the device essentially has a growth and descend cycle of its own, whereas we can't break down PC's the same way – it is the same PC as it was in the 90s, in terms of the categories we are operating in this dataset.
#
# But if we have to pick two most promising platforms in terms of revenue going into the next year, our best bet would still be PS4 and XOne.

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Needs fixing!🤔:</b>
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> Also done 👌 <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary:second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# I can see, everything is alright!

# %% [markdown]
# ### Global sales distribution by platform

# %% [markdown]
# Now let's see how the distributin of sales of all games looks like platform. For this we'll need not the crude sum of all total_sales per platform, but the rather the total sales per game per platform. This distribution can contained in data grouped by platform grouped by games' total sales. Recall that we are now working with data after 2011:

# %%
p_sales = new_data.groupby(['platform', 'name'])['total_sales'].sum().reset_index()

# %%
p_sales
# Out:
#      platform                         name  total_sales
# 0         3DS               Beyblade Burst         0.03
# 1         3DS            Fire Emblem Fates         1.67
# 2         3DS         Frozen: Olaf's Quest         0.59
# 3         3DS   Haikyu!! Cross Team Match!         0.04
# 4         3DS     12-Sai. Honto no Kimochi         0.07
# ...       ...                          ...          ...
# 2899     XOne                       XCOM 2         0.04
# 2900     XOne                       ZombiU         0.01
# 2901     XOne          Zombie Army Trilogy         0.11
# 2902     XOne            Zoo Tycoon (2013)         0.36
# 2903     XOne   Zumba Fitness: World Party         0.24
#
# [2904 rows x 3 columns]

# %% [markdown]
# Using this data we can display the distribution on a combined boxplot. But first let's just take a template of sorted platforms by sales for order:

# %%
plt.figure(figsize = (14, 10))
sns.boxplot(data = p_sales, x = 'platform', y = 'total_sales')
# Out:
# <AxesSubplot:xlabel='platform', ylabel='total_sales'>

# %% [markdown]
# So we get a really flat boxplot, which is not very helpful visually. It seems like here we must make the tradeoff depending on if we want to account for the most grossing games (which would make sense) by cutting out games whose sales below a certain threshold, which could be a lot of games in terms of count, or we could do the opposite and consider these higher grossing games outliers. Let's check who the outliers are in terms of our data:

# %%
len(p_sales.query('total_sales < 1'))
# Out:
# 2566

# %%
len(p_sales.query('total_sales > 1'))
# Out:
# 338

# %% [markdown]
# Well, since the majority of games actually make less a million (in these past 5 years), it will be fair to look at them.

# %%
plt.figure(figsize = (14, 10))
sns.boxplot(data = p_sales.query('total_sales < 1'), x = 'platform', y = 'total_sales')
plt.title("Distibution of sales figures for games by platforms during 2012-2016")
plt.show()

# %% [markdown]
# We can line them up by total_sales numbers per platform for convenience and hide the outliers (Thanks for the tip to my reviewer!):

# %%
top_sales = new_data.query('total_sales < 1')[['platform', 'total_sales']].groupby('platform').sum().sort_values(by = 'total_sales', ascending = False).reset_index()
order = top_sales['platform']

# %%
plt.figure(figsize = (14, 10))
sns.boxplot(data = p_sales.query('total_sales < 1'), x = 'platform', y = 'total_sales', order = order, showfliers = False)
plt.title("Distibution of sales figures for games by platforms during 2012-2016")
plt.show()

# %% [markdown]
# Looks better.

# %% [markdown]
# So we see that indeed there are strong differences as to what kind of sales figures per games are going for each platform. We can see that X360 has the best typical sales figure per game on average – more that half of its games' total revenue starts at more than 200000 USD, and typically more games that bring in much more than that. But of course we should consider, too that the majority of those sales in terms of revenue value happened in 2012, and the total amount has dropped steeply since then. By comparison, for the next-gen XOne, which has been on the rise in terms of total sales during the same period when X360 was declining, the typical revenue per game was about a third lower:

# %%
p_sales.query('total_sales < 1').groupby('platform')['total_sales'].median().sort_values(ascending = False)
# Out:
# platform
# X360    0.220
# WiiU    0.150
# Wii     0.145
# PS3     0.140
# XOne    0.140
# PS4     0.115
# 3DS     0.090
# PC      0.080
# PSV     0.050
# DS      0.045
# PSP     0.040
# Name: total_sales, dtype: float64

# %% [markdown]
# And PS4, which has dominated the market in terms of total sales, grossing almost twice as much as XOne over the same period of time, seems to typically gross much less per game than XOne does. Even smaller sums are more common for popular mobile-format devices like Nintendo. All this could speak for the general trend in platforms: one of the reasons of PS4 success in total sales could be its lower price for games on average, which made its products more accessible to a larger customer base. Either way, knowing that the platforms such as Xbox360 are already on the decline, we should consider looking to the popular platforms that also try to expand their user base by offering products at accessible prices – this could lead to more sales overall.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary<a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, boxplots are built correctly!

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# As for your boxplots if you want to exclude outliers from the picture, you can use `showfliers = False`

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> Awesome tip, thank you! Really helpful with boxplots. <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary:second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍</b>

# %% [markdown]
# ### User and professional reviews' effect on sales

# %% [markdown]
# Let's take our five most-performing platforms in terms of sales and see if those are in any way effected by the reviews that critics and users leave. We can build a function to test it on the top-performing platform and then apply it on its competitor platforms.

# %% [markdown]
# We have to remember that we have missing values for both critic and user reviews. We have to drop them for this to work, but we should keep in mind that in this case we are measuring the effect (or lack of it) of reviews only where they are present, and that it is NOT the same thing as measuring the mere presence or absence of reviews on sales.

# %%
fresh_data = new_data.dropna(subset = ['critic_score', 'user_score'])

# %%
fresh_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1308 entries, 16 to 16692
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             1308 non-null   object
#  1   platform         1308 non-null   object
#  2   year_of_release  1308 non-null   int64
#  3   genre            1308 non-null   object
#  4   na_sales         1308 non-null   float64
#  5   eu_sales         1308 non-null   float64
#  6   jp_sales         1308 non-null   float64
#  7   other_sales      1308 non-null   float64
#  8   critic_score     1308 non-null   float64
#  9   user_score       1308 non-null   float64
#  10  rating           1308 non-null   object
#  11  total_sales      1308 non-null   float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 132.8+ KB

# %%
def review_effect_plot(platform, review): # 'user_score' or 'critic_score'
    subset = fresh_data.loc[fresh_data['platform'] == platform][['total_sales', review]]
    #if review == 'user_score':
    #    subset = subset.loc[subset['user_score'] != "tbd"]
    #    subset['user_score'] = subset['user_score'].astype(float)
        
    subset.plot(kind = 'scatter', x = review, y = 'total_sales', figsize = (10, 6))
    plt.title(f'Sales on {platform} by {review}')
    plt.show()

# %%
def show_corr(platform, review):
    subset = fresh_data.loc[fresh_data['platform'] == platform][['total_sales', review]]
    #if review == 'user_score':
    #    subset = subset.loc[subset['user_score'] != "tbd"]
    #    subset['user_score'] = subset['user_score'].astype(float)
        
    p_corr = subset['total_sales'].corr(subset[review])
    print(p_corr)
    if p_corr > 0.7:
        print(f'There is a positive correlation between sales and {review} for games on {platform}')
    else:
        print(f'There is no correlation between sales and {review} for games on {platform}')

# %%
review_effect_plot('PS4', 'user_score')

# %%
show_corr('PS4', 'user_score')
# Out:
# -0.03362497596528879
# There is no correlation between sales and user_score for games on PS4

# %% [markdown]
# The negative Pearson coefficient tells that there is negative correlation between the two variables, however it is too close to 0, so one can say it is so weak as if there was no relationship between the variables at all (almost). So, if imagined it was closer to -1 then there would be a strong negative correlation and games with worse reviews would be likely to sell more! A wonder indeed. But that is not the case and we can only see the direction of correlation is negative (such as it is – which is weak). How about critics' reviews?

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Needs fixing!🤔:</b>
#
# Roman, it is better to pay more attention to the correlation interpretation: we cannot conclude that there is no correlation, it is but yes, as you mentioned we have weak correlation. So we can only conclude about the direction of the correlation (positive/negative) and power (weak/strong):
#
# https://www.investopedia.com/ask/answers/032515/what-does-it-mean-if-correlation-coefficient-positive-negative-or-zero.asp
#
# https://www.statisticshowto.com/probability-and-statistics/correlation-analysis/
# </div>

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> Of course, you're absolutely right. Thanks for pointing this out! I was definitely way too categorical in rejecting it straight away because the coefficient was below the threshold, and that made me gloss over the obvious difference and direction of correlation, and not pay enough attention to the conclusions. I went over it again and rewrote my interpretation. <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary:second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, agree with new version of the interpretation, good job!

# %%
review_effect_plot('PS4', 'critic_score')

# %%
show_corr('PS4', 'critic_score')
# Out:
# 0.40589480145836637
# There is no correlation between sales and critic_score for games on PS4

# %% [markdown]
# We set a fair threshold of 0.7 by most standards, and even though we can not say for sure there is a dependency between critics' reviews and sales, we can see that the direction of the correlation between the varibale is positive, so there is some likelihood that a better review would associate with better sales, and the relationship is much stronger between the platform and critics reviews than with users reviews, but it would still be considered weak by most standards.

# %% [markdown]
# Now let's what we can find out about the rest of the popular platforms:

# %%
new_data[['platform', 'total_sales']].groupby('platform').sum().sort_values(by = 'total_sales', ascending = False).reset_index()
# Out:
#    platform  total_sales
# 0       PS4       314.14
# 1       PS3       289.71
# 2      X360       237.52
# 3       3DS       195.48
# 4      XOne       159.32
# 5      WiiU        82.19
# 6        PC        63.51
# 7       PSV        49.44
# 8       Wii        36.60
# 9        DS        13.21
# 10      PSP        11.69

# %%
top = ['PS3', 'X360', '3DS', 'XOne']
scores = ['user_score', 'critic_score']

# %%
for pl in top:
    for score in scores:
        review_effect_plot(pl, score)
        show_corr(pl, score)
# Out:
# 0.0030792381862629146
# There is no correlation between sales and user_score for games on PS3
# 0.330930994936513
# There is no correlation between sales and critic_score for games on PS3
# -0.0022574187683972583
# There is no correlation between sales and user_score for games on X360
# 0.36026590261380487
# There is no correlation between sales and critic_score for games on X360
# 0.20535376485966675
# There is no correlation between sales and user_score for games on 3DS
# 0.31362816460243675
# There is no correlation between sales and critic_score for games on 3DS
# -0.09400318326920865
# There is no correlation between sales and user_score for games on XOne
# 0.410422035612964
# There is no correlation between sales and critic_score for games on XOne

# %% [markdown]
# It looks like in general, there is likely no correlation of sales figures with user scores: for most of the platforms studied, the direction of correlation is sometimes even negative, but with the exception of Nintendo, always too close to 0, and therefore very weak.
#
# At the same we see a somewhat stronger (and consistently positive) correlation between sales and critics reviews, but since it is still in the range of 0.3 to slightly over 0.4, this would be insufficient to conclude that the variables are related. Although from the business (and marketing) perspective, obviously, this is still something not to be discarded. It's likely they are related in more complex ways. But to make any conclusions of that, one would have to ask which one is driving the other, and to ask more questions on the nature and origion of data on user_scores.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary<a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# As for platform choice - I can agree with your choice, because yes, at this step for the correlation analysis we need to choose one of potentially profitable platform, so PS4 is adequate choice here.

# %% [markdown]
# ### Genres by sales

# %% [markdown]
# Let's look at the genres: which have performed the best? Have some of them been on decline, while other ones were getting more popular? Let's use sales as a benchmark:

# %%
genres_data = pd.pivot_table(new_data, index = 'year_of_release', columns = 'genre', values = 'total_sales', aggfunc = 'sum', fill_value = 0)

# %%
genres_data
# Out:
# genre            Action  Adventure  Fighting   Misc  Platform  Puzzle  Racing  \
# year_of_release
# 2012             123.91       5.79      9.18  22.22     18.37    1.72   13.61
# 2013             122.79       6.18      7.09  25.51     24.54    0.96   12.46
# 2014              97.58       5.57     15.85  23.38      8.81    1.49   16.66
# 2015              72.02       8.16      7.90  11.57      6.05    0.71    8.07
# 2016              30.11       3.82      4.47   2.60      3.23    0.01    2.79
#
# genre            Role-Playing  Shooter  Simulation  Sports  Strategy
# year_of_release
# 2012                    46.91    71.77       13.36   30.42      3.26
# 2013                    44.48    62.11        8.82   41.17      6.12
# 2014                    45.88    65.21        5.58   45.15      0.98
# 2015                    37.64    67.51        5.66   40.84      1.85
# 2016                    18.18    38.22        1.89   23.49      1.13

# %%
sns.lineplot(data = genres_data)
sns.set(rc = {'figure.figsize':(12,6)})
plt.title("Total sales by genres from 2012 to 2016")
plt.show()

# %% [markdown]
# <div class="alert alert-block alert-danger">
#     <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Needs fixing!🤔:</b>
#
# Please, check this bug too, the same as above:
#
# ![image.png](attachment:image.png)

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> Fixed that 👌 <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary:second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Yes, now it works!

# %% [markdown]
# Despite the declining sales for everyone, we can see that action and shooter remain two most popular genres by sales, and shoot even outcompeted action in this sense in the last year. Role-playing and sports are close seconds. But we can see the market dwindling for every genre in terms of sales.

# %%
top_list = new_data[['genre', 'total_sales']].groupby('genre').sum().sort_values(by = 'total_sales', ascending = False).reset_index()

# %%
top_list.stb.freq(['genre'], value = 'total_sales', style = True, cum_cols = False)
# Out:
# <style type="text/css">
# </style>
# <table id="T_b092f">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_b092f_level0_col0" class="col_heading level0 col0" >genre</th>
#       <th id="T_b092f_level0_col1" class="col_heading level0 col1" >total_sales</th>
#       <th id="T_b092f_level0_col2" class="col_heading level0 col2" >percent</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_b092f_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_b092f_row0_col0" class="data row0 col0" >Action</td>
#       <td id="T_b092f_row0_col1" class="data row0 col1" >446</td>
#       <td id="T_b092f_row0_col2" class="data row0 col2" >30.73%</td>
#     </tr>
#     <tr>
#       <th id="T_b092f_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_b092f_row1_col0" class="data row1 col0" >Shooter</td>
#       <td id="T_b092f_row1_col1" class="data row1 col1" >305</td>
# ...

# %% [markdown]
# In general, we can say that during the last five years Action genre accounted for over 30% of total sales, and Action and Shooter together dominated the market with over half the total_sales. We can also look at the mean and median values for sales by genre, to see how that will change the rankings, but if we want to think about market share by sales, the above table is useful.

# %%
top_list_by_mean = new_data[['genre', 'total_sales']].groupby('genre').mean().sort_values(by = 'total_sales', ascending = False).reset_index()
top_list_by_mean
# Out:
#            genre  total_sales
# 0        Shooter     1.280756
# 1       Platform     0.717647
# 2         Sports     0.675634
# 3   Role-Playing     0.519059
# 4         Racing     0.461983
# 5           Misc     0.441865
# 6     Simulation     0.435926
# 7         Action     0.428828
# 8       Fighting     0.408165
# 9       Strategy     0.187887
# 10        Puzzle     0.174643
# 11     Adventure     0.097426

# %%
top_list_by_median = new_data[['genre', 'total_sales']].groupby('genre').median().sort_values(by = 'total_sales', ascending = False).reset_index()
top_list_by_median
# Out:
#            genre  total_sales
# 0        Shooter        0.430
# 1         Sports        0.240
# 2       Platform        0.210
# 3   Role-Playing        0.140
# 4         Racing        0.135
# 5       Fighting        0.130
# 6         Action        0.120
# 7           Misc        0.120
# 8     Simulation        0.120
# 9       Strategy        0.080
# 10        Puzzle        0.045
# 11     Adventure        0.030

# %% [markdown]
# Looking at mean and median values is also useful: we can see shooter games, on average, sell more than action, and for both games there must be some wild outliers, which must be some very successful games. Especially so in the case of Action – we can see that the data is scewed for both with mean 3x the value of median, but Action completes rips total sales with a wildly successful release.

# %%
top_games = new_data[['name', 'genre', 'total_sales']].groupby(['name', 'genre']).sum().sort_values(by = 'total_sales', ascending = False).reset_index()
top_games.head(10)
# Out:
#                              name    genre  total_sales
# 0              Grand Theft Auto V   Action        56.58
# 1      Call of Duty: Black Ops II  Shooter        29.40
# 2            Call of Duty: Ghosts  Shooter        27.39
# 3       Call of Duty: Black Ops 3  Shooter        25.67
# 4                       Minecraft     Misc        24.16
# 5  Call of Duty: Advanced Warfare  Shooter        21.97
# 6                         FIFA 15   Sports        17.37
# 7                         FIFA 14   Sports        16.46
# 8                         FIFA 16   Sports        16.30
# 9                  FIFA Soccer 13   Action        15.97

# %% [markdown]
# Indeed we can see how a single Action game is dominating and it's Action.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# Here you can also calculate the mean and median sales per genre, the leader will change.

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> Thank you for the suggestion! It's a useful bit of analysis, I tried to expand on it a bit. <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary:second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Good job!

# %% [markdown]
# ## Create a user profile for each region

# %% [markdown]
# Let's do a breakdown for the three main regions in terms of sales: do they differ by platforms and genres? We'll do this using a function. I will round the values for market share for simplicity.

# %%
def show_top_platforms(region, parameter): # 'platform' or 'genre'
    top = new_data[[parameter, region]].groupby(parameter).sum().sort_values(by = region, ascending = False).reset_index()
    top['share'] = round((top[region]/top[region].sum()) * 100)
    print(top.head())

# %%
regions = ['na_sales', 'eu_sales', 'jp_sales']
for region in regions:
    print(f'Top five platforms by sales and market share for {region}:')
    print()
    show_top_platforms(region, 'platform')
    print()
# Out:
# Top five platforms by sales and market share for na_sales:
#
#   platform  na_sales  share
# 0     X360    140.57   24.0
# 1      PS4    108.74   18.0
# 2      PS3    103.74   17.0
# 3     XOne     93.12   16.0
# 4      3DS     55.87    9.0
#
# Top five platforms by sales and market share for eu_sales:
#
#   platform  eu_sales  share
# 0      PS4    141.09   28.0
# 1      PS3    107.27   21.0
# 2     X360     74.89   15.0
# 3     XOne     51.59   10.0
# 4      3DS     42.85    8.0
#
# Top five platforms by sales and market share for jp_sales:
#
#   platform  jp_sales  share
# 0      3DS     87.82   46.0
# 1      PS3     35.29   18.0
# 2      PSV     21.11   11.0
# 3      PS4     15.96    8.0
# 4     WiiU     13.01    7.0

# %% [markdown]
# This is pretty interesting! We can see how Xbox is more popular in the States, with 24 percent of the sales, and the new generation XOne stepping on the heels of both models of PS, where for EU it's the opposite. In both of these markets the sales are dominated by these two gaming stations, and the handheld Nintendo 3 takes smallest share (still, meaning in the top 5) of less than 10%. For Japan it's reversed - Nintendo 3 dominates sales with 46%, and Xbox is not even a thing.
#
# Let's what the genre preferences are like for these regions:

# %%
regions = ['na_sales', 'eu_sales', 'jp_sales']
for region in regions:
    print(f'Top five genres by sales and market share for {region}:')
    print()
    show_top_platforms(region, 'genre')
    print()
# Out:
# Top five genres by sales and market share for na_sales:
#
#           genre  na_sales  share
# 0        Action    180.15   30.0
# 1       Shooter    144.83   24.0
# 2        Sports     81.53   14.0
# 3  Role-Playing     64.11   11.0
# 4          Misc     38.19    6.0
#
# Top five genres by sales and market share for eu_sales:
#
#           genre  eu_sales  share
# 0        Action    161.70   32.0
# 1       Shooter    113.49   22.0
# 2        Sports     69.09   14.0
# 3  Role-Playing     48.58   10.0
# 4        Racing     27.29    5.0
#
# Top five genres by sales and market share for jp_sales:
#
#           genre  jp_sales  share
# 0  Role-Playing     65.54   34.0
# 1        Action     52.80   27.0
# 2          Misc     13.10    7.0
# 3    Simulation     10.41    5.0
# 4      Fighting      9.44    5.0

# %% [markdown]
# Fascinating. Again, a strong difference in preferences for genres: whereas both North American players seem to share the taste Action, Shooter, Sports and Role Playing genres in equal measure, Europeans also like Races more than players from North America. And the Role-Playing genre is by far the most popular on the Japanese market, leaving Action (that dominated global sales until 2016) behind. Players from that region also prefer Simulation, Fighting and other genres to both Sports and Racing.

# %% [markdown]
# Could the sales also be affected by the rating of the games?

# %%
regions = ['na_sales', 'eu_sales', 'jp_sales']
for region in regions:
    print(f'Top five rating categories by sales and market share for {region}:')
    print()
    show_top_platforms(region, 'rating')
    print()
# Out:
# Top five rating categories by sales and market share for na_sales:
#
#     rating  na_sales  share
# 0        M    231.67   39.0
# 1        E    114.49   19.0
# 2  unknown    103.31   17.0
# 3     E10+     78.01   13.0
# 4        T     66.31   11.0
#
# Top five rating categories by sales and market share for eu_sales:
#
#     rating  eu_sales  share
# 0        M    194.44   38.0
# 1        E    113.05   22.0
# 2  unknown     91.50   18.0
# 3     E10+     57.25   11.0
# 4        T     53.01   10.0
#
# Top five rating categories by sales and market share for jp_sales:
#
#     rating  jp_sales  share
# 0  unknown    109.11   57.0
# 1        E     28.33   15.0
# 2        T     26.09   14.0
# 3        M     21.20   11.0
# 4     E10+      8.19    4.0

# %% [markdown]
# - M stands for Mature (17 or older)
# - E stand for Everyone (6 or older)
# - E stand for Everyone (but 10 or older – "may contain more cartoon, fantasy or mild violence, mild language, and/or minimal suggestive themes")
# - T stand for Teen (13 or older)

# %% [markdown]
# Interesting: north american and european markets appear identical in what we can (speculatively) deduce from this breakdown - that gaming market is more aimed at adults with roughly half of all sales being designated for 17 or older, and the other half for teenagers and kids, where in Japan gaming culture is more popular among kids (or less popular with adults?..). This kind of rhymes with the Shooter/Action genre being more popular in EU and North America, and RPG being more popular in Japan, shince Shooter and Action games are more likely targeted at adult audience. But it could also have other reasons.

# %% [markdown]
# UPD. Keeping games that were not rated really adds interesting changes to the results! We can see how unrated games (in terms of rating assigned, not user or critic reviews) make up a large proportion of the market. And we can especially see that most of the games by far (more than all other categories combined!) sold in the Japan region are not rated. We can offer speculative theories as to why that it: it could be looser market regulation, or it could be that it doesn't apply to certain games, or some other reason. It could also be the case that data on ratig for that particular market was unavailable.

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary <a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# Ok, Roman, the logic of the decision is correct, but still it is better to include in the analysis the platforms without rating, how to do it - check my comment above.

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> Thanks again! I tried to expand my conclusion a little bit, based on the new results. It really does change the picture! <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary:second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, now the conclusion and results are more precise!

# %% [markdown]
# ## Test Hypothesis

# %% [markdown]
# We have already seen that user and critic reviews don't seem to correlate with sales, but as a final step, let's find out if users rate games any differently for different platforms.

# %% [markdown]
# We are going to employ statistical methods to test the following two hypothesis:
#
# - "Average user ratings of the Xbox One and PC platforms are the same"
# - "Average user ratings for the Action and Sports genres are different"
#
# We'll build a function that performs a two-tailed t_test that calculates the p_value and see whether the probability that the difference between the means of reviews are different is strong enough too tell us whether we should reject these hypothesis, or if we cannot reject them.
#
# One small step before we implement the function: let's once again clean our new_data (going from after 2011) from 'tbd' and missing values. We'll use samples of (slices of) data for platforms XOne and PC and for genres Action and Sports, respectively.

# %%
new_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 2905 entries, 16 to 16714
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   name             2905 non-null   object
#  1   platform         2905 non-null   object
#  2   year_of_release  2905 non-null   int64
#  3   genre            2905 non-null   object
#  4   na_sales         2905 non-null   float64
#  5   eu_sales         2905 non-null   float64
#  6   jp_sales         2905 non-null   float64
#  7   other_sales      2905 non-null   float64
#  8   critic_score     1324 non-null   float64
#  9   user_score       1543 non-null   float64
#  10  rating           2905 non-null   object
#  11  total_sales      2905 non-null   float64
# dtypes: float64(7), int64(1), object(4)
# memory usage: 295.0+ KB

# %% [markdown]
# Let's just keep track of the numbers so we have an understanding of how large our samples will be.

# %%
#final_data = new_data.dropna(subset = ['user_score'])

# %%
#len(final_data)

# %%
#final_data.info()

# %% [markdown]
# All good. Now let's select the samples and test the first hypothesis:

# %% [markdown]
# <div class="alert alert-block alert-warning">
#    <h2>Reviewer's commentary<a class="tocSkip"> </h2>
#     <br/>
# <b>Remarks and recommendations📌:</b>
#
# Useful tip: if there are any missing values in your samples you can drop them using `dropna()` (as you did) or (and this method is more logical) you can use special argument `nan_policy` that can specified as `omit`, so it helps to drop NaN values too in  `st.ttest_ind`
#
#
# https://docs.scipy.org/doc/scipy/reference/generated/scipy.stats.ttest_ind.html
#
#
# Your strategy of action here can be optimized: you can replace tbd wiwth NaN (Nan - is the special case of float) so then you can simply convert data types to float in user_score as for missing values - to deal with them you can use nan_policy = omit and not to replace NaN with marker.

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> Thanks for pointing this out! It's very useful indeed and I tried to rework the process using this way. Everything seems to have worked!  <a class="tocSkip"> </div>

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary:second iteration of the review <a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# It works, indeed!👌😎

# %% [markdown]
# ### "Average user ratings of the Xbox One and PC platforms are the same"

# %%
#xbox = final_data.query('platform == "XOne"')['user_score']
xbox = new_data.query('platform == "XOne"')['user_score']

# %%
len(xbox)
# Out:
# 247

# %%
#pc = final_data.query('platform == "PC"')['user_score']
pc = new_data.query('platform == "PC"')['user_score']

# %%
len(pc)
# Out:
# 255

# %% [markdown]
# Alright. The sample sizes are good enough for our test! Let's go:

# %% [markdown]
# Because we are comparing independent instances of user score for different platforms between each other and asking whether their mean value is the same, it's appropriate that we use a two-tailed t-test. We are testing if means of two statistical populations are equal. In this case our null hypothesis (H0) is: "The average user rating for (games on) XOne and PC is equal". And so the alternative hypothesis (H1) is: "The average user_score for XOne and PC is not equal".
#
# It is not guaranteed likely that the variance of the two groups (average user scores for the two platforms) is the same. To fool-proof against that possibility, we will include another method inside the function that tests for that. If the variance is different, the function inside the function will pass the respective third parameter to our ttest (by default it assumes that the variance is equal), so that we can switch to perform Welch's ttest, which is more appropriate for when variance is not equal. And we will use the standard alpha of 5% to assess the result.

# %%
def t_test(sample_1, sample_2, s1_name, s2_name, alpha = 0.05): # we are just passing the names for extra printing feature at the end
    p_value_levene = st.levene(sample_1, sample_2).pvalue
    if p_value_levene < alpha:
        var_value = False
    else:
        var_value = True
    
    p_value = st.ttest_ind(sample_1, sample_2, equal_var = var_value, nan_policy = 'omit').pvalue
    print(p_value)
    if p_value < alpha:
        print(f'Reject Null Hypothesis: the average user score for {s1_name} and {s2_name} games is different. There is a very tiny probability of randomly getting any other difference between them, therefore we must reject the probability that they can be equal.')
    else:
        print('Cannot reject the Null Hypothesis: there is a relatively high chance of getting similar average user score.')

# %%
t_test(xbox, pc, "Xbox One", "PC")
# Out:
# 0.625277452217331
# Cannot reject the Null Hypothesis: there is a relatively high chance of getting similar average user score.

# %% [markdown]
# A playah's a playah! On both Xbox and PC. Interesting, so we know that there is high chance that average user review for Xbox and PC games would be the same. Even though we are not comparing the same games necessarily, though they may overlap in our samples (important to keep in mind), we comparing large enough samples of games – different games of different genres, but on two different platforms. Perhaps it doesn't make much difference to the user, or there are no substantial difference in gameplay, or users of each platform are satisfied wiht the games that come for those platforms.
#
# But let's if the same is true for different genres of games. My tentative bet is that these ones should actually be more likely to be different, but let's find out:

# %% [markdown]
# ### "Average user ratings for the Action and Sports genres are different"

# %% [markdown]
# We are comparing independent instances of user score for different genres between each other and asking whether their mean value is the same. So let's the original hypothesis (which says "they are different", so that the Null Hypothesis says "Average user ratings for the Action and Sports genres are equal", so we can safely reuse our function without confusing our head with the result. The alternative hypothesis will be, respectively: "Average user ratings for the Action and Sports genres are not equal".

# %%
action = new_data.query('genre == "Action"')['user_score']

# %%
len(action)
# Out:
# 1041

# %%
sports = new_data.query('genre == "Sports"')['user_score']

# %%
len(sports)
# Out:
# 268

# %% [markdown]
# Recall from our earlier research that the Action genre is indeed much more popular than sports, especially in the largest markets by sales (NA and EU). Alright, let's go:

# %%
t_test(action, sports, "Action", "Sports")
# Out:
# 1.1405639632262841e-26
# Reject Null Hypothesis: the average user score for Action and Sports games is different. There is a very tiny probability of randomly getting any other difference between them, therefore we must reject the probability that they can be equal.

# %% [markdown]
# It looks like my hunch was right! The tiny p_value we got from the test obliges us to reject the hypothesis that the average user score for Action and Sports games is equal.

# %% [markdown]
# <div class="alert alert-block alert-success">
#     <h2>Reviewer's commentary<a class="tocSkip"> </h2>
#     <br/>
# <b>Well done!👍:</b>
#
# Ok, Roman, what is absolutely correct at this step of the analysis:
#
# 1) you correctly formulated the null and alternative hypotheses
#
# 2) the test for statistical hypotheses testing was chosen correctly
#
# 3) it is great that you checked the variances for the equality using Levene's test

# %% [markdown]
# ## Overall conclusion 🎮

# %% [markdown]
# We've studied the data for game releases and sales and analysed how different platforms and genres have performed over the years. Overall, one of the most important things we've seen is what seems to be a general decline in game releases and sales overall. So it seems like the market itself has shrunken from the peak quite significantly over the course of the last 7 to 8 years (up to 2016). We can't say for sure why that is – we can assume that the decline from the peak in 2008 could be related to the effects of the financial crisis in some way, but it's hard to say whether that would hold so long.
#
# We can only speculate that this could be due to something that cannot be captured by our dataset – for example, due to the rise of smartphones and mobile games. Whatever it is, it's something to look for outside of the data we've got so far, but definitely worth considering for our business, because if Ice product remains tied to these platforms and games, it's likely that the revenue will only decline or not grow so much in the long term, because the pie is shrinking for everyone.
#
# Other than that, we saw that users review the games more or less equally on two different platforms – Xbox and PC, but that they rate games of Action and Sports genre differently. However we also know that there is no strong correlation between user reviews and sales, and the relationship could be that the most well-produced and popular game gradully gains more acclaim from the users.
#
# Still, working with data that we have we've seen that the market in NA and the EU seems to be dominated by gaming stations, whether Play Station or Xbox, but if we want to expand our clientele in Japan, we should better consider platforms like Nintendo and maybe try to study their competetion. While growth is shrinking for everybody, it is likely that PS and XBox will continue to rake in the most sales, but we must remain on our toes and watch the trends carefully. As we now know, the cycle of growth for the last 'great whale' that was PS4 is already coming to an end. And while it would be a fair assumption that the next generation PS as well as Xbox will likely have good overall sales, those would be a more long term investment, and we should be careful not to overinvest in products related to the biggest platforms like PS4 that are already on the downward slope .

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **The overall review conclusion**
#
# Roman, thank you for submitting your project! I can see that you've worked really hard on it! I'm really impressed this the amount of work you have done. But there are several things in your project which I suppose it is important to fix in order to make your project really ideal! My comments will navigate you!
#
#
# **Good things and practices in your project I want to highlight🙂**:
#
# * You use different methods for working with your data. It is really great that you can apply these methods on practice, keep it up!
# * You worked with the visualization, it is really good that you use plots in your work!
# * You have formulated conclusions after the each step of the analysis, good job!
# * You correctly used test for statistical hypotheses testing.
# * You project is well-structured and orginized, it was a pleasure for me to review it.
#
# **What is worth working on👀**:
#
# * It is important to fix all the bugs in the code, try to specify the version of the seaborn.
# * Other recommendations you will find in my comments.
#
# **Good luck! I will wait for your work for a second iteration of the review!😉**
# ![gif](https://media.giphy.com/media/l41Yh1olOKd1Tgbw4/giphy.gif)

# %% [markdown]
# #### <font color='Purple'>Student's commentary:</font> Thank you so much for taking the time to review my project again, and for leaving detailed feedback and tips! I really appreciate it. I've tried to fix most of the mishaps, and I hope the library installations and updates will work smoothly this time. <a class="tocSkip"> </div>

# %% [markdown]
# <div style="border:solid Chocolate 2px; padding: 40px">
#
# **The overall review conclusion: second iteration of the review**
#
# Roman, thank you for submitting your project with corrections! And thank you for your comments and explanations!😉
#
# You did a great job to improve the project, I can see your progress, so I hasten to say that your project has been accepted and you can proceed to the next sprint!
#
# **I wish you exciting and cool projects in the next sprints😉**
#
# ![gif](https://media.giphy.com/media/Ypb0ILMUEPtdY43gH2/giphy.gif)
